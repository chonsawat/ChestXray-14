# %%
import pandas as pd

# %%
df_list = []
for i in range(1, 6):
    filename = "/home/jovyan/ChestXray-14/results/paper/table3_1/best_model_fold_{}.csv".format(i)
    df = pd.read_csv(filename)
    df_list.append(df)

# %%
df_tmp = pd.concat(df_list).T
df_tmp.columns = [f"Fold {i+1}" for i in range(5)]
df_tmp.to_csv("/home/jovyan/ChestXray-14/results/paper/table3_1/best_model_5_folds.csv", index=True)
df_tmp
# Out:
#                       Fold 1    Fold 2    Fold 3    Fold 4    Fold 5
# No Finding          0.750886  0.753198  0.740660  0.749626  0.758701
# Atelectasis         0.342496  0.338869  0.340299  0.352240  0.371999
# Consolidation       0.193038  0.213219  0.207992  0.212666  0.213697
# Infiltration        0.383263  0.393012  0.386318  0.400829  0.401369
# Pneumothorax        0.288976  0.297448  0.263662  0.296447  0.303048
# Edema               0.226340  0.203846  0.222080  0.252390  0.233229
# Emphysema           0.135762  0.130028  0.147580  0.153348  0.158977
# Fibrosis            0.064455  0.066047  0.068509  0.072186  0.063298
# Effusion            0.495286  0.514138  0.482054  0.521289  0.520569
# Pneumonia           0.060512  0.061608  0.076980  0.086957  0.079295
# Pleural_Thickening  0.177433  0.165751  0.169416  0.155963  0.191120
# Cardiomegaly        0.328032  0.373689  0.310933  0.362123  0.412289
# Nodule              0.155206  0.155908  0.145118  0.162255  0.154990
# ...
