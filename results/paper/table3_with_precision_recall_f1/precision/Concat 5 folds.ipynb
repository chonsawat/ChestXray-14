# %%
import pandas as pd

# %%
df_list = []
for i in range(1, 6):
    filename = "best_model_fold_{}.csv".format(i)
    df = pd.read_csv(filename)
    df_list.append(df)

# %%
df_tmp = pd.concat(df_list).T
df_tmp.columns = [f"Fold {i+1}" for i in range(5)]
df_tmp.to_csv("best_model_5_folds.csv", index=True)
df_tmp
# Out:
#                       Fold 1    Fold 2    Fold 3    Fold 4    Fold 5
# No Finding          0.654894  0.656820  0.645472  0.651916  0.661624
# Atelectasis         0.246684  0.246999  0.248230  0.254744  0.271375
# Consolidation       0.126294  0.141228  0.136425  0.140014  0.141638
# Infiltration        0.295949  0.299047  0.296894  0.309425  0.308585
# Pneumothorax        0.210688  0.217038  0.197594  0.215131  0.219576
# Edema               0.160563  0.142986  0.158182  0.179024  0.166667
# Emphysema           0.092830  0.089666  0.104603  0.106287  0.111371
# Fibrosis            0.034315  0.035323  0.036684  0.038769  0.033590
# Effusion            0.421503  0.440709  0.409784  0.442665  0.436975
# Pneumonia           0.039196  0.039197  0.048417  0.054808  0.051040
# Pleural_Thickening  0.124171  0.115634  0.121096  0.109549  0.134684
# Cardiomegaly        0.367483  0.428884  0.367299  0.399083  0.431535
# Nodule              0.090079  0.090400  0.083831  0.094084  0.089317
# Mass                0.162132  0.159478  0.157110  0.158216  0.183145
# Hernia              0.009043  0.010171  0.009615  0.009569  0.008475
