# %%
import pandas as pd

# %%
df_list = []
for i in range(1, 6):
    filename = "best_model_fold_{}.csv".format(i)
    df = pd.read_csv(filename)
    df_list.append(df)

# %%
df_tmp = pd.concat(df_list).T
df_tmp.columns = [f"Fold {i+1}" for i in range(5)]
df_tmp.to_csv("best_model_5_folds.csv", index=True)
df_tmp
# Out:
#                       Fold 1    Fold 2    Fold 3    Fold 4    Fold 5
# No Finding          0.879852  0.882724  0.868779  0.881792  0.889164
# Atelectasis         0.560000  0.539553  0.540934  0.570631  0.591219
# Consolidation       0.409396  0.434917  0.437500  0.442037  0.435011
# Infiltration        0.543660  0.573083  0.552829  0.568873  0.573939
# Pneumothorax        0.459847  0.472507  0.396104  0.476592  0.488910
# Edema               0.383408  0.354911  0.372591  0.427646  0.388309
# Emphysema           0.252567  0.236473  0.250501  0.275194  0.277670
# Fibrosis            0.529781  0.507289  0.517143  0.522911  0.547855
# Effusion            0.600381  0.616928  0.585274  0.633876  0.643714
# Pneumonia           0.132653  0.143860  0.187726  0.210332  0.177632
# Pleural_Thickening  0.310709  0.292537  0.281899  0.270622  0.328967
# Cardiomegaly        0.296230  0.331081  0.269565  0.331429  0.394687
# Nodule              0.560311  0.566199  0.539632  0.589105  0.585505
# ...
