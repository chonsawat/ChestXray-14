# %%
# %cd ~/ChestXray-14/
# Out:
# /home/jovyan/ChestXray-14

# %%
"""
Chonsawat Path: input_path = "/content/drive/MyDrive/KKU /Project/Dataset/ChestXray NIH"
Deepnote Path: input_path = "/datasets/chonsawat-drive/KKU /Project/Dataset/ChestXray NIH"
Elab Path: input_path = "~/ChestXray-14/dataset/ChestXray NIH"
"""
input_path = "dataset/ChestXray NIH"

from sklearn.utils import shuffle
from tqdm.notebook import tqdm
import tensorflow as tf
import pandas as pd
import numpy as np
import os

import warnings
warnings.filterwarnings('ignore')

# %%
STRATEGY = tf.distribute.get_strategy()    
BATCH_SIZE = 16
IMG_SIZE = 224
SEED = 42
    
print('Using tensorflow %s' % tf.__version__)
# Out:
# Using tensorflow 2.6.2

# %%
feature_map = {
    'image': tf.io.FixedLenFeature([], tf.string),
    'image_id': tf.io.FixedLenFeature([], tf.string),
    'No Finding': tf.io.FixedLenFeature([], tf.int64),
    'Atelectasis': tf.io.FixedLenFeature([], tf.int64),
    'Consolidation': tf.io.FixedLenFeature([], tf.int64),
    'Infiltration': tf.io.FixedLenFeature([], tf.int64),
    'Pneumothorax': tf.io.FixedLenFeature([], tf.int64),
    'Edema': tf.io.FixedLenFeature([], tf.int64),
    'Emphysema': tf.io.FixedLenFeature([], tf.int64),
    'Fibrosis': tf.io.FixedLenFeature([], tf.int64),
    'Effusion': tf.io.FixedLenFeature([], tf.int64),
    'Pneumonia': tf.io.FixedLenFeature([], tf.int64),
    'Pleural_Thickening': tf.io.FixedLenFeature([], tf.int64),
    'Cardiomegaly': tf.io.FixedLenFeature([], tf.int64),
    'Nodule': tf.io.FixedLenFeature([], tf.int64),
    'Mass': tf.io.FixedLenFeature([], tf.int64),
    'Hernia': tf.io.FixedLenFeature([], tf.int64)}


def count_data_items(filenames):
    return np.sum([int(x[:-6].split('-')[-1]) for x in filenames])


def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=1)
    image = tf.reshape(image, [IMG_SIZE, IMG_SIZE, 1])
    return image


def scale_image(image, target):
    image = tf.cast(image, tf.float32) / 255.
    return image, target


def read_tfrecord(example):
    example = tf.io.parse_single_example(example, feature_map)
    image = decode_image(example['image'])
    target = [
        example['No Finding'],
        example['Atelectasis'],
        example['Consolidation'],
        example['Infiltration'],
        example['Pneumothorax'],
        example['Edema'],
        example['Emphysema'],
        example['Fibrosis'],
        example['Effusion'],
        example['Pneumonia'],
        example['Pleural_Thickening'],
        example['Cardiomegaly'],
        example['Nodule'],
        example['Mass'],
        example['Hernia']]
    return image, target


def data_augment(image, target):
    image = tf.image.random_flip_left_right(image, seed=SEED)
    image = tf.image.random_flip_up_down(image, seed=SEED)
    return image, target


def get_dataset(filenames, shuffled=False, repeated=False, 
                cached=False, augmented=False, distributed=True):
    auto = tf.data.experimental.AUTOTUNE
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=auto)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=auto)
    if augmented:
        dataset = dataset.map(data_augment, num_parallel_calls=auto)
    dataset = dataset.map(scale_image, num_parallel_calls=auto)
    if shuffled:
        dataset = dataset.shuffle(2048, seed=SEED)
    if repeated:
        dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    if cached:
        dataset = dataset.cache()
    dataset = dataset.prefetch(auto)
    if distributed:
        dataset = STRATEGY.experimental_distribute_dataset(dataset)
    return dataset


def get_model():
    model = tf.keras.models.Sequential([
        tf.keras.applications.EfficientNetB0(
            include_top=False,
            input_shape=(None, None, 1),
            weights=None,
            pooling='avg'),
        tf.keras.layers.Dense(15, activation='sigmoid')
    ])
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=tf.keras.metrics.AUC(multi_label=True))

    return model

# %%
filenames = tf.io.gfile.glob(f'{input_path}/data/224x224/*.tfrec')

train_filenames = [filenames[0]]
val_filenames = [filenames[1]]

get_dataset(val_filenames, shuffled=True, repeated=True, augmented=True)
# Out:
# <PrefetchDataset shapes: ((16, 224, 224, 1), (16, 15)), types: (tf.float32, tf.int64)>

# %%
filenames = tf.io.gfile.glob(f'{input_path}/data/224x224/*.tfrec')
filenames
# Out:
# ['dataset/ChestXray NIH/data/224x224/000-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/001-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/002-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/003-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/004-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/005-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/006-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/007-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/008-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/009-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/010-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/011-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/012-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/013-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/014-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/015-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/016-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/017-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/018-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/019-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/020-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/021-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/022-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/023-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/024-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/025-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/026-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/027-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/028-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/029-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/030-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/031-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/032-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/033-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/034-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/035-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/036-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/037-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/038-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/039-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/040-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/041-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/042-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/043-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/044-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/045-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/046-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/047-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/048-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/049-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/050-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/051-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/052-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/053-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/054-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/055-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/056-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/057-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/058-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/059-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/060-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/061-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/062-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/063-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/064-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/065-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/066-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/067-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/068-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/069-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/070-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/071-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/072-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/073-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/074-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/075-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/076-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/077-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/078-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/079-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/080-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/081-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/082-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/083-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/084-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/085-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/086-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/087-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/088-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/089-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/090-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/091-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/092-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/093-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/094-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/095-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/096-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/097-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/098-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/099-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/100-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/101-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/102-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/103-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/104-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/105-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/106-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/107-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/108-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/109-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/110-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/111-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/112-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/113-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/114-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/115-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/116-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/117-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/118-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/119-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/120-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/121-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/122-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/123-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/124-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/125-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/126-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/127-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/128-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/129-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/130-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/131-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/132-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/133-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/134-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/135-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/136-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/137-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/138-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/139-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/140-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/141-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/142-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/143-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/144-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/145-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/146-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/147-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/148-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/149-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/150-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/151-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/152-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/153-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/154-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/155-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/156-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/157-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/158-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/159-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/160-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/161-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/162-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/163-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/164-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/165-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/166-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/167-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/168-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/169-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/170-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/171-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/172-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/173-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/174-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/175-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/176-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/177-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/178-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/179-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/180-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/181-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/182-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/183-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/184-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/185-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/186-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/187-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/188-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/189-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/190-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/191-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/192-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/193-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/194-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/195-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/196-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/197-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/198-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/199-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/200-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/201-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/202-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/203-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/204-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/205-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/206-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/207-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/208-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/209-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/210-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/211-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/212-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/213-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/214-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/215-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/216-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/217-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/218-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/219-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/220-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/221-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/222-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/223-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/224-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/225-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/226-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/227-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/228-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/229-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/230-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/231-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/232-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/233-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/234-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/235-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/236-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/237-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/238-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/239-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/240-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/241-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/242-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/243-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/244-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/245-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/246-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/247-438.tfrec',
#  'dataset/ChestXray NIH/data/224x224/248-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/249-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/250-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/251-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/252-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/253-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/254-437.tfrec',
#  'dataset/ChestXray NIH/data/224x224/255-437.tfrec']

# %%
train_filenames = tf.io.gfile.glob(f'{input_path}/data/224x224/train/*.tfrec')
val_filenames = tf.io.gfile.glob(f'{input_path}/data/224x224/valid/*.tfrec')
test_filenames = tf.io.gfile.glob(f'{input_path}/data/224x224/test/*.tfrec')

steps_per_epoch = count_data_items(train_filenames) // BATCH_SIZE
validation_steps = count_data_items(val_filenames) // BATCH_SIZE

train_dataset = get_dataset(train_filenames, shuffled=True, repeated=True, augmented=True)
val_dataset = get_dataset(val_filenames, cached=True)

with STRATEGY.scope():
    model = get_model()
    
history = model.fit(
    train_dataset,
    steps_per_epoch=steps_per_epoch,
    epochs=2,
    validation_data=val_dataset,
    validation_steps=validation_steps,
    verbose=1)
# Out:
# 2022-03-29 15:49:32.231576: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-29 15:49:33.114378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8003 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:17:00.0, compute capability: 8.0
# Epoch 1/2
# 2022-03-29 15:49:38.459118: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-29 15:49:40.993691: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2022-03-29 15:49:41.935629: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-03-29 15:49:41.936703: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-03-29 15:49:41.936753: W tensorflow/stream_executor/gpu/asm_compiler.cc:77] Couldn't get ptxas version string: Internal: Couldn't invoke ptxas --version
# 2022-03-29 15:49:41.937793: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-03-29 15:49:41.937989: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-03-29 15:49:49.159266: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 27/27 [==============================] - 31s 225ms/step - loss: 0.3218 - auc: 0.4831 - val_loss: 0.4801 - val_auc: 0.4667
# Epoch 2/2
# 27/27 [==============================] - 4s 161ms/step - loss: 0.2329 - auc: 0.4863 - val_loss: 0.2754 - val_auc: 0.4667

# %%
model.save(f"{input_path}/models/EfficientNetB0.h5")
