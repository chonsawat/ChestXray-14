# %%
import tensorflow as tf
import datetime
# Out:
# 2023-04-09 20:16:20.836332: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# from modules.dataset import Dataset

# %%
import os

CURRENT_PATH = os.path.abspath("")
f"{CURRENT_PATH}/results/history/under_sampling_5_folds_with_cross_entropy_loss_with_model_under_sampling_dropout/EfficientNetB0_None_FOLD_1"
# Out:
# '/home/jovyan/ChestXray-14/experiments/Under_sampling-multilabel_classification/results/history/under_sampling_5_folds_with_cross_entropy_loss_with_model_under_sampling_dropout/EfficientNetB0_None_FOLD_1'

# %%
import pandas as pd
import matplotlib.pyplot as plt

FOLD_NUM = 5
for fold_num in range(1, FOLD_NUM + 1):
    # ChestXray-14/experiments/Under_sampling-multilabel_classification/results/history/under_sampling_5_folds_with_cross_entropy_loss_freeze_imagenet_model_3/EfficientNetB0_imagenet_FOLD_1
    history_path = f"{CURRENT_PATH}/results/history/under_sampling_5_folds_with_cross_entropy_loss_with_model_under_sampling_dropout/EfficientNetB0_None_FOLD_{fold_num}"
    file_name = f"{history_path}/history.csv"
    df = pd.read_csv(file_name)
    
    plt.title(f"EfficientNetB0_None cross_entropy_loss_with_model_dropout FOLD {fold_num}")
    plt.plot(df.loss, label="Training")
    plt.plot(df.val_loss, label="Validation")
    plt.legend()
    plt.show()
    # break
