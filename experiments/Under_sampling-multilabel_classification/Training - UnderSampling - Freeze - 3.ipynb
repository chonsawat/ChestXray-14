# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from typeguard>=2.7->tensorflow_addons) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
import sys
sys.path.append('/home/jovyan/ChestXray-14')

# %%
import tensorflow as tf

from modules.models import Model_with_dropout_freeze_model_3
from modules.utils import get_dataset

from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, TensorBoard
# Out:
# 2023-04-05 17:00:49.421643: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from modules.dataset import LABELS

# %%
ROOT_PATH = "/home/jovyan/ChestXray-14"
INPUT_PATH = f"{ROOT_PATH}/dataset/ChestXray NIH"
EXPERIMENT_NAME = "under_sampling_5_folds_with_cross_entropy_loss_freeze_imagenet_model_3"

# %%
class Dataset:
    INPUT_PATH = INPUT_PATH
    
    def __init__(self, fold_num):
        self.fold_num = fold_num
    
    def get_train(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/under_sampling_5_folds_dataset/folds/fold{self.fold_num}/train/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

    def get_test(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/under_sampling_5_folds_dataset/folds/fold{self.fold_num}/test/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

# %% [markdown]
# ## tf.keras.mixed_precision for faster training

# %%
print(tf.keras.mixed_precision.global_policy())
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
print(tf.keras.mixed_precision.global_policy())
# Out:
# <Policy "float32">
# <Policy "float32">

# %% [markdown]
# ## Model Training

# %%
import os
CURRENT_PATH = os.path.abspath("")
CURRENT_PATH
# Out:
# '/home/jovyan/ChestXray-14/experiments/Under_sampling-multilabel_classification'

# %%
# Learning rate
def lr_schedule(epoch, learning_rate):
    tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
    return learning_rate

# %%
import datetime

def get_callbacks(NAME, weight_option, fold_num):
    log_dir = f"{CURRENT_PATH}/logs/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    
    model_checkpoint_callback = ModelCheckpoint(f'results/models/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}.h5', monitor='val_loss', mode='min', save_best_only=True)
    early_stop_callback = EarlyStopping(monitor='val_loss', mode="min", patience=10, verbose=1)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.5, patience=3, verbose=1)
    lr_logging_callback = LearningRateScheduler(lr_schedule)
    
    return model_checkpoint_callback, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback

# %%
# Constant variables
NAME = "EfficientNetB0"
EPOCHS = 100

# %%
import pprint
import numpy as np

def check_label_on_dataset(train_dataset, test_dataset):
    y_list = []
    for x,y in train_dataset:
        # print(y)
        y_list.append(y)
    train_labels = np.vstack(y_list)

    y_list = []
    for x,y in test_dataset:
        # print(y)
        y_list.append(y)
    test_labels = np.vstack(y_list)

    # Print
    pprint.pprint(list(zip(LABELS,train_labels.sum(axis=0))))
    print("Count:", len(train_labels))
    pprint.pprint(list(zip(LABELS, test_labels.sum(axis=0))))
    print("Count: ", len(test_labels))

    print("All:", len(train_labels)+len(test_labels))

# %%
# TODO: Main
import time
from tqdm.notebook import tqdm

NUM_FOLDS = 5
weight_option = 'imagenet' # use `imagenet` or `None` only

# Fold [1, 3]
for fold_num in tqdm(range(1, NUM_FOLDS + 1)):
    
    # Callbacks
    (
        model_checkpoint_callback, 
        early_stop_callback, 
        reduce_lr_callback, 
        lr_logging_callback, 
        tensorboard_callback
    ) = get_callbacks(
        NAME, weight_option, fold_num
    )

    # Path for CSV
    path = os.path.join(CURRENT_PATH, "results", "history", EXPERIMENT_NAME, f"{NAME}_{weight_option}_FOLD_{fold_num}")
    os.makedirs(path, exist_ok=True)

    # CSV Logger
    csv_logger = CSVLogger(os.path.join(path, f"history.csv"))

    # Dataset
    dataset = Dataset(fold_num)
    train_dataset, test_dataset = dataset.get_train(), dataset.get_test()
    # check_label_on_dataset(train_dataset, test_dataset)

    # Modeling
    transfer_model = tf.keras.applications.efficientnet.EfficientNetB0(
        include_top=False, 
        weights=weight_option,
        input_shape=(224, 224, 3),
        pooling=None
    )
    transfer_model.trainable = False

    model = Model_with_dropout_freeze_model_3(
        transfer_model,
    )
    model = model.get_model()
    model._name = f"{EXPERIMENT_NAME}_FOLD_{fold_num}"
    model.summary()

    # Record time for training
    start = time.time()
    
    # Visualize
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=test_dataset,
        verbose=1, # Show Progress Bar while Traning
        callbacks=[model_checkpoint_callback, csv_logger, early_stop_callback, reduce_lr_callback, lr_logging_callback]
    )
    
    end = time.time()
    print(
        "===== " * 5,
        "Model Traninig for: {:.2f} second(s)".format(end - start),
        "===== " * 5,
        "\n\n"
    )
    
    # break
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2023-04-05 17:00:52.574207: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 17:00:53.333526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8011 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:31:00.0, compute capability: 8.0
# Model: "under_sampling_5_folds_with_cross_entropy_loss_freeze_imagenet_model_3_FOLD_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 4,243,442
# Trainable params: 193,871
# Non-trainable params: 4,049,571
# _________________________________________________________________
# Epoch 1/100
# 2023-04-05 17:01:05.044419: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-04-05 17:01:05.948825: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-05 17:01:05.950563: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-05 17:01:05.950621: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-04-05 17:01:05.951833: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-05 17:01:05.951960: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#       1/Unknown - 10s 10s/step - loss: 0.7104 - auc: 0.3127 - f1_score: 0.0000e+00 - precision: 0.0988 - recall: 0.7273
# 2023-04-05 17:01:07.196717: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 3066/3066 [==============================] - 183s 56ms/step - loss: 0.2909 - auc: 0.4976 - f1_score: 0.0366 - precision: 0.1269 - recall: 0.0027 - val_loss: 0.2648 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2866 - auc: 0.4977 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2588 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2858 - auc: 0.4970 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2576 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2855 - auc: 0.5007 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2574 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 5/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2854 - auc: 0.5003 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2573 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 6/100
# 3066/3066 [==============================] - 168s 55ms/step - loss: 0.2853 - auc: 0.4995 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2574 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 7/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2853 - auc: 0.4984 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2853 - auc: 0.4984 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2574 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 8/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2852 - auc: 0.4981 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2570 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 9/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2852 - auc: 0.4982 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2570 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 10/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2852 - auc: 0.4982 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2570 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 11/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2852 - auc: 0.4982 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2852 - auc: 0.4982 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2570 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 12/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2851 - auc: 0.4987 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2565 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 13/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4981 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2565 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 14/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4981 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2565 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 15/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2851 - auc: 0.4979 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2851 - auc: 0.4979 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2565 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 16/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4979 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2562 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 17/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4978 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2562 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 18/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4978 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2562 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 19/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2851 - auc: 0.4976 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4976 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2562 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 20/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2851 - auc: 0.4985 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2560 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 21/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2851 - auc: 0.4982 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2560 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 22/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2851 - auc: 0.4986 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2560 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 23/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2851 - auc: 0.4984 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2851 - auc: 0.4984 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2560 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 24/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4985 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2558 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 25/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4988 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2557 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 26/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4991 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2557 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 27/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2851 - auc: 0.4991 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4991 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2557 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 28/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4993 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2557 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 29/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4992 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 30/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4991 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 31/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2851 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 32/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 33/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 34/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 35/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2556 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 36/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 37/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2850 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3066/3066 [==============================] - 170s 56ms/step - loss: 0.2850 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.9063e-06
# Epoch 38/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4987 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.9063e-06
# Epoch 39/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.9063e-06
# Epoch 40/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9531e-06
# Epoch 41/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9531e-06
# Epoch 42/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4993 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9531e-06
# Epoch 43/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3066/3066 [==============================] - 171s 56ms/step - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 44/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4995 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 45/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4996 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 46/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.4996 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4996 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 4.8828e-07
# Epoch 47/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 4.8828e-07
# Epoch 48/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 4.8828e-07
# Epoch 49/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4994 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.4414e-07
# Epoch 50/100
# 3066/3066 [==============================] - 171s 56ms/step - loss: 0.2850 - auc: 0.4993 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.4414e-07
# Epoch 51/100
# 3066/3066 [==============================] - 171s 56ms/step - loss: 0.2850 - auc: 0.4993 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.4414e-07
# Epoch 52/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2207e-07
# Epoch 53/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2207e-07
# Epoch 54/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2207e-07
# Epoch 55/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.4995 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4995 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.1035e-08
# Epoch 56/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.1035e-08
# Epoch 57/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.1035e-08
# Epoch 58/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2850 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0518e-08
# Epoch 59/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0518e-08
# Epoch 60/100
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.2850 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0518e-08
# Epoch 61/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 3066/3066 [==============================] - 170s 56ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5259e-08
# Epoch 62/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5259e-08
# Epoch 63/100
# 3066/3066 [==============================] - 171s 56ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5259e-08
# Epoch 64/100
# 3065/3066 [============================>.] - ETA: 0s - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 64: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.6294e-09
# Epoch 65/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.6294e-09
# Epoch 66/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.6294e-09
# Epoch 67/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 67: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.8147e-09
# Epoch 68/100
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.8147e-09
# Epoch 69/100
# 3066/3066 [==============================] - 170s 56ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.8147e-09
# Epoch 70/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 3066/3066 [==============================] - 170s 55ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9073e-09
# Epoch 71/100
# 3066/3066 [==============================] - 170s 56ms/step - loss: 0.2850 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2555 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9073e-09
# Epoch 71: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 12072.04 second(s) ===== ===== ===== ===== =====
#
#
# Model: "under_sampling_5_folds_with_cross_entropy_loss_freeze_imagenet_model_3_FOLD_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 128)               163968
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 4,243,442
# Trainable params: 193,871
# Non-trainable params: 4,049,571
# _________________________________________________________________
# Epoch 1/100
# 3058/3058 [==============================] - 177s 56ms/step - loss: 0.2899 - auc_1: 0.5001 - f1_score: 0.0368 - precision_1: 0.1695 - recall_1: 0.0025 - val_loss: 0.2637 - val_auc_1: 0.5004 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2858 - auc_1: 0.4984 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2592 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2850 - auc_1: 0.4996 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2595 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2849 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2589 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 5/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_1: 0.4994 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2584 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 6/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2847 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2583 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 7/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2847 - auc_1: 0.4996 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2584 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 8/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2847 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2847 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2584 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 5.0000e-04
# Epoch 9/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4996 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2582 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 5.0000e-04
# Epoch 10/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2582 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 5.0000e-04
# Epoch 11/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2582 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 5.0000e-04
# Epoch 12/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2846 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2846 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2582 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 2.5000e-04
# Epoch 13/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2579 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 2.5000e-04
# Epoch 14/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4989 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2579 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 2.5000e-04
# Epoch 15/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2579 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 2.5000e-04
# Epoch 16/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2846 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2846 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2579 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.2500e-04
# Epoch 17/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2845 - auc_1: 0.4987 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2578 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.2500e-04
# Epoch 18/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4988 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2577 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.2500e-04
# Epoch 19/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4988 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2577 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.2500e-04
# Epoch 20/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2845 - auc_1: 0.4988 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2845 - auc_1: 0.4988 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2578 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 6.2500e-05
# Epoch 21/100
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.4987 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2575 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 6.2500e-05
# Epoch 22/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4984 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2575 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 6.2500e-05
# Epoch 23/100
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.4984 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2575 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 6.2500e-05
# Epoch 24/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2845 - auc_1: 0.4985 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2845 - auc_1: 0.4985 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2575 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.1250e-05
# Epoch 25/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4987 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2573 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.1250e-05
# Epoch 26/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2572 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.1250e-05
# Epoch 27/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4992 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2572 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.1250e-05
# Epoch 28/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2845 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2845 - auc_1: 0.4990 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2572 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.5625e-05
# Epoch 29/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4996 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2571 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.5625e-05
# Epoch 30/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4992 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2571 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.5625e-05
# Epoch 31/100
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.4991 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2571 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.5625e-05
# Epoch 32/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2845 - auc_1: 0.4991 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.4991 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2571 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 7.8125e-06
# Epoch 33/100
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 7.8125e-06
# Epoch 34/100
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.4999 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 7.8125e-06
# Epoch 35/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 7.8125e-06
# Epoch 36/100
# 3058/3058 [==============================] - 169s 55ms/step - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 7.8125e-06
# Epoch 37/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3058/3058 [==============================] - 171s 56ms/step - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.9063e-06
# Epoch 38/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.9063e-06
# Epoch 39/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.4997 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 3.9063e-06
# Epoch 40/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3058/3058 [==============================] - 171s 56ms/step - loss: 0.2845 - auc_1: 0.4998 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2570 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.9531e-06
# Epoch 41/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.9531e-06
# Epoch 42/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 1.9531e-06
# Epoch 43/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 9.7656e-07
# Epoch 44/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 9.7656e-07
# Epoch 45/100
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 9.7656e-07
# Epoch 46/100
# 3057/3058 [============================>.] - ETA: 0s - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3058/3058 [==============================] - 170s 56ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 4.8828e-07
# Epoch 47/100
# 3058/3058 [==============================] - 170s 55ms/step - loss: 0.2845 - auc_1: 0.5000 - f1_score: 0.0329 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.2569 - val_auc_1: 0.5000 - val_f1_score: 0.0197 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 4.8828e-07
# Epoch 48/100
# ...
# Epoch 28/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.4997 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.4997 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2563 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 7.8125e-06
# Epoch 29/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.4995 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2563 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 7.8125e-06
# Epoch 30/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.4998 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2563 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 7.8125e-06
# Epoch 31/100
# 3061/3062 [============================>.] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2563 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.9063e-06
# Epoch 32/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2563 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.9063e-06
# Epoch 33/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.9063e-06
# Epoch 34/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.9063e-06
# Epoch 35/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.9063e-06
# Epoch 36/100
# 3061/3062 [============================>.] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.9531e-06
# Epoch 37/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.9531e-06
# Epoch 38/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.9531e-06
# Epoch 39/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 39: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3062/3062 [==============================] - 172s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 9.7656e-07
# Epoch 40/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 9.7656e-07
# Epoch 41/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 9.7656e-07
# Epoch 42/100
# 3061/3062 [============================>.] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 4.8828e-07
# Epoch 43/100
# 3062/3062 [==============================] - 170s 55ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 4.8828e-07
# Epoch 44/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 4.8828e-07
# Epoch 45/100
# 3061/3062 [============================>.] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 2.4414e-07
# Epoch 46/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 2.4414e-07
# Epoch 47/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 2.4414e-07
# Epoch 48/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.2207e-07
# Epoch 49/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.2207e-07
# Epoch 50/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.2207e-07
# Epoch 51/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 3062/3062 [==============================] - 172s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 6.1035e-08
# Epoch 52/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 6.1035e-08
# Epoch 53/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 6.1035e-08
# Epoch 54/100
# 3061/3062 [============================>.] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 3062/3062 [==============================] - 170s 55ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.0518e-08
# Epoch 55/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.0518e-08
# Epoch 56/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.0518e-08
# Epoch 57/100
# 3061/3062 [============================>.] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 3062/3062 [==============================] - 170s 55ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.5259e-08
# Epoch 58/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.5259e-08
# Epoch 59/100
# 3062/3062 [==============================] - 170s 55ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.5259e-08
# Epoch 60/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 60: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 7.6294e-09
# Epoch 61/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 7.6294e-09
# Epoch 62/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 7.6294e-09
# Epoch 63/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.8147e-09
# Epoch 64/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.8147e-09
# Epoch 65/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 3.8147e-09
# Epoch 66/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 3062/3062 [==============================] - 172s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.9073e-09
# Epoch 67/100
# 3062/3062 [==============================] - 171s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.9073e-09
# Epoch 68/100
# 3062/3062 [==============================] - 170s 56ms/step - loss: 0.2848 - auc_4: 0.5000 - f1_score: 0.0327 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 0.2562 - val_auc_4: 0.5000 - val_f1_score: 0.0201 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 1.9073e-09
# Epoch 68: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 11627.83 second(s) ===== ===== ===== ===== =====

# %%
print("Done")
# Out:
# Done
