# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from typeguard>=2.7->tensorflow_addons) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
import sys
sys.path.append('/home/jovyan/ChestXray-14')

# %%
import tensorflow as tf

from modules.models import Model
from modules.utils import get_dataset

from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, TensorBoard
# Out:
# 2023-04-01 13:46:19.047127: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from modules.dataset import LABELS

# %%
ROOT_PATH = "/home/jovyan/ChestXray-14"
INPUT_PATH = f"{ROOT_PATH}/dataset/ChestXray NIH"
EXPERIMENT_NAME = "under_sampling_5_folds_with_facal_loss"

# %%
class Dataset:
    INPUT_PATH = INPUT_PATH
    
    def __init__(self, fold_num):
        self.fold_num = fold_num
    
    def get_train(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/under_sampling_5_folds_dataset/folds/fold{self.fold_num}/train/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

    def get_test(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/under_sampling_5_folds_dataset/folds/fold{self.fold_num}/test/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

# %% [markdown]
# ## tf.keras.mixed_precision for faster training

# %%
print(tf.keras.mixed_precision.global_policy())
tf.keras.mixed_precision.set_global_policy('mixed_float16')
print(tf.keras.mixed_precision.global_policy())
# Out:
# <Policy "float32">
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA A100-SXM4-40GB MIG 2g.10gb, compute capability 8.0
# <Policy "mixed_float16">

# %% [markdown]
# ## Model Training

# %%
import os
CURRENT_PATH = os.path.abspath("")
CURRENT_PATH
# Out:
# '/home/jovyan/ChestXray-14/experiments/Under_sampling-multilabel_classification'

# %%
# Learning rate
def lr_schedule(epoch, learning_rate):
    tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
    return learning_rate

# %%
import datetime

def get_callbacks(NAME, weight_option, fold_num):
    log_dir = f"{CURRENT_PATH}/logs/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    
    model_checkpoint_callback = ModelCheckpoint(f'results/models/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}.h5', monitor='val_loss', mode='min', save_best_only=True)
    early_stop_callback = EarlyStopping(monitor='val_loss', mode="min", patience=20, verbose=1)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.5, patience=3, verbose=1)
    lr_logging_callback = LearningRateScheduler(lr_schedule)
    
    return model_checkpoint_callback, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback

# %%
# Constant variables
NAME = "EfficientNetB0"
EPOCHS = 100
weight_option = None # use `imagenet` or `None` only

# %%
import pprint
import numpy as np

def check_label_on_dataset(train_dataset, test_dataset):
    y_list = []
    for x,y in train_dataset:
        # print(y)
        y_list.append(y)
    train_labels = np.vstack(y_list)

    y_list = []
    for x,y in test_dataset:
        # print(y)
        y_list.append(y)
    test_labels = np.vstack(y_list)

    # Print
    pprint.pprint(list(zip(LABELS,train_labels.sum(axis=0))))
    print("Count:", len(train_labels))
    pprint.pprint(list(zip(LABELS, test_labels.sum(axis=0))))
    print("Count: ", len(test_labels))

    print("All:", len(train_labels)+len(test_labels))

# %%
# TODO: Main
import time
from tqdm.notebook import tqdm

NUM_FOLDS = 5
for fold_num in tqdm(range(1, NUM_FOLDS + 1)):
    
    # Callbacks
    (
        model_checkpoint_callback, 
        early_stop_callback, 
        reduce_lr_callback, 
        lr_logging_callback, 
        tensorboard_callback
    ) = get_callbacks(
        NAME, weight_option, fold_num
    )

    # Path for CSV
    path = os.path.join(CURRENT_PATH, "results", "history", EXPERIMENT_NAME, f"{NAME}_{weight_option}_FOLD_{fold_num}")
    os.makedirs(path, exist_ok=True)

    # CSV Logger
    csv_logger = CSVLogger(os.path.join(path, f"history.csv"))

    # Dataset
    dataset = Dataset(fold_num)
    train_dataset, test_dataset = dataset.get_train(), dataset.get_test()
    check_label_on_dataset(train_dataset, test_dataset)

    # Modeling
    transfer_model = tf.keras.applications.efficientnet.EfficientNetB0(
        include_top=False, 
        weights=weight_option,
        input_shape=(224, 224, 3),
        pooling=None
    )

    model = Model(
        transfer_model,
    )
    model.loss = tf.keras.losses.BinaryFocalCrossentropy(
        from_logits=False,
    )
    model = model.get_model()
    model._name = f"{EXPERIMENT_NAME}_FOLD_{fold_num}"
    model.summary()

    # Record time for training
    start = time.time()
    
    # Visualize
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=test_dataset,
        verbose=1, # Show Progress Bar while Traning
        callbacks=[model_checkpoint_callback, csv_logger, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback]
    )
    
    end = time.time()
    print(
        "===== " * 5,
        "Model Traninig for: {:.2f} second(s)".format(end - start),
        "===== " * 5,
        "\n\n"
    )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2023-04-01 13:46:22.579855: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-01 13:46:23.340312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8011 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:b1:00.0, compute capability: 8.0
# [('No Finding', 7560),
#  ('Atelectasis', 9334),
#  ('Consolidation', 3773),
#  ('Infiltration', 15943),
#  ('Pneumothorax', 4256),
#  ('Edema', 1857),
#  ('Emphysema', 2029),
#  ('Fibrosis', 1367),
#  ('Effusion', 10692),
#  ('Pneumonia', 1137),
#  ('Pleural_Thickening', 2722),
#  ('Cardiomegaly', 2219),
#  ('Nodule', 5046),
#  ('Mass', 4641),
#  ('Hernia', 181)]
# Count: 49055
# [('No Finding', 12160),
#  ('Atelectasis', 2225),
#  ('Consolidation', 894),
#  ('Infiltration', 3951),
#  ('Pneumothorax', 1046),
#  ('Edema', 446),
#  ('Emphysema', 487),
#  ('Fibrosis', 319),
#  ('Effusion', 2625),
#  ('Pneumonia', 294),
#  ('Pleural_Thickening', 663),
#  ('Cardiomegaly', 557),
#  ('Nodule', 1285),
#  ('Mass', 1141),
#  ('Hernia', 46)]
# Count:  22424
# All: 71479
# Model: "under_sampling_5_folds_with_facal_loss_FOLD_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 128)               8028288
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 2023-04-01 13:47:00.433385: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-04-01 13:47:01.352076: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-01 13:47:01.353379: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-01 13:47:01.353435: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-04-01 13:47:01.354889: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-01 13:47:01.355005: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 3066/3066 [==============================] - 375s 117ms/step - loss: 0.0774 - auc: 0.5655 - f1_score: 0.0574 - precision: 0.2663 - recall: 0.0100 - val_loss: 0.0689 - val_auc: 0.6328 - val_f1_score: 0.0424 - val_precision: 0.3309 - val_recall: 0.0194 - lr: 0.0010
# Epoch 2/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0745 - auc: 0.6125 - f1_score: 0.0698 - precision: 0.4590 - recall: 0.0093 - val_loss: 0.1417 - val_auc: 0.6217 - val_f1_score: 0.0496 - val_precision: 0.1509 - val_recall: 0.0112 - lr: 0.0010
# Epoch 3/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0764 - auc: 0.5395 - f1_score: 0.0472 - precision: 0.4080 - recall: 0.0023 - val_loss: 0.0693 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4978 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4978 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0693 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 5/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.0766 - auc: 0.4969 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0693 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 6/100
# 3066/3066 [==============================] - 354s 115ms/step - loss: 0.0766 - auc: 0.4973 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0693 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 5.0000e-04
# Epoch 7/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4977 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3066/3066 [==============================] - 354s 116ms/step - loss: 0.0766 - auc: 0.4977 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0693 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 8/100
# 3066/3066 [==============================] - 354s 116ms/step - loss: 0.0766 - auc: 0.4968 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0691 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 9/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.0766 - auc: 0.4970 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0691 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.5000e-04
# Epoch 10/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4965 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3066/3066 [==============================] - 353s 115ms/step - loss: 0.0766 - auc: 0.4965 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0692 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 11/100
# 3066/3066 [==============================] - 360s 117ms/step - loss: 0.0766 - auc: 0.4960 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0690 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 12/100
# 3066/3066 [==============================] - 371s 121ms/step - loss: 0.0766 - auc: 0.4965 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0690 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2500e-04
# Epoch 13/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4970 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.0766 - auc: 0.4970 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0690 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 14/100
# 3066/3066 [==============================] - 360s 118ms/step - loss: 0.0766 - auc: 0.4969 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0690 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 15/100
# 3066/3066 [==============================] - 360s 117ms/step - loss: 0.0766 - auc: 0.4971 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0690 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.2500e-05
# Epoch 16/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4987 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3066/3066 [==============================] - 361s 118ms/step - loss: 0.0766 - auc: 0.4987 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0690 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 17/100
# 3066/3066 [==============================] - 362s 118ms/step - loss: 0.0766 - auc: 0.4983 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 18/100
# 3066/3066 [==============================] - 361s 118ms/step - loss: 0.0766 - auc: 0.4989 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.1250e-05
# Epoch 19/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3066/3066 [==============================] - 362s 118ms/step - loss: 0.0766 - auc: 0.4990 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 20/100
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.0766 - auc: 0.4992 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 21/100
# 3066/3066 [==============================] - 360s 117ms/step - loss: 0.0766 - auc: 0.4992 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5625e-05
# Epoch 22/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4993 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.0766 - auc: 0.4993 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 23/100
# 3066/3066 [==============================] - 357s 117ms/step - loss: 0.0766 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 24/100
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.0766 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 7.8125e-06
# Epoch 25/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.9063e-06
# Epoch 26/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.9063e-06
# Epoch 27/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.9063e-06
# Epoch 28/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4997 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0689 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9531e-06
# Epoch 29/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9531e-06
# Epoch 30/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.0766 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.9531e-06
# Epoch 31/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 32/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.0766 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 33/100
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 34/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 35/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 9.7656e-07
# Epoch 36/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.4998 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 4.8828e-07
# Epoch 37/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 4.8828e-07
# Epoch 38/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 4.8828e-07
# Epoch 39/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 3066/3066 [==============================] - 358s 117ms/step - loss: 0.0766 - auc: 0.4999 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.4414e-07
# Epoch 40/100
# 3066/3066 [==============================] - 360s 117ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.4414e-07
# Epoch 41/100
# 3066/3066 [==============================] - 360s 117ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 2.4414e-07
# Epoch 42/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2207e-07
# Epoch 43/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2207e-07
# Epoch 44/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.2207e-07
# Epoch 45/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.1035e-08
# Epoch 46/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.1035e-08
# Epoch 47/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 6.1035e-08
# Epoch 48/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0518e-08
# Epoch 49/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0518e-08
# Epoch 50/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0518e-08
# Epoch 51/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5259e-08
# Epoch 52/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5259e-08
# Epoch 53/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.0766 - auc: 0.5000 - f1_score: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0688 - val_auc: 0.5000 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.5259e-08
# Epoch 53: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 18967.49 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7547),
#  ('Atelectasis', 9233),
#  ('Consolidation', 3699),
#  ('Infiltration', 16008),
#  ('Pneumothorax', 4229),
#  ('Edema', 1855),
#  ('Emphysema', 2017),
#  ('Fibrosis', 1343),
#  ('Effusion', 10576),
#  ('Pneumonia', 1146),
#  ('Pleural_Thickening', 2715),
#  ('Cardiomegaly', 2184),
#  ('Nodule', 5047),
#  ('Mass', 4643),
#  ('Hernia', 180)]
# Count: 48922
# [('No Finding', 12040),
#  ('Atelectasis', 2326),
#  ('Consolidation', 968),
#  ('Infiltration', 3886),
#  ('Pneumothorax', 1073),
#  ('Edema', 448),
#  ('Emphysema', 499),
#  ('Fibrosis', 343),
#  ('Effusion', 2741),
#  ('Pneumonia', 285),
#  ('Pleural_Thickening', 670),
#  ('Cardiomegaly', 592),
#  ('Nodule', 1284),
#  ('Mass', 1139),
#  ('Hernia', 47)]
# Count:  22424
# All: 71346
# Model: "under_sampling_5_folds_with_facal_loss_FOLD_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_1 (Flatten)         (None, 62720)             0
#
#  dense_5 (Dense)             (None, 128)               8028288
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 3058/3058 [==============================] - 373s 118ms/step - loss: 0.0776 - auc_1: 0.5428 - f1_score: 0.0450 - precision_1: 0.2174 - recall_1: 0.0040 - val_loss: 0.0662 - val_auc_1: 0.6053 - val_f1_score: 0.0197 - val_precision_1: 0.5000 - val_recall_1: 1.0585e-04 - lr: 0.0010
# Epoch 2/100
# 2998/3058 [============================>.] - ETA: 6s - loss: 0.0751 - auc_1: 0.5885 - f1_score: 0.0502 - precision_1: 0.4620 - recall_1: 0.0035
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 3058/3058 [==============================] - 356s 117ms/step - loss: 0.0747 - auc_1: 0.5985 - f1_score: 0.0646 - precision_1: 0.5025 - recall_1: 0.0084 - val_loss: 0.0623 - val_auc_1: 0.6588 - val_f1_score: 0.0846 - val_precision_1: 0.3668 - val_recall_1: 0.0146 - lr: 0.0010
# Epoch 4/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0736 - auc_1: 0.6248 - f1_score: 0.0778 - precision_1: 0.5096 - recall_1: 0.0172 - val_loss: 0.0641 - val_auc_1: 0.6592 - val_f1_score: 0.0646 - val_precision_1: 0.3287 - val_recall_1: 0.0033 - lr: 0.0010
# Epoch 5/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0730 - auc_1: 0.6424 - f1_score: 0.0836 - precision_1: 0.5251 - recall_1: 0.0267 - val_loss: 0.0637 - val_auc_1: 0.6765 - val_f1_score: 0.0938 - val_precision_1: 0.4108 - val_recall_1: 0.0191 - lr: 0.0010
# Epoch 6/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0728 - auc_1: 0.6495 - f1_score: 0.0872 - precision_1: 0.5139 - recall_1: 0.0289
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3058/3058 [==============================] - 356s 117ms/step - loss: 0.0728 - auc_1: 0.6495 - f1_score: 0.0872 - precision_1: 0.5139 - recall_1: 0.0289 - val_loss: 0.0644 - val_auc_1: 0.6875 - val_f1_score: 0.0699 - val_precision_1: 0.3505 - val_recall_1: 0.0206 - lr: 5.0000e-04
# Epoch 7/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0720 - auc_1: 0.6681 - f1_score: 0.0939 - precision_1: 0.5442 - recall_1: 0.0375 - val_loss: 0.0640 - val_auc_1: 0.7023 - val_f1_score: 0.0722 - val_precision_1: 0.4195 - val_recall_1: 0.0262 - lr: 5.0000e-04
# Epoch 8/100
# 3058/3058 [==============================] - 355s 116ms/step - loss: 0.0718 - auc_1: 0.6760 - f1_score: 0.0947 - precision_1: 0.5548 - recall_1: 0.0402 - val_loss: 0.0647 - val_auc_1: 0.7025 - val_f1_score: 0.0740 - val_precision_1: 0.4183 - val_recall_1: 0.0296 - lr: 5.0000e-04
# Epoch 9/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0712 - auc_1: 0.6860 - f1_score: 0.1000 - precision_1: 0.5580 - recall_1: 0.0491
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0712 - auc_1: 0.6860 - f1_score: 0.1000 - precision_1: 0.5580 - recall_1: 0.0491 - val_loss: 0.0635 - val_auc_1: 0.7104 - val_f1_score: 0.0774 - val_precision_1: 0.4160 - val_recall_1: 0.0349 - lr: 2.5000e-04
# Epoch 10/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0706 - auc_1: 0.6988 - f1_score: 0.1101 - precision_1: 0.5630 - recall_1: 0.0565 - val_loss: 0.0629 - val_auc_1: 0.7140 - val_f1_score: 0.0890 - val_precision_1: 0.4340 - val_recall_1: 0.0381 - lr: 2.5000e-04
# Epoch 11/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0706 - auc_1: 0.6976 - f1_score: 0.1149 - precision_1: 0.5589 - recall_1: 0.0519 - val_loss: 0.0629 - val_auc_1: 0.7133 - val_f1_score: 0.0955 - val_precision_1: 0.4183 - val_recall_1: 0.0368 - lr: 2.5000e-04
# Epoch 12/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0705 - auc_1: 0.6988 - f1_score: 0.1192 - precision_1: 0.5631 - recall_1: 0.0572
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0705 - auc_1: 0.6988 - f1_score: 0.1192 - precision_1: 0.5631 - recall_1: 0.0572 - val_loss: 0.0627 - val_auc_1: 0.7152 - val_f1_score: 0.0957 - val_precision_1: 0.4133 - val_recall_1: 0.0395 - lr: 1.2500e-04
# Epoch 13/100
# 3058/3058 [==============================] - 355s 116ms/step - loss: 0.0703 - auc_1: 0.7024 - f1_score: 0.1204 - precision_1: 0.5611 - recall_1: 0.0582 - val_loss: 0.0625 - val_auc_1: 0.7187 - val_f1_score: 0.1021 - val_precision_1: 0.4158 - val_recall_1: 0.0426 - lr: 1.2500e-04
# Epoch 14/100
# 3058/3058 [==============================] - 355s 116ms/step - loss: 0.0702 - auc_1: 0.7048 - f1_score: 0.1234 - precision_1: 0.5599 - recall_1: 0.0592 - val_loss: 0.0627 - val_auc_1: 0.7194 - val_f1_score: 0.1023 - val_precision_1: 0.4123 - val_recall_1: 0.0444 - lr: 1.2500e-04
# Epoch 15/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0700 - auc_1: 0.7089 - f1_score: 0.1252 - precision_1: 0.5582 - recall_1: 0.0606
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0700 - auc_1: 0.7089 - f1_score: 0.1252 - precision_1: 0.5582 - recall_1: 0.0606 - val_loss: 0.0625 - val_auc_1: 0.7204 - val_f1_score: 0.1051 - val_precision_1: 0.4171 - val_recall_1: 0.0452 - lr: 6.2500e-05
# Epoch 16/100
# 3058/3058 [==============================] - 358s 117ms/step - loss: 0.0698 - auc_1: 0.7133 - f1_score: 0.1292 - precision_1: 0.5693 - recall_1: 0.0640 - val_loss: 0.0621 - val_auc_1: 0.7223 - val_f1_score: 0.1106 - val_precision_1: 0.4205 - val_recall_1: 0.0487 - lr: 6.2500e-05
# Epoch 17/100
# 3058/3058 [==============================] - 355s 116ms/step - loss: 0.0696 - auc_1: 0.7160 - f1_score: 0.1307 - precision_1: 0.5702 - recall_1: 0.0668 - val_loss: 0.0624 - val_auc_1: 0.7219 - val_f1_score: 0.1087 - val_precision_1: 0.4160 - val_recall_1: 0.0480 - lr: 6.2500e-05
# Epoch 18/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0696 - auc_1: 0.7169 - f1_score: 0.1312 - precision_1: 0.5711 - recall_1: 0.0672 - val_loss: 0.0625 - val_auc_1: 0.7230 - val_f1_score: 0.1090 - val_precision_1: 0.4124 - val_recall_1: 0.0517 - lr: 6.2500e-05
# Epoch 19/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0694 - auc_1: 0.7187 - f1_score: 0.1322 - precision_1: 0.5737 - recall_1: 0.0683
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0694 - auc_1: 0.7187 - f1_score: 0.1322 - precision_1: 0.5737 - recall_1: 0.0683 - val_loss: 0.0620 - val_auc_1: 0.7245 - val_f1_score: 0.1115 - val_precision_1: 0.4177 - val_recall_1: 0.0507 - lr: 3.1250e-05
# Epoch 20/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0692 - auc_1: 0.7213 - f1_score: 0.1344 - precision_1: 0.5769 - recall_1: 0.0707 - val_loss: 0.0619 - val_auc_1: 0.7244 - val_f1_score: 0.1149 - val_precision_1: 0.4226 - val_recall_1: 0.0531 - lr: 3.1250e-05
# Epoch 21/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0693 - auc_1: 0.7204 - f1_score: 0.1346 - precision_1: 0.5747 - recall_1: 0.0706 - val_loss: 0.0620 - val_auc_1: 0.7230 - val_f1_score: 0.1149 - val_precision_1: 0.4177 - val_recall_1: 0.0522 - lr: 3.1250e-05
# Epoch 22/100
# 3058/3058 [==============================] - 356s 117ms/step - loss: 0.0692 - auc_1: 0.7220 - f1_score: 0.1356 - precision_1: 0.5784 - recall_1: 0.0720 - val_loss: 0.0619 - val_auc_1: 0.7246 - val_f1_score: 0.1140 - val_precision_1: 0.4195 - val_recall_1: 0.0564 - lr: 3.1250e-05
# Epoch 23/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0692 - auc_1: 0.7222 - f1_score: 0.1363 - precision_1: 0.5728 - recall_1: 0.0731
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0692 - auc_1: 0.7222 - f1_score: 0.1363 - precision_1: 0.5728 - recall_1: 0.0731 - val_loss: 0.0619 - val_auc_1: 0.7239 - val_f1_score: 0.1152 - val_precision_1: 0.4183 - val_recall_1: 0.0538 - lr: 1.5625e-05
# Epoch 24/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0691 - auc_1: 0.7240 - f1_score: 0.1376 - precision_1: 0.5745 - recall_1: 0.0727 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1163 - val_precision_1: 0.4263 - val_recall_1: 0.0541 - lr: 1.5625e-05
# Epoch 25/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0691 - auc_1: 0.7253 - f1_score: 0.1382 - precision_1: 0.5746 - recall_1: 0.0735 - val_loss: 0.0617 - val_auc_1: 0.7246 - val_f1_score: 0.1176 - val_precision_1: 0.4264 - val_recall_1: 0.0557 - lr: 1.5625e-05
# Epoch 26/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0691 - auc_1: 0.7238 - f1_score: 0.1380 - precision_1: 0.5789 - recall_1: 0.0751 - val_loss: 0.0617 - val_auc_1: 0.7240 - val_f1_score: 0.1180 - val_precision_1: 0.4256 - val_recall_1: 0.0547 - lr: 1.5625e-05
# Epoch 27/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0690 - auc_1: 0.7256 - f1_score: 0.1386 - precision_1: 0.5779 - recall_1: 0.0748 - val_loss: 0.0618 - val_auc_1: 0.7242 - val_f1_score: 0.1171 - val_precision_1: 0.4214 - val_recall_1: 0.0559 - lr: 1.5625e-05
# Epoch 28/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0690 - auc_1: 0.7254 - f1_score: 0.1386 - precision_1: 0.5774 - recall_1: 0.0757
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0690 - auc_1: 0.7254 - f1_score: 0.1386 - precision_1: 0.5774 - recall_1: 0.0757 - val_loss: 0.0618 - val_auc_1: 0.7244 - val_f1_score: 0.1175 - val_precision_1: 0.4265 - val_recall_1: 0.0572 - lr: 7.8125e-06
# Epoch 29/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0689 - auc_1: 0.7265 - f1_score: 0.1401 - precision_1: 0.5773 - recall_1: 0.0768 - val_loss: 0.0617 - val_auc_1: 0.7245 - val_f1_score: 0.1178 - val_precision_1: 0.4269 - val_recall_1: 0.0577 - lr: 7.8125e-06
# Epoch 30/100
# 3058/3058 [==============================] - 358s 117ms/step - loss: 0.0689 - auc_1: 0.7267 - f1_score: 0.1401 - precision_1: 0.5794 - recall_1: 0.0781 - val_loss: 0.0618 - val_auc_1: 0.7242 - val_f1_score: 0.1179 - val_precision_1: 0.4253 - val_recall_1: 0.0577 - lr: 7.8125e-06
# Epoch 31/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0689 - auc_1: 0.7272 - f1_score: 0.1404 - precision_1: 0.5789 - recall_1: 0.0770
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3058/3058 [==============================] - 358s 117ms/step - loss: 0.0689 - auc_1: 0.7272 - f1_score: 0.1404 - precision_1: 0.5789 - recall_1: 0.0770 - val_loss: 0.0618 - val_auc_1: 0.7244 - val_f1_score: 0.1178 - val_precision_1: 0.4276 - val_recall_1: 0.0565 - lr: 3.9063e-06
# Epoch 32/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0689 - auc_1: 0.7274 - f1_score: 0.1403 - precision_1: 0.5770 - recall_1: 0.0774 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1178 - val_precision_1: 0.4269 - val_recall_1: 0.0571 - lr: 3.9063e-06
# Epoch 33/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0689 - auc_1: 0.7275 - f1_score: 0.1392 - precision_1: 0.5784 - recall_1: 0.0764 - val_loss: 0.0617 - val_auc_1: 0.7244 - val_f1_score: 0.1179 - val_precision_1: 0.4278 - val_recall_1: 0.0572 - lr: 3.9063e-06
# Epoch 34/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0689 - auc_1: 0.7290 - f1_score: 0.1396 - precision_1: 0.5766 - recall_1: 0.0774
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0689 - auc_1: 0.7290 - f1_score: 0.1396 - precision_1: 0.5766 - recall_1: 0.0774 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1175 - val_precision_1: 0.4259 - val_recall_1: 0.0563 - lr: 1.9531e-06
# Epoch 35/100
# 3058/3058 [==============================] - 356s 117ms/step - loss: 0.0689 - auc_1: 0.7274 - f1_score: 0.1413 - precision_1: 0.5841 - recall_1: 0.0778 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1174 - val_precision_1: 0.4258 - val_recall_1: 0.0562 - lr: 1.9531e-06
# Epoch 36/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0689 - auc_1: 0.7268 - f1_score: 0.1404 - precision_1: 0.5816 - recall_1: 0.0780 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1177 - val_precision_1: 0.4239 - val_recall_1: 0.0570 - lr: 1.9531e-06
# Epoch 37/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0689 - auc_1: 0.7276 - f1_score: 0.1407 - precision_1: 0.5809 - recall_1: 0.0782
# Epoch 37: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0689 - auc_1: 0.7276 - f1_score: 0.1407 - precision_1: 0.5809 - recall_1: 0.0782 - val_loss: 0.0618 - val_auc_1: 0.7242 - val_f1_score: 0.1176 - val_precision_1: 0.4245 - val_recall_1: 0.0569 - lr: 9.7656e-07
# Epoch 38/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0689 - auc_1: 0.7274 - f1_score: 0.1412 - precision_1: 0.5818 - recall_1: 0.0784 - val_loss: 0.0618 - val_auc_1: 0.7242 - val_f1_score: 0.1177 - val_precision_1: 0.4264 - val_recall_1: 0.0559 - lr: 9.7656e-07
# Epoch 39/100
# 3058/3058 [==============================] - 356s 117ms/step - loss: 0.0688 - auc_1: 0.7284 - f1_score: 0.1410 - precision_1: 0.5813 - recall_1: 0.0776 - val_loss: 0.0618 - val_auc_1: 0.7244 - val_f1_score: 0.1178 - val_precision_1: 0.4259 - val_recall_1: 0.0575 - lr: 9.7656e-07
# Epoch 40/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0688 - auc_1: 0.7291 - f1_score: 0.1410 - precision_1: 0.5784 - recall_1: 0.0770
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0688 - auc_1: 0.7291 - f1_score: 0.1410 - precision_1: 0.5784 - recall_1: 0.0770 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1174 - val_precision_1: 0.4262 - val_recall_1: 0.0578 - lr: 4.8828e-07
# Epoch 41/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0688 - auc_1: 0.7283 - f1_score: 0.1413 - precision_1: 0.5770 - recall_1: 0.0787 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1178 - val_precision_1: 0.4265 - val_recall_1: 0.0578 - lr: 4.8828e-07
# Epoch 42/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0688 - auc_1: 0.7288 - f1_score: 0.1416 - precision_1: 0.5817 - recall_1: 0.0784 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1175 - val_precision_1: 0.4258 - val_recall_1: 0.0575 - lr: 4.8828e-07
# Epoch 43/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.0688 - auc_1: 0.7290 - f1_score: 0.1421 - precision_1: 0.5785 - recall_1: 0.0781
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0688 - auc_1: 0.7290 - f1_score: 0.1421 - precision_1: 0.5785 - recall_1: 0.0781 - val_loss: 0.0618 - val_auc_1: 0.7244 - val_f1_score: 0.1178 - val_precision_1: 0.4259 - val_recall_1: 0.0579 - lr: 2.4414e-07
# Epoch 44/100
# 3058/3058 [==============================] - 356s 116ms/step - loss: 0.0688 - auc_1: 0.7282 - f1_score: 0.1414 - precision_1: 0.5804 - recall_1: 0.0779 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1181 - val_precision_1: 0.4261 - val_recall_1: 0.0581 - lr: 2.4414e-07
# Epoch 45/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.0688 - auc_1: 0.7285 - f1_score: 0.1412 - precision_1: 0.5742 - recall_1: 0.0778 - val_loss: 0.0618 - val_auc_1: 0.7243 - val_f1_score: 0.1180 - val_precision_1: 0.4258 - val_recall_1: 0.0579 - lr: 2.4414e-07
# Epoch 45: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 16063.17 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7543),
#  ('Atelectasis', 9226),
#  ('Consolidation', 3739),
#  ('Infiltration', 15900),
#  ('Pneumothorax', 4224),
#  ('Edema', 1836),
#  ('Emphysema', 2017),
#  ('Fibrosis', 1336),
#  ('Effusion', 10655),
#  ('Pneumonia', 1154),
#  ('Pleural_Thickening', 2711),
#  ('Cardiomegaly', 2201),
#  ('Nodule', 5082),
#  ('Mass', 4641),
#  ('Hernia', 175)]
# Count: 48995
# [('No Finding', 12117),
#  ('Atelectasis', 2333),
#  ('Consolidation', 928),
#  ('Infiltration', 3994),
#  ('Pneumothorax', 1078),
#  ('Edema', 467),
#  ('Emphysema', 499),
#  ('Fibrosis', 350),
#  ('Effusion', 2662),
#  ('Pneumonia', 277),
#  ('Pleural_Thickening', 674),
#  ('Cardiomegaly', 575),
#  ('Nodule', 1249),
#  ('Mass', 1141),
#  ('Hernia', 52)]
# Count:  22424
# All: 71419
# Model: "under_sampling_5_folds_with_facal_loss_FOLD_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dense_10 (Dense)            (None, 128)               8028288
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 3063/3063 [==============================] - 373s 118ms/step - loss: 0.0782 - auc_2: 0.5457 - f1_score: 0.0510 - precision_2: 0.2000 - recall_2: 0.0057 - val_loss: 0.0654 - val_auc_2: 0.6459 - val_f1_score: 0.0203 - val_precision_2: 0.3788 - val_recall_2: 0.0039 - lr: 0.0010
# Epoch 2/100
# 3063/3063 [==============================] - 356s 116ms/step - loss: 0.0751 - auc_2: 0.5913 - f1_score: 0.0651 - precision_2: 0.4587 - recall_2: 0.0060 - val_loss: 0.0703 - val_auc_2: 0.5775 - val_f1_score: 0.0267 - val_precision_2: 0.1489 - val_recall_2: 2.4651e-04 - lr: 0.0010
# Epoch 3/100
# 3063/3063 [==============================] - 357s 116ms/step - loss: 0.0755 - auc_2: 0.5771 - f1_score: 0.0483 - precision_2: 0.2477 - recall_2: 3.7272e-04 - val_loss: 0.0670 - val_auc_2: 0.6345 - val_f1_score: 0.0293 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 3063/3063 [==============================] - 357s 116ms/step - loss: 0.0742 - auc_2: 0.6130 - f1_score: 0.0758 - precision_2: 0.5097 - recall_2: 0.0065 - val_loss: 0.0652 - val_auc_2: 0.6605 - val_f1_score: 0.0620 - val_precision_2: 0.4496 - val_recall_2: 0.0044 - lr: 0.0010
# Epoch 5/100
# 3063/3063 [==============================] - 356s 116ms/step - loss: 0.0744 - auc_2: 0.6067 - f1_score: 0.0736 - precision_2: 0.5069 - recall_2: 0.0131 - val_loss: 0.0699 - val_auc_2: 0.5001 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 6/100
# 3063/3063 [==============================] - 356s 116ms/step - loss: 0.0765 - auc_2: 0.4960 - f1_score: 0.0327 - precision_2: 0.2000 - recall_2: 1.3805e-05 - val_loss: 0.0698 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 7/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0765 - auc_2: 0.4959 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3063/3063 [==============================] - 356s 116ms/step - loss: 0.0765 - auc_2: 0.4959 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0698 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 5.0000e-04
# Epoch 8/100
# 3063/3063 [==============================] - 358s 117ms/step - loss: 0.0765 - auc_2: 0.4971 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0698 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 5.0000e-04
# Epoch 9/100
# 3063/3063 [==============================] - 356s 116ms/step - loss: 0.0764 - auc_2: 0.4972 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0698 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 5.0000e-04
# Epoch 10/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0764 - auc_2: 0.4969 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3063/3063 [==============================] - 357s 117ms/step - loss: 0.0764 - auc_2: 0.4969 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0698 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 2.5000e-04
# Epoch 11/100
# 3063/3063 [==============================] - 357s 117ms/step - loss: 0.0764 - auc_2: 0.4983 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0695 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 2.5000e-04
# Epoch 12/100
# 3063/3063 [==============================] - 357s 116ms/step - loss: 0.0764 - auc_2: 0.4981 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0695 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 2.5000e-04
# Epoch 13/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0764 - auc_2: 0.4978 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# ...
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3063/3063 [==============================] - 356s 116ms/step - loss: 0.0764 - auc_2: 0.4977 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0692 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 3.1250e-05
# Epoch 20/100
# 3063/3063 [==============================] - 354s 115ms/step - loss: 0.0764 - auc_2: 0.4979 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0692 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 3.1250e-05
# Epoch 21/100
# 3063/3063 [==============================] - 354s 115ms/step - loss: 0.0764 - auc_2: 0.4986 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0692 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 3.1250e-05
# Epoch 22/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0764 - auc_2: 0.4983 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3063/3063 [==============================] - 353s 115ms/step - loss: 0.0764 - auc_2: 0.4983 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0692 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 1.5625e-05
# Epoch 23/100
# 3063/3063 [==============================] - 352s 115ms/step - loss: 0.0764 - auc_2: 0.4994 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0692 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 1.5625e-05
# Epoch 24/100
# 3063/3063 [==============================] - 353s 115ms/step - loss: 0.0764 - auc_2: 0.4995 - f1_score: 0.0327 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.0692 - val_auc_2: 0.5000 - val_f1_score: 0.0202 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 1.5625e-05
# Epoch 24: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 8557.68 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7544),
#  ('Atelectasis', 9230),
#  ('Consolidation', 3744),
#  ('Infiltration', 15814),
#  ('Pneumothorax', 4234),
#  ('Edema', 1840),
#  ('Emphysema', 2000),
#  ('Fibrosis', 1315),
#  ('Effusion', 10613),
#  ('Pneumonia', 1160),
#  ('Pleural_Thickening', 2694),
#  ('Cardiomegaly', 2251),
#  ('Nodule', 5046),
#  ('Mass', 4609),
#  ('Hernia', 183)]
# Count: 48824
# [('No Finding', 11945),
#  ('Atelectasis', 2329),
#  ('Consolidation', 923),
#  ('Infiltration', 4080),
#  ('Pneumothorax', 1068),
#  ('Edema', 463),
#  ('Emphysema', 516),
#  ('Fibrosis', 371),
#  ('Effusion', 2704),
#  ('Pneumonia', 271),
#  ('Pleural_Thickening', 691),
#  ('Cardiomegaly', 525),
#  ('Nodule', 1285),
#  ('Mass', 1173),
#  ('Hernia', 44)]
# Count:  22424
# All: 71248
# Model: "under_sampling_5_folds_with_facal_loss_FOLD_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_3 (Flatten)         (None, 62720)             0
#
#  dense_15 (Dense)            (None, 128)               8028288
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 3052/3052 [==============================] - 369s 117ms/step - loss: 0.0780 - auc_3: 0.5543 - f1_score: 0.0488 - precision_3: 0.2185 - recall_3: 0.0086 - val_loss: 0.0658 - val_auc_3: 0.6136 - val_f1_score: 0.0343 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 3052/3052 [==============================] - 351s 115ms/step - loss: 0.0752 - auc_3: 0.5915 - f1_score: 0.0600 - precision_3: 0.4527 - recall_3: 0.0070 - val_loss: 0.0678 - val_auc_3: 0.6262 - val_f1_score: 0.0246 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 3052/3052 [==============================] - 352s 115ms/step - loss: 0.0742 - auc_3: 0.6143 - f1_score: 0.0730 - precision_3: 0.5019 - recall_3: 0.0129 - val_loss: 0.0647 - val_auc_3: 0.6702 - val_f1_score: 0.0557 - val_precision_3: 0.3634 - val_recall_3: 0.0341 - lr: 0.0010
# Epoch 4/100
# 3052/3052 [==============================] - 354s 116ms/step - loss: 0.0729 - auc_3: 0.6493 - f1_score: 0.0863 - precision_3: 0.5139 - recall_3: 0.0270 - val_loss: 0.0642 - val_auc_3: 0.6770 - val_f1_score: 0.0474 - val_precision_3: 0.4122 - val_recall_3: 0.0142 - lr: 0.0010
# Epoch 5/100
# 3052/3052 [==============================] - 352s 115ms/step - loss: 0.0732 - auc_3: 0.6478 - f1_score: 0.0888 - precision_3: 0.5110 - recall_3: 0.0167 - val_loss: 0.0626 - val_auc_3: 0.7008 - val_f1_score: 0.0891 - val_precision_3: 0.4066 - val_recall_3: 0.0243 - lr: 0.0010
# Epoch 6/100
# 3052/3052 [==============================] - 350s 115ms/step - loss: 0.0720 - auc_3: 0.6723 - f1_score: 0.1028 - precision_3: 0.5369 - recall_3: 0.0325 - val_loss: 0.0648 - val_auc_3: 0.6838 - val_f1_score: 0.0809 - val_precision_3: 0.3945 - val_recall_3: 0.0285 - lr: 0.0010
# Epoch 7/100
# 3052/3052 [==============================] - 354s 116ms/step - loss: 0.0738 - auc_3: 0.6280 - f1_score: 0.0828 - precision_3: 0.5278 - recall_3: 0.0168 - val_loss: 0.0685 - val_auc_3: 0.5949 - val_f1_score: 0.0318 - val_precision_3: 1.0000 - val_recall_3: 3.5226e-05 - lr: 0.0010
# Epoch 8/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0739 - auc_3: 0.6287 - f1_score: 0.0752 - precision_3: 0.5053 - recall_3: 0.0092
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0739 - auc_3: 0.6287 - f1_score: 0.0752 - precision_3: 0.5053 - recall_3: 0.0092 - val_loss: 0.0652 - val_auc_3: 0.6633 - val_f1_score: 0.0488 - val_precision_3: 0.3656 - val_recall_3: 0.0108 - lr: 5.0000e-04
# Epoch 9/100
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.0724 - auc_3: 0.6624 - f1_score: 0.0956 - precision_3: 0.5490 - recall_3: 0.0211 - val_loss: 0.0628 - val_auc_3: 0.6990 - val_f1_score: 0.0942 - val_precision_3: 0.4298 - val_recall_3: 0.0233 - lr: 5.0000e-04
# Epoch 10/100
# 3052/3052 [==============================] - 357s 117ms/step - loss: 0.0713 - auc_3: 0.6838 - f1_score: 0.1149 - precision_3: 0.5452 - recall_3: 0.0393 - val_loss: 0.0619 - val_auc_3: 0.7097 - val_f1_score: 0.1044 - val_precision_3: 0.4635 - val_recall_3: 0.0259 - lr: 5.0000e-04
# Epoch 11/100
# 3052/3052 [==============================] - 354s 116ms/step - loss: 0.0709 - auc_3: 0.6924 - f1_score: 0.1199 - precision_3: 0.5547 - recall_3: 0.0481 - val_loss: 0.0629 - val_auc_3: 0.7113 - val_f1_score: 0.0938 - val_precision_3: 0.4351 - val_recall_3: 0.0320 - lr: 5.0000e-04
# Epoch 12/100
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.0716 - auc_3: 0.6787 - f1_score: 0.1133 - precision_3: 0.5495 - recall_3: 0.0428 - val_loss: 0.0632 - val_auc_3: 0.6960 - val_f1_score: 0.0833 - val_precision_3: 0.4472 - val_recall_3: 0.0206 - lr: 5.0000e-04
# Epoch 13/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0721 - auc_3: 0.6666 - f1_score: 0.1054 - precision_3: 0.5585 - recall_3: 0.0360
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3052/3052 [==============================] - 357s 117ms/step - loss: 0.0721 - auc_3: 0.6666 - f1_score: 0.1054 - precision_3: 0.5585 - recall_3: 0.0360 - val_loss: 0.0657 - val_auc_3: 0.6388 - val_f1_score: 0.0619 - val_precision_3: 0.4440 - val_recall_3: 0.0127 - lr: 2.5000e-04
# Epoch 14/100
# 3052/3052 [==============================] - 356s 116ms/step - loss: 0.0722 - auc_3: 0.6627 - f1_score: 0.1053 - precision_3: 0.5654 - recall_3: 0.0362 - val_loss: 0.0638 - val_auc_3: 0.6931 - val_f1_score: 0.0903 - val_precision_3: 0.4431 - val_recall_3: 0.0274 - lr: 2.5000e-04
# Epoch 15/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0709 - auc_3: 0.6924 - f1_score: 0.1190 - precision_3: 0.5584 - recall_3: 0.0484 - val_loss: 0.0625 - val_auc_3: 0.7132 - val_f1_score: 0.1053 - val_precision_3: 0.4553 - val_recall_3: 0.0303 - lr: 2.5000e-04
# Epoch 16/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0705 - auc_3: 0.6991 - f1_score: 0.1236 - precision_3: 0.5587 - recall_3: 0.0552
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3052/3052 [==============================] - 354s 116ms/step - loss: 0.0705 - auc_3: 0.6991 - f1_score: 0.1236 - precision_3: 0.5587 - recall_3: 0.0552 - val_loss: 0.0628 - val_auc_3: 0.7140 - val_f1_score: 0.1050 - val_precision_3: 0.4437 - val_recall_3: 0.0361 - lr: 1.2500e-04
# Epoch 17/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0701 - auc_3: 0.7051 - f1_score: 0.1285 - precision_3: 0.5735 - recall_3: 0.0602 - val_loss: 0.0623 - val_auc_3: 0.7177 - val_f1_score: 0.1139 - val_precision_3: 0.4368 - val_recall_3: 0.0412 - lr: 1.2500e-04
# Epoch 18/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0700 - auc_3: 0.7083 - f1_score: 0.1317 - precision_3: 0.5718 - recall_3: 0.0624 - val_loss: 0.0620 - val_auc_3: 0.7205 - val_f1_score: 0.1160 - val_precision_3: 0.4404 - val_recall_3: 0.0418 - lr: 1.2500e-04
# Epoch 19/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0698 - auc_3: 0.7124 - f1_score: 0.1336 - precision_3: 0.5752 - recall_3: 0.0654
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0698 - auc_3: 0.7124 - f1_score: 0.1336 - precision_3: 0.5752 - recall_3: 0.0654 - val_loss: 0.0622 - val_auc_3: 0.7221 - val_f1_score: 0.1134 - val_precision_3: 0.4396 - val_recall_3: 0.0444 - lr: 6.2500e-05
# Epoch 20/100
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.0696 - auc_3: 0.7166 - f1_score: 0.1344 - precision_3: 0.5778 - recall_3: 0.0682 - val_loss: 0.0621 - val_auc_3: 0.7225 - val_f1_score: 0.1163 - val_precision_3: 0.4366 - val_recall_3: 0.0438 - lr: 6.2500e-05
# Epoch 21/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0695 - auc_3: 0.7165 - f1_score: 0.1358 - precision_3: 0.5734 - recall_3: 0.0683 - val_loss: 0.0621 - val_auc_3: 0.7221 - val_f1_score: 0.1187 - val_precision_3: 0.4393 - val_recall_3: 0.0452 - lr: 6.2500e-05
# Epoch 22/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0694 - auc_3: 0.7181 - f1_score: 0.1378 - precision_3: 0.5749 - recall_3: 0.0703
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.0694 - auc_3: 0.7181 - f1_score: 0.1378 - precision_3: 0.5749 - recall_3: 0.0703 - val_loss: 0.0619 - val_auc_3: 0.7234 - val_f1_score: 0.1185 - val_precision_3: 0.4377 - val_recall_3: 0.0470 - lr: 3.1250e-05
# Epoch 23/100
# 3052/3052 [==============================] - 357s 117ms/step - loss: 0.0693 - auc_3: 0.7211 - f1_score: 0.1391 - precision_3: 0.5735 - recall_3: 0.0729 - val_loss: 0.0618 - val_auc_3: 0.7241 - val_f1_score: 0.1213 - val_precision_3: 0.4364 - val_recall_3: 0.0472 - lr: 3.1250e-05
# Epoch 24/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0693 - auc_3: 0.7217 - f1_score: 0.1396 - precision_3: 0.5770 - recall_3: 0.0741 - val_loss: 0.0620 - val_auc_3: 0.7233 - val_f1_score: 0.1212 - val_precision_3: 0.4388 - val_recall_3: 0.0504 - lr: 3.1250e-05
# Epoch 25/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0693 - auc_3: 0.7210 - f1_score: 0.1397 - precision_3: 0.5791 - recall_3: 0.0743
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3052/3052 [==============================] - 357s 117ms/step - loss: 0.0693 - auc_3: 0.7210 - f1_score: 0.1397 - precision_3: 0.5791 - recall_3: 0.0743 - val_loss: 0.0618 - val_auc_3: 0.7245 - val_f1_score: 0.1230 - val_precision_3: 0.4493 - val_recall_3: 0.0480 - lr: 1.5625e-05
# Epoch 26/100
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.0692 - auc_3: 0.7233 - f1_score: 0.1402 - precision_3: 0.5811 - recall_3: 0.0735 - val_loss: 0.0617 - val_auc_3: 0.7250 - val_f1_score: 0.1229 - val_precision_3: 0.4439 - val_recall_3: 0.0502 - lr: 1.5625e-05
# Epoch 27/100
# 3052/3052 [==============================] - 354s 116ms/step - loss: 0.0692 - auc_3: 0.7236 - f1_score: 0.1399 - precision_3: 0.5784 - recall_3: 0.0757 - val_loss: 0.0618 - val_auc_3: 0.7246 - val_f1_score: 0.1222 - val_precision_3: 0.4458 - val_recall_3: 0.0522 - lr: 1.5625e-05
# Epoch 28/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0691 - auc_3: 0.7241 - f1_score: 0.1412 - precision_3: 0.5806 - recall_3: 0.0754 - val_loss: 0.0618 - val_auc_3: 0.7247 - val_f1_score: 0.1235 - val_precision_3: 0.4422 - val_recall_3: 0.0521 - lr: 1.5625e-05
# Epoch 29/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0691 - auc_3: 0.7245 - f1_score: 0.1398 - precision_3: 0.5720 - recall_3: 0.0752
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.0691 - auc_3: 0.7245 - f1_score: 0.1398 - precision_3: 0.5720 - recall_3: 0.0752 - val_loss: 0.0619 - val_auc_3: 0.7234 - val_f1_score: 0.1232 - val_precision_3: 0.4404 - val_recall_3: 0.0532 - lr: 7.8125e-06
# Epoch 30/100
# 3052/3052 [==============================] - 358s 117ms/step - loss: 0.0690 - auc_3: 0.7266 - f1_score: 0.1419 - precision_3: 0.5822 - recall_3: 0.0759 - val_loss: 0.0616 - val_auc_3: 0.7252 - val_f1_score: 0.1240 - val_precision_3: 0.4399 - val_recall_3: 0.0536 - lr: 7.8125e-06
# Epoch 31/100
# 3052/3052 [==============================] - 362s 118ms/step - loss: 0.0690 - auc_3: 0.7251 - f1_score: 0.1411 - precision_3: 0.5797 - recall_3: 0.0754 - val_loss: 0.0617 - val_auc_3: 0.7248 - val_f1_score: 0.1237 - val_precision_3: 0.4415 - val_recall_3: 0.0546 - lr: 7.8125e-06
# Epoch 32/100
# 3052/3052 [==============================] - 367s 120ms/step - loss: 0.0690 - auc_3: 0.7260 - f1_score: 0.1422 - precision_3: 0.5842 - recall_3: 0.0764 - val_loss: 0.0617 - val_auc_3: 0.7248 - val_f1_score: 0.1234 - val_precision_3: 0.4443 - val_recall_3: 0.0547 - lr: 7.8125e-06
# Epoch 33/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0690 - auc_3: 0.7264 - f1_score: 0.1407 - precision_3: 0.5797 - recall_3: 0.0758
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3052/3052 [==============================] - 359s 118ms/step - loss: 0.0690 - auc_3: 0.7264 - f1_score: 0.1407 - precision_3: 0.5797 - recall_3: 0.0758 - val_loss: 0.0617 - val_auc_3: 0.7243 - val_f1_score: 0.1242 - val_precision_3: 0.4448 - val_recall_3: 0.0541 - lr: 3.9063e-06
# Epoch 34/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.0690 - auc_3: 0.7263 - f1_score: 0.1417 - precision_3: 0.5832 - recall_3: 0.0762

# %%
print("Done")
# Out:
# Done
