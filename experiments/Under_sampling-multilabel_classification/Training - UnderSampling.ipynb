# %%
import sys
sys.path.append('/home/jovyan/ChestXray-14')

# %%
import tensorflow as tf

from modules.models import Model
from modules.utils import get_dataset

from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, TensorBoard
# Out:
# 2023-04-01 10:49:21.735121: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from modules.dataset import LABELS

# %%
ROOT_PATH = "/home/jovyan/ChestXray-14"
INPUT_PATH = f"{ROOT_PATH}/dataset/ChestXray NIH"
EXPERIMENT_NAME = "under_sampling_5_folds_with_cross_entropy_loss"

# %%
class Dataset:
    INPUT_PATH = INPUT_PATH
    
    def __init__(self, fold_num):
        self.fold_num = fold_num
    
    def get_train(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/under_sampling_5_folds_dataset/folds/fold{self.fold_num}/train/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

    def get_test(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/under_sampling_5_folds_dataset/folds/fold{self.fold_num}/test/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

# %% [markdown]
# ## tf.keras.mixed_precision for faster training

# %%
print(tf.keras.mixed_precision.global_policy())
tf.keras.mixed_precision.set_global_policy('mixed_float16')
print(tf.keras.mixed_precision.global_policy())
# Out:
# <Policy "float32">
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA A100-SXM4-40GB MIG 2g.10gb, compute capability 8.0
# <Policy "mixed_float16">

# %% [markdown]
# ## Model Training

# %%
import os
CURRENT_PATH = os.path.abspath("")
CURRENT_PATH
# Out:
# '/home/jovyan/ChestXray-14/experiments/Under_sampling-multilabel_classification'

# %%
# Learning rate
def lr_schedule(epoch, learning_rate):
    tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
    return learning_rate

# %%
import datetime

def get_callbacks(NAME, weight_option, fold_num):
    log_dir = f"{CURRENT_PATH}/logs/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    
    model_checkpoint_callback = ModelCheckpoint(f'results/models/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}.h5', monitor='val_loss', mode='min', save_best_only=True)
    early_stop_callback = EarlyStopping(monitor='val_loss', mode="min", patience=20, verbose=1)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.5, patience=3, verbose=1)
    lr_logging_callback = LearningRateScheduler(lr_schedule)
    
    return model_checkpoint_callback, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback

# %%
# Constant variables
NAME = "EfficientNetB0"
EPOCHS = 100
weight_option = None # use `imagenet` or `None` only

# %%
import pprint
import numpy as np

def check_label_on_dataset(train_dataset, test_dataset):
    y_list = []
    for x,y in train_dataset:
        # print(y)
        y_list.append(y)
    train_labels = np.vstack(y_list)

    y_list = []
    for x,y in test_dataset:
        # print(y)
        y_list.append(y)
    test_labels = np.vstack(y_list)

    # Print
    pprint.pprint(list(zip(LABELS,train_labels.sum(axis=0))))
    print("Count:", len(train_labels))
    pprint.pprint(list(zip(LABELS, test_labels.sum(axis=0))))
    print("Count: ", len(test_labels))

    print("All:", len(train_labels)+len(test_labels))

# %%
# TODO: Main
import time
from tqdm.notebook import tqdm

NUM_FOLDS = 5
for fold_num in tqdm(range(1, NUM_FOLDS + 1)):
    
    # Callbacks
    (
        model_checkpoint_callback, 
        early_stop_callback, 
        reduce_lr_callback, 
        lr_logging_callback, 
        tensorboard_callback
    ) = get_callbacks(
        NAME, weight_option, fold_num
    )

    # Path for CSV
    path = os.path.join(CURRENT_PATH, "results", "history", EXPERIMENT_NAME, f"{NAME}_{weight_option}_FOLD_{fold_num}")
    os.makedirs(path, exist_ok=True)

    # CSV Logger
    csv_logger = CSVLogger(os.path.join(path, f"history.csv"))

    # Dataset
    dataset = Dataset(fold_num)
    train_dataset, test_dataset = dataset.get_train(), dataset.get_test()
    check_label_on_dataset(train_dataset, test_dataset)

    # Modeling
    transfer_model = tf.keras.applications.efficientnet.EfficientNetB0(
        include_top=False, 
        weights=weight_option,
        input_shape=(224, 224, 3),
        pooling=None
    )

    model = Model(
        transfer_model,
    )
    model = model.get_model()
    model._name = f"{EXPERIMENT_NAME}_FOLD_{fold_num}"
    model.summary()

    # Record time for training
    start = time.time()
    
    # Visualize
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=test_dataset,
        verbose=1, # Show Progress Bar while Traning
        callbacks=[model_checkpoint_callback, csv_logger, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback]
    )
    
    end = time.time()
    print(
        "===== " * 5,
        "Model Traninig for: {:.2f} second(s)".format(end - start),
        "===== " * 5,
        "\n\n"
    )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2023-04-01 10:49:24.766516: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-01 10:49:25.531016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8011 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:31:00.0, compute capability: 8.0
# [('No Finding', 7560),
#  ('Atelectasis', 9334),
#  ('Consolidation', 3773),
#  ('Infiltration', 15943),
#  ('Pneumothorax', 4256),
#  ('Edema', 1857),
#  ('Emphysema', 2029),
#  ('Fibrosis', 1367),
#  ('Effusion', 10692),
#  ('Pneumonia', 1137),
#  ('Pleural_Thickening', 2722),
#  ('Cardiomegaly', 2219),
#  ('Nodule', 5046),
#  ('Mass', 4641),
#  ('Hernia', 181)]
# Count: 49055
# [('No Finding', 12160),
#  ('Atelectasis', 2225),
#  ('Consolidation', 894),
#  ('Infiltration', 3951),
#  ('Pneumothorax', 1046),
#  ('Edema', 446),
#  ('Emphysema', 487),
#  ('Fibrosis', 319),
#  ('Effusion', 2625),
#  ('Pneumonia', 294),
#  ('Pleural_Thickening', 663),
#  ('Cardiomegaly', 557),
#  ('Nodule', 1285),
#  ('Mass', 1141),
#  ('Hernia', 46)]
# Count:  22424
# All: 71479
# Model: "under_sampling_5_folds_with_cross_entropy_loss_FOLD_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 128)               8028288
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 2023-04-01 10:50:01.851678: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-04-01 10:50:02.614800: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-01 10:50:02.615756: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-01 10:50:02.615792: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-04-01 10:50:02.616730: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-01 10:50:02.616829: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 3066/3066 [==============================] - 377s 118ms/step - loss: 0.2914 - auc: 0.5018 - f1_score: 0.0400 - precision: 0.1860 - recall: 0.0034 - val_loss: 0.2584 - val_auc: 0.5138 - val_f1_score: 0.0200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.2849 - auc: 0.5413 - f1_score: 0.0381 - precision: 0.3103 - recall: 4.9480e-04 - val_loss: 0.2470 - val_auc: 0.6102 - val_f1_score: 0.0314 - val_precision: 0.5000 - val_recall: 3.5538e-05 - lr: 0.0010
# Epoch 3/100
# 3066/3066 [==============================] - 340s 111ms/step - loss: 0.2806 - auc: 0.5824 - f1_score: 0.0519 - precision: 0.4891 - recall: 0.0034 - val_loss: 0.2601 - val_auc: 0.5883 - val_f1_score: 0.0451 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 3066/3066 [==============================] - 349s 114ms/step - loss: 0.2783 - auc: 0.5985 - f1_score: 0.0630 - precision: 0.4738 - recall: 0.0053 - val_loss: 0.2429 - val_auc: 0.6486 - val_f1_score: 0.0694 - val_precision: 0.3774 - val_recall: 0.0028 - lr: 0.0010
# Epoch 5/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2752 - auc: 0.6233 - f1_score: 0.0781 - precision: 0.4964 - recall: 0.0114 - val_loss: 0.2434 - val_auc: 0.6518 - val_f1_score: 0.0757 - val_precision: 0.3879 - val_recall: 0.0281 - lr: 0.0010
# Epoch 6/100
# 3066/3066 [==============================] - 349s 114ms/step - loss: 0.2717 - auc: 0.6402 - f1_score: 0.0895 - precision: 0.5228 - recall: 0.0279 - val_loss: 0.2434 - val_auc: 0.6623 - val_f1_score: 0.0691 - val_precision: 0.4124 - val_recall: 0.0333 - lr: 0.0010
# Epoch 7/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2701 - auc: 0.6510 - f1_score: 0.0935 - precision: 0.5343 - recall: 0.0386 - val_loss: 0.2410 - val_auc: 0.6648 - val_f1_score: 0.0645 - val_precision: 0.4010 - val_recall: 0.0304 - lr: 0.0010
# Epoch 8/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2688 - auc: 0.6583 - f1_score: 0.0958 - precision: 0.5353 - recall: 0.0431 - val_loss: 0.2461 - val_auc: 0.6608 - val_f1_score: 0.0673 - val_precision: 0.3710 - val_recall: 0.0438 - lr: 0.0010
# Epoch 9/100
# 3066/3066 [==============================] - 357s 117ms/step - loss: 0.2673 - auc: 0.6671 - f1_score: 0.0989 - precision: 0.5516 - recall: 0.0531 - val_loss: 0.2397 - val_auc: 0.6895 - val_f1_score: 0.0857 - val_precision: 0.4048 - val_recall: 0.0490 - lr: 0.0010
# Epoch 10/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2663 - auc: 0.6744 - f1_score: 0.1046 - precision: 0.5541 - recall: 0.0539 - val_loss: 0.2362 - val_auc: 0.6856 - val_f1_score: 0.0941 - val_precision: 0.4206 - val_recall: 0.0433 - lr: 0.0010
# Epoch 11/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2656 - auc: 0.6765 - f1_score: 0.1078 - precision: 0.5568 - recall: 0.0566 - val_loss: 0.2370 - val_auc: 0.6897 - val_f1_score: 0.0951 - val_precision: 0.4136 - val_recall: 0.0475 - lr: 0.0010
# Epoch 12/100
# 3066/3066 [==============================] - 353s 115ms/step - loss: 0.2643 - auc: 0.6849 - f1_score: 0.1111 - precision: 0.5585 - recall: 0.0593 - val_loss: 0.2385 - val_auc: 0.6874 - val_f1_score: 0.0936 - val_precision: 0.4003 - val_recall: 0.0550 - lr: 0.0010
# Epoch 13/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2634 - auc: 0.6881 - f1_score: 0.1135 - precision: 0.5615 - recall: 0.0648 - val_loss: 0.2357 - val_auc: 0.6990 - val_f1_score: 0.0953 - val_precision: 0.4329 - val_recall: 0.0410 - lr: 0.0010
# Epoch 14/100
# 3066/3066 [==============================] - 357s 117ms/step - loss: 0.2631 - auc: 0.6916 - f1_score: 0.1159 - precision: 0.5595 - recall: 0.0650 - val_loss: 0.2325 - val_auc: 0.7085 - val_f1_score: 0.1013 - val_precision: 0.4195 - val_recall: 0.0510 - lr: 0.0010
# Epoch 15/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2605 - auc: 0.7025 - f1_score: 0.1323 - precision: 0.5744 - recall: 0.0791 - val_loss: 0.2348 - val_auc: 0.7075 - val_f1_score: 0.1068 - val_precision: 0.4389 - val_recall: 0.0520 - lr: 0.0010
# Epoch 16/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2596 - auc: 0.7060 - f1_score: 0.1358 - precision: 0.5751 - recall: 0.0810 - val_loss: 0.2340 - val_auc: 0.7087 - val_f1_score: 0.1061 - val_precision: 0.4102 - val_recall: 0.0571 - lr: 0.0010
# Epoch 17/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2607 - auc: 0.7047 - f1_score: 0.1356 - precision: 0.5684 - recall: 0.0738
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2607 - auc: 0.7047 - f1_score: 0.1356 - precision: 0.5684 - recall: 0.0738 - val_loss: 0.2340 - val_auc: 0.7145 - val_f1_score: 0.1142 - val_precision: 0.4239 - val_recall: 0.0600 - lr: 5.0000e-04
# Epoch 18/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2566 - auc: 0.7189 - f1_score: 0.1470 - precision: 0.5813 - recall: 0.0889 - val_loss: 0.2390 - val_auc: 0.6972 - val_f1_score: 0.1081 - val_precision: 0.4129 - val_recall: 0.0593 - lr: 5.0000e-04
# Epoch 19/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2569 - auc: 0.7175 - f1_score: 0.1458 - precision: 0.5841 - recall: 0.0916 - val_loss: 0.2344 - val_auc: 0.7187 - val_f1_score: 0.1130 - val_precision: 0.4005 - val_recall: 0.0709 - lr: 5.0000e-04
# Epoch 20/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2550 - auc: 0.7245 - f1_score: 0.1507 - precision: 0.5889 - recall: 0.1013
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2550 - auc: 0.7245 - f1_score: 0.1507 - precision: 0.5889 - recall: 0.1013 - val_loss: 0.2373 - val_auc: 0.7192 - val_f1_score: 0.1116 - val_precision: 0.4025 - val_recall: 0.0744 - lr: 2.5000e-04
# Epoch 21/100
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.2522 - auc: 0.7358 - f1_score: 0.1593 - precision: 0.5992 - recall: 0.1113 - val_loss: 0.2280 - val_auc: 0.7280 - val_f1_score: 0.1231 - val_precision: 0.4377 - val_recall: 0.0864 - lr: 2.5000e-04
# Epoch 22/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2510 - auc: 0.7409 - f1_score: 0.1626 - precision: 0.5986 - recall: 0.1185 - val_loss: 0.2283 - val_auc: 0.7267 - val_f1_score: 0.1235 - val_precision: 0.4397 - val_recall: 0.0832 - lr: 2.5000e-04
# Epoch 23/100
# 3066/3066 [==============================] - 354s 115ms/step - loss: 0.2502 - auc: 0.7439 - f1_score: 0.1647 - precision: 0.6031 - recall: 0.1219 - val_loss: 0.2312 - val_auc: 0.7251 - val_f1_score: 0.1221 - val_precision: 0.4341 - val_recall: 0.0872 - lr: 2.5000e-04
# Epoch 24/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2490 - auc: 0.7461 - f1_score: 0.1681 - precision: 0.6030 - recall: 0.1289
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2490 - auc: 0.7461 - f1_score: 0.1681 - precision: 0.6030 - recall: 0.1289 - val_loss: 0.2289 - val_auc: 0.7274 - val_f1_score: 0.1278 - val_precision: 0.4446 - val_recall: 0.0935 - lr: 1.2500e-04
# Epoch 25/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2471 - auc: 0.7532 - f1_score: 0.1731 - precision: 0.6128 - recall: 0.1372 - val_loss: 0.2275 - val_auc: 0.7314 - val_f1_score: 0.1308 - val_precision: 0.4542 - val_recall: 0.1030 - lr: 1.2500e-04
# Epoch 26/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2462 - auc: 0.7560 - f1_score: 0.1758 - precision: 0.6061 - recall: 0.1408 - val_loss: 0.2283 - val_auc: 0.7278 - val_f1_score: 0.1318 - val_precision: 0.4534 - val_recall: 0.1070 - lr: 1.2500e-04
# Epoch 27/100
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.2456 - auc: 0.7588 - f1_score: 0.1779 - precision: 0.6122 - recall: 0.1452 - val_loss: 0.2276 - val_auc: 0.7261 - val_f1_score: 0.1324 - val_precision: 0.4599 - val_recall: 0.1121 - lr: 1.2500e-04
# Epoch 28/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2450 - auc: 0.7599 - f1_score: 0.1800 - precision: 0.6155 - recall: 0.1485
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3066/3066 [==============================] - 352s 115ms/step - loss: 0.2450 - auc: 0.7599 - f1_score: 0.1800 - precision: 0.6155 - recall: 0.1485 - val_loss: 0.2294 - val_auc: 0.7251 - val_f1_score: 0.1302 - val_precision: 0.4465 - val_recall: 0.1133 - lr: 6.2500e-05
# Epoch 29/100
# 3066/3066 [==============================] - 360s 117ms/step - loss: 0.2436 - auc: 0.7644 - f1_score: 0.1837 - precision: 0.6197 - recall: 0.1549 - val_loss: 0.2274 - val_auc: 0.7273 - val_f1_score: 0.1341 - val_precision: 0.4677 - val_recall: 0.1209 - lr: 6.2500e-05
# Epoch 30/100
# 3066/3066 [==============================] - 358s 117ms/step - loss: 0.2430 - auc: 0.7671 - f1_score: 0.1853 - precision: 0.6186 - recall: 0.1573 - val_loss: 0.2269 - val_auc: 0.7279 - val_f1_score: 0.1341 - val_precision: 0.4664 - val_recall: 0.1202 - lr: 6.2500e-05
# Epoch 31/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.2427 - auc: 0.7665 - f1_score: 0.1856 - precision: 0.6234 - recall: 0.1581 - val_loss: 0.2265 - val_auc: 0.7262 - val_f1_score: 0.1355 - val_precision: 0.4702 - val_recall: 0.1253 - lr: 6.2500e-05
# Epoch 32/100
# 3066/3066 [==============================] - 358s 117ms/step - loss: 0.2422 - auc: 0.7694 - f1_score: 0.1881 - precision: 0.6230 - recall: 0.1611 - val_loss: 0.2274 - val_auc: 0.7268 - val_f1_score: 0.1355 - val_precision: 0.4691 - val_recall: 0.1246 - lr: 6.2500e-05
# Epoch 33/100
# 3066/3066 [==============================] - 358s 117ms/step - loss: 0.2419 - auc: 0.7700 - f1_score: 0.1883 - precision: 0.6226 - recall: 0.1613 - val_loss: 0.2287 - val_auc: 0.7255 - val_f1_score: 0.1330 - val_precision: 0.4587 - val_recall: 0.1247 - lr: 6.2500e-05
# Epoch 34/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2411 - auc: 0.7729 - f1_score: 0.1898 - precision: 0.6232 - recall: 0.1658
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2411 - auc: 0.7729 - f1_score: 0.1898 - precision: 0.6232 - recall: 0.1658 - val_loss: 0.2283 - val_auc: 0.7243 - val_f1_score: 0.1346 - val_precision: 0.4630 - val_recall: 0.1263 - lr: 3.1250e-05
# Epoch 35/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2405 - auc: 0.7736 - f1_score: 0.1920 - precision: 0.6249 - recall: 0.1683 - val_loss: 0.2274 - val_auc: 0.7258 - val_f1_score: 0.1358 - val_precision: 0.4649 - val_recall: 0.1257 - lr: 3.1250e-05
# Epoch 36/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.2402 - auc: 0.7752 - f1_score: 0.1925 - precision: 0.6243 - recall: 0.1697 - val_loss: 0.2281 - val_auc: 0.7254 - val_f1_score: 0.1347 - val_precision: 0.4591 - val_recall: 0.1255 - lr: 3.1250e-05
# Epoch 37/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2398 - auc: 0.7759 - f1_score: 0.1941 - precision: 0.6248 - recall: 0.1717
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.2398 - auc: 0.7759 - f1_score: 0.1941 - precision: 0.6248 - recall: 0.1717 - val_loss: 0.2275 - val_auc: 0.7246 - val_f1_score: 0.1366 - val_precision: 0.4705 - val_recall: 0.1316 - lr: 1.5625e-05
# Epoch 38/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2395 - auc: 0.7774 - f1_score: 0.1952 - precision: 0.6223 - recall: 0.1729 - val_loss: 0.2281 - val_auc: 0.7244 - val_f1_score: 0.1347 - val_precision: 0.4626 - val_recall: 0.1290 - lr: 1.5625e-05
# Epoch 39/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2393 - auc: 0.7761 - f1_score: 0.1957 - precision: 0.6277 - recall: 0.1750 - val_loss: 0.2284 - val_auc: 0.7236 - val_f1_score: 0.1345 - val_precision: 0.4625 - val_recall: 0.1294 - lr: 1.5625e-05
# Epoch 40/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2391 - auc: 0.7786 - f1_score: 0.1965 - precision: 0.6279 - recall: 0.1759
# Epoch 40: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2391 - auc: 0.7786 - f1_score: 0.1965 - precision: 0.6279 - recall: 0.1759 - val_loss: 0.2284 - val_auc: 0.7247 - val_f1_score: 0.1345 - val_precision: 0.4586 - val_recall: 0.1272 - lr: 7.8125e-06
# Epoch 41/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2390 - auc: 0.7781 - f1_score: 0.1959 - precision: 0.6255 - recall: 0.1764 - val_loss: 0.2281 - val_auc: 0.7249 - val_f1_score: 0.1344 - val_precision: 0.4606 - val_recall: 0.1272 - lr: 7.8125e-06
# Epoch 42/100
# 3066/3066 [==============================] - 359s 117ms/step - loss: 0.2388 - auc: 0.7786 - f1_score: 0.1968 - precision: 0.6265 - recall: 0.1767 - val_loss: 0.2280 - val_auc: 0.7241 - val_f1_score: 0.1347 - val_precision: 0.4625 - val_recall: 0.1281 - lr: 7.8125e-06
# Epoch 43/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2386 - auc: 0.7800 - f1_score: 0.1972 - precision: 0.6310 - recall: 0.1764
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2386 - auc: 0.7800 - f1_score: 0.1972 - precision: 0.6310 - recall: 0.1764 - val_loss: 0.2281 - val_auc: 0.7248 - val_f1_score: 0.1347 - val_precision: 0.4610 - val_recall: 0.1281 - lr: 3.9063e-06
# Epoch 44/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2387 - auc: 0.7799 - f1_score: 0.1979 - precision: 0.6273 - recall: 0.1774 - val_loss: 0.2275 - val_auc: 0.7247 - val_f1_score: 0.1347 - val_precision: 0.4628 - val_recall: 0.1285 - lr: 3.9063e-06
# Epoch 45/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2387 - auc: 0.7789 - f1_score: 0.1985 - precision: 0.6292 - recall: 0.1776 - val_loss: 0.2278 - val_auc: 0.7242 - val_f1_score: 0.1346 - val_precision: 0.4623 - val_recall: 0.1279 - lr: 3.9063e-06
# Epoch 46/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2386 - auc: 0.7796 - f1_score: 0.1960 - precision: 0.6286 - recall: 0.1773
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.2386 - auc: 0.7796 - f1_score: 0.1960 - precision: 0.6286 - recall: 0.1773 - val_loss: 0.2276 - val_auc: 0.7251 - val_f1_score: 0.1350 - val_precision: 0.4647 - val_recall: 0.1287 - lr: 1.9531e-06
# Epoch 47/100
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2385 - auc: 0.7802 - f1_score: 0.1986 - precision: 0.6305 - recall: 0.1778 - val_loss: 0.2275 - val_auc: 0.7254 - val_f1_score: 0.1351 - val_precision: 0.4654 - val_recall: 0.1290 - lr: 1.9531e-06
# Epoch 48/100
# 3066/3066 [==============================] - 355s 116ms/step - loss: 0.2385 - auc: 0.7799 - f1_score: 0.1980 - precision: 0.6297 - recall: 0.1787 - val_loss: 0.2275 - val_auc: 0.7253 - val_f1_score: 0.1355 - val_precision: 0.4655 - val_recall: 0.1300 - lr: 1.9531e-06
# Epoch 49/100
# 3066/3066 [==============================] - ETA: 0s - loss: 0.2384 - auc: 0.7804 - f1_score: 0.1978 - precision: 0.6291 - recall: 0.1784
# Epoch 49: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3066/3066 [==============================] - 356s 116ms/step - loss: 0.2384 - auc: 0.7804 - f1_score: 0.1978 - precision: 0.6291 - recall: 0.1784 - val_loss: 0.2277 - val_auc: 0.7251 - val_f1_score: 0.1350 - val_precision: 0.4643 - val_recall: 0.1284 - lr: 9.7656e-07
# Epoch 50/100
# 3066/3066 [==============================] - 358s 117ms/step - loss: 0.2384 - auc: 0.7799 - f1_score: 0.1986 - precision: 0.6300 - recall: 0.1787 - val_loss: 0.2275 - val_auc: 0.7247 - val_f1_score: 0.1356 - val_precision: 0.4652 - val_recall: 0.1291 - lr: 9.7656e-07
# Epoch 51/100
# 3066/3066 [==============================] - 357s 116ms/step - loss: 0.2385 - auc: 0.7816 - f1_score: 0.1976 - precision: 0.6275 - recall: 0.1783 - val_loss: 0.2275 - val_auc: 0.7251 - val_f1_score: 0.1354 - val_precision: 0.4639 - val_recall: 0.1292 - lr: 9.7656e-07
# Epoch 51: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 18173.29 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7547),
#  ('Atelectasis', 9233),
#  ('Consolidation', 3699),
#  ('Infiltration', 16008),
#  ('Pneumothorax', 4229),
#  ('Edema', 1855),
#  ('Emphysema', 2017),
#  ('Fibrosis', 1343),
#  ('Effusion', 10576),
#  ('Pneumonia', 1146),
#  ('Pleural_Thickening', 2715),
#  ('Cardiomegaly', 2184),
#  ('Nodule', 5047),
#  ('Mass', 4643),
#  ('Hernia', 180)]
# Count: 48922
# [('No Finding', 12040),
#  ('Atelectasis', 2326),
#  ('Consolidation', 968),
#  ('Infiltration', 3886),
#  ('Pneumothorax', 1073),
#  ('Edema', 448),
#  ('Emphysema', 499),
#  ('Fibrosis', 343),
#  ('Effusion', 2741),
#  ('Pneumonia', 285),
#  ('Pleural_Thickening', 670),
#  ('Cardiomegaly', 592),
#  ('Nodule', 1284),
#  ('Mass', 1139),
#  ('Hernia', 47)]
# Count:  22424
# All: 71346
# Model: "under_sampling_5_folds_with_cross_entropy_loss_FOLD_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_1 (Flatten)         (None, 62720)             0
#
#  dense_5 (Dense)             (None, 128)               8028288
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 3058/3058 [==============================] - 376s 119ms/step - loss: 0.2832 - auc_1: 0.5817 - f1_score: 0.0662 - precision_1: 0.3914 - recall_1: 0.0167 - val_loss: 0.2454 - val_auc_1: 0.6517 - val_f1_score: 0.0336 - val_precision_1: 0.3333 - val_recall_1: 0.0293 - lr: 0.0010
# Epoch 2/100
# 3058/3058 [==============================] - 361s 118ms/step - loss: 0.2741 - auc_1: 0.6230 - f1_score: 0.0825 - precision_1: 0.5164 - recall_1: 0.0284 - val_loss: 0.2336 - val_auc_1: 0.6727 - val_f1_score: 0.0737 - val_precision_1: 0.3508 - val_recall_1: 0.0288 - lr: 0.0010
# Epoch 3/100
# 3058/3058 [==============================] - 361s 118ms/step - loss: 0.2718 - auc_1: 0.6366 - f1_score: 0.0902 - precision_1: 0.5419 - recall_1: 0.0370 - val_loss: 0.2329 - val_auc_1: 0.6791 - val_f1_score: 0.0818 - val_precision_1: 0.4581 - val_recall_1: 0.0445 - lr: 0.0010
# Epoch 4/100
# 3058/3058 [==============================] - 360s 118ms/step - loss: 0.2674 - auc_1: 0.6633 - f1_score: 0.1005 - precision_1: 0.5541 - recall_1: 0.0530 - val_loss: 0.2382 - val_auc_1: 0.6911 - val_f1_score: 0.0800 - val_precision_1: 0.3744 - val_recall_1: 0.0179 - lr: 0.0010
# Epoch 5/100
# 3058/3058 [==============================] - 365s 119ms/step - loss: 0.2668 - auc_1: 0.6678 - f1_score: 0.1046 - precision_1: 0.5504 - recall_1: 0.0531 - val_loss: 0.2324 - val_auc_1: 0.7090 - val_f1_score: 0.1000 - val_precision_1: 0.4030 - val_recall_1: 0.0406 - lr: 0.0010
# Epoch 6/100
# 3058/3058 [==============================] - 372s 122ms/step - loss: 0.2636 - auc_1: 0.6823 - f1_score: 0.1172 - precision_1: 0.5668 - recall_1: 0.0691 - val_loss: 0.2301 - val_auc_1: 0.7126 - val_f1_score: 0.0972 - val_precision_1: 0.4290 - val_recall_1: 0.0328 - lr: 0.0010
# Epoch 7/100
# 3058/3058 [==============================] - 366s 120ms/step - loss: 0.2622 - auc_1: 0.6914 - f1_score: 0.1232 - precision_1: 0.5711 - recall_1: 0.0716 - val_loss: 0.2301 - val_auc_1: 0.7233 - val_f1_score: 0.1075 - val_precision_1: 0.4308 - val_recall_1: 0.0422 - lr: 0.0010
# Epoch 8/100
# 3058/3058 [==============================] - 367s 120ms/step - loss: 0.2611 - auc_1: 0.6954 - f1_score: 0.1296 - precision_1: 0.5769 - recall_1: 0.0756 - val_loss: 0.2255 - val_auc_1: 0.7170 - val_f1_score: 0.1263 - val_precision_1: 0.5372 - val_recall_1: 0.0609 - lr: 0.0010
# Epoch 9/100
# 3058/3058 [==============================] - 364s 119ms/step - loss: 0.2628 - auc_1: 0.6869 - f1_score: 0.1241 - precision_1: 0.5744 - recall_1: 0.0706 - val_loss: 0.2272 - val_auc_1: 0.7218 - val_f1_score: 0.1126 - val_precision_1: 0.4573 - val_recall_1: 0.0331 - lr: 0.0010
# Epoch 10/100
# 3058/3058 [==============================] - 363s 119ms/step - loss: 0.2597 - auc_1: 0.7016 - f1_score: 0.1361 - precision_1: 0.5766 - recall_1: 0.0808 - val_loss: 0.2285 - val_auc_1: 0.7185 - val_f1_score: 0.1173 - val_precision_1: 0.4372 - val_recall_1: 0.0367 - lr: 0.0010
# Epoch 11/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2607 - auc_1: 0.6976 - f1_score: 0.1330 - precision_1: 0.5777 - recall_1: 0.0767
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3058/3058 [==============================] - 372s 122ms/step - loss: 0.2607 - auc_1: 0.6976 - f1_score: 0.1330 - precision_1: 0.5777 - recall_1: 0.0767 - val_loss: 0.2335 - val_auc_1: 0.7215 - val_f1_score: 0.1036 - val_precision_1: 0.4297 - val_recall_1: 0.0435 - lr: 5.0000e-04
# Epoch 12/100
# 3058/3058 [==============================] - 373s 122ms/step - loss: 0.2565 - auc_1: 0.7155 - f1_score: 0.1468 - precision_1: 0.5923 - recall_1: 0.0921 - val_loss: 0.2271 - val_auc_1: 0.7321 - val_f1_score: 0.1304 - val_precision_1: 0.4547 - val_recall_1: 0.0545 - lr: 5.0000e-04
# Epoch 13/100
# 3058/3058 [==============================] - 373s 122ms/step - loss: 0.2546 - auc_1: 0.7218 - f1_score: 0.1565 - precision_1: 0.5940 - recall_1: 0.1000 - val_loss: 0.2297 - val_auc_1: 0.7267 - val_f1_score: 0.1301 - val_precision_1: 0.4534 - val_recall_1: 0.0611 - lr: 5.0000e-04
# Epoch 14/100
# 3058/3058 [==============================] - 375s 123ms/step - loss: 0.2531 - auc_1: 0.7289 - f1_score: 0.1621 - precision_1: 0.5966 - recall_1: 0.1096 - val_loss: 0.2253 - val_auc_1: 0.7343 - val_f1_score: 0.1299 - val_precision_1: 0.4637 - val_recall_1: 0.0652 - lr: 5.0000e-04
# Epoch 15/100
# 3058/3058 [==============================] - 375s 123ms/step - loss: 0.2514 - auc_1: 0.7368 - f1_score: 0.1662 - precision_1: 0.6000 - recall_1: 0.1162 - val_loss: 0.2245 - val_auc_1: 0.7362 - val_f1_score: 0.1406 - val_precision_1: 0.4920 - val_recall_1: 0.0709 - lr: 5.0000e-04
# Epoch 16/100
# 3058/3058 [==============================] - 375s 123ms/step - loss: 0.2504 - auc_1: 0.7410 - f1_score: 0.1695 - precision_1: 0.6020 - recall_1: 0.1200 - val_loss: 0.2262 - val_auc_1: 0.7367 - val_f1_score: 0.1424 - val_precision_1: 0.4868 - val_recall_1: 0.0710 - lr: 5.0000e-04
# Epoch 17/100
# 3058/3058 [==============================] - 373s 122ms/step - loss: 0.2488 - auc_1: 0.7445 - f1_score: 0.1751 - precision_1: 0.6059 - recall_1: 0.1236 - val_loss: 0.2275 - val_auc_1: 0.7353 - val_f1_score: 0.1353 - val_precision_1: 0.4583 - val_recall_1: 0.0700 - lr: 5.0000e-04
# Epoch 18/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2473 - auc_1: 0.7507 - f1_score: 0.1785 - precision_1: 0.6111 - recall_1: 0.1344
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3058/3058 [==============================] - 371s 121ms/step - loss: 0.2473 - auc_1: 0.7507 - f1_score: 0.1785 - precision_1: 0.6111 - recall_1: 0.1344 - val_loss: 0.2271 - val_auc_1: 0.7358 - val_f1_score: 0.1385 - val_precision_1: 0.4499 - val_recall_1: 0.0876 - lr: 2.5000e-04
# Epoch 19/100
# 3058/3058 [==============================] - 359s 118ms/step - loss: 0.2424 - auc_1: 0.7675 - f1_score: 0.1902 - precision_1: 0.6253 - recall_1: 0.1547 - val_loss: 0.2249 - val_auc_1: 0.7369 - val_f1_score: 0.1475 - val_precision_1: 0.4743 - val_recall_1: 0.1084 - lr: 2.5000e-04
# Epoch 20/100
# 3058/3058 [==============================] - 357s 117ms/step - loss: 0.2403 - auc_1: 0.7731 - f1_score: 0.1960 - precision_1: 0.6287 - recall_1: 0.1655 - val_loss: 0.2290 - val_auc_1: 0.7339 - val_f1_score: 0.1465 - val_precision_1: 0.4543 - val_recall_1: 0.1080 - lr: 2.5000e-04
# Epoch 21/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2379 - auc_1: 0.7804 - f1_score: 0.2015 - precision_1: 0.6342 - recall_1: 0.1776
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3058/3058 [==============================] - 370s 121ms/step - loss: 0.2379 - auc_1: 0.7804 - f1_score: 0.2015 - precision_1: 0.6342 - recall_1: 0.1776 - val_loss: 0.2270 - val_auc_1: 0.7329 - val_f1_score: 0.1479 - val_precision_1: 0.4787 - val_recall_1: 0.1254 - lr: 1.2500e-04
# Epoch 22/100
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2347 - auc_1: 0.7872 - f1_score: 0.2100 - precision_1: 0.6406 - recall_1: 0.1904 - val_loss: 0.2278 - val_auc_1: 0.7325 - val_f1_score: 0.1531 - val_precision_1: 0.4791 - val_recall_1: 0.1437 - lr: 1.2500e-04
# Epoch 23/100
# 3058/3058 [==============================] - 373s 122ms/step - loss: 0.2323 - auc_1: 0.7937 - f1_score: 0.2178 - precision_1: 0.6459 - recall_1: 0.2029 - val_loss: 0.2281 - val_auc_1: 0.7309 - val_f1_score: 0.1532 - val_precision_1: 0.4852 - val_recall_1: 0.1510 - lr: 1.2500e-04
# Epoch 24/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2305 - auc_1: 0.7978 - f1_score: 0.2215 - precision_1: 0.6519 - recall_1: 0.2121
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2305 - auc_1: 0.7978 - f1_score: 0.2215 - precision_1: 0.6519 - recall_1: 0.2121 - val_loss: 0.2316 - val_auc_1: 0.7273 - val_f1_score: 0.1518 - val_precision_1: 0.4760 - val_recall_1: 0.1520 - lr: 6.2500e-05
# Epoch 25/100
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2278 - auc_1: 0.8039 - f1_score: 0.2281 - precision_1: 0.6564 - recall_1: 0.2249 - val_loss: 0.2335 - val_auc_1: 0.7288 - val_f1_score: 0.1527 - val_precision_1: 0.4610 - val_recall_1: 0.1569 - lr: 6.2500e-05
# Epoch 26/100
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2264 - auc_1: 0.8087 - f1_score: 0.2322 - precision_1: 0.6590 - recall_1: 0.2315 - val_loss: 0.2357 - val_auc_1: 0.7253 - val_f1_score: 0.1522 - val_precision_1: 0.4573 - val_recall_1: 0.1609 - lr: 6.2500e-05
# Epoch 27/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2253 - auc_1: 0.8096 - f1_score: 0.2352 - precision_1: 0.6632 - recall_1: 0.2369
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3058/3058 [==============================] - 375s 123ms/step - loss: 0.2253 - auc_1: 0.8096 - f1_score: 0.2352 - precision_1: 0.6632 - recall_1: 0.2369 - val_loss: 0.2363 - val_auc_1: 0.7238 - val_f1_score: 0.1519 - val_precision_1: 0.4538 - val_recall_1: 0.1600 - lr: 3.1250e-05
# Epoch 28/100
# 3058/3058 [==============================] - 375s 123ms/step - loss: 0.2236 - auc_1: 0.8142 - f1_score: 0.2390 - precision_1: 0.6667 - recall_1: 0.2435 - val_loss: 0.2370 - val_auc_1: 0.7233 - val_f1_score: 0.1529 - val_precision_1: 0.4559 - val_recall_1: 0.1717 - lr: 3.1250e-05
# Epoch 29/100
# 3058/3058 [==============================] - 373s 122ms/step - loss: 0.2229 - auc_1: 0.8145 - f1_score: 0.2425 - precision_1: 0.6686 - recall_1: 0.2502 - val_loss: 0.2368 - val_auc_1: 0.7228 - val_f1_score: 0.1541 - val_precision_1: 0.4588 - val_recall_1: 0.1741 - lr: 3.1250e-05
# Epoch 30/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2223 - auc_1: 0.8164 - f1_score: 0.2440 - precision_1: 0.6692 - recall_1: 0.2517
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3058/3058 [==============================] - 375s 122ms/step - loss: 0.2223 - auc_1: 0.8164 - f1_score: 0.2440 - precision_1: 0.6692 - recall_1: 0.2517 - val_loss: 0.2379 - val_auc_1: 0.7218 - val_f1_score: 0.1544 - val_precision_1: 0.4570 - val_recall_1: 0.1768 - lr: 1.5625e-05
# Epoch 31/100
# 3058/3058 [==============================] - 373s 122ms/step - loss: 0.2215 - auc_1: 0.8182 - f1_score: 0.2457 - precision_1: 0.6700 - recall_1: 0.2556 - val_loss: 0.2382 - val_auc_1: 0.7207 - val_f1_score: 0.1542 - val_precision_1: 0.4609 - val_recall_1: 0.1808 - lr: 1.5625e-05
# Epoch 32/100
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2209 - auc_1: 0.8188 - f1_score: 0.2477 - precision_1: 0.6695 - recall_1: 0.2573 - val_loss: 0.2381 - val_auc_1: 0.7208 - val_f1_score: 0.1549 - val_precision_1: 0.4604 - val_recall_1: 0.1815 - lr: 1.5625e-05
# Epoch 33/100
# 3058/3058 [==============================] - ETA: 0s - loss: 0.2204 - auc_1: 0.8219 - f1_score: 0.2483 - precision_1: 0.6721 - recall_1: 0.2606
# Epoch 33: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2204 - auc_1: 0.8219 - f1_score: 0.2483 - precision_1: 0.6721 - recall_1: 0.2606 - val_loss: 0.2394 - val_auc_1: 0.7199 - val_f1_score: 0.1549 - val_precision_1: 0.4556 - val_recall_1: 0.1806 - lr: 7.8125e-06
# Epoch 34/100
# 3058/3058 [==============================] - 374s 122ms/step - loss: 0.2202 - auc_1: 0.8200 - f1_score: 0.2500 - precision_1: 0.6734 - recall_1: 0.2619 - val_loss: 0.2393 - val_auc_1: 0.7196 - val_f1_score: 0.1540 - val_precision_1: 0.4554 - val_recall_1: 0.1821 - lr: 7.8125e-06
# Epoch 35/100
# 3058/3058 [==============================] - 375s 122ms/step - loss: 0.2197 - auc_1: 0.8212 - f1_score: 0.2515 - precision_1: 0.6763 - recall_1: 0.2640 - val_loss: 0.2398 - val_auc_1: 0.7191 - val_f1_score: 0.1537 - val_precision_1: 0.4544 - val_recall_1: 0.1825 - lr: 7.8125e-06
# Epoch 35: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 12969.79 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7543),
#  ('Atelectasis', 9226),
#  ('Consolidation', 3739),
#  ('Infiltration', 15900),
#  ('Pneumothorax', 4224),
#  ('Edema', 1836),
#  ('Emphysema', 2017),
#  ('Fibrosis', 1336),
#  ('Effusion', 10655),
#  ('Pneumonia', 1154),
#  ('Pleural_Thickening', 2711),
#  ('Cardiomegaly', 2201),
#  ('Nodule', 5082),
#  ('Mass', 4641),
#  ('Hernia', 175)]
# Count: 48995
# [('No Finding', 12117),
#  ('Atelectasis', 2333),
#  ('Consolidation', 928),
#  ('Infiltration', 3994),
#  ('Pneumothorax', 1078),
#  ('Edema', 467),
#  ('Emphysema', 499),
#  ('Fibrosis', 350),
#  ('Effusion', 2662),
#  ('Pneumonia', 277),
#  ('Pleural_Thickening', 674),
#  ('Cardiomegaly', 575),
#  ('Nodule', 1249),
#  ('Mass', 1141),
#  ('Hernia', 52)]
# Count:  22424
# All: 71419
# Model: "under_sampling_5_folds_with_cross_entropy_loss_FOLD_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dense_10 (Dense)            (None, 128)               8028288
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 3063/3063 [==============================] - 392s 123ms/step - loss: 0.2864 - auc_2: 0.5589 - f1_score: 0.0586 - precision_2: 0.2574 - recall_2: 0.0069 - val_loss: 0.2487 - val_auc_2: 0.5186 - val_f1_score: 0.0224 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 3063/3063 [==============================] - 374s 122ms/step - loss: 0.2779 - auc_2: 0.5960 - f1_score: 0.0726 - precision_2: 0.4889 - recall_2: 0.0104 - val_loss: 0.2401 - val_auc_2: 0.6474 - val_f1_score: 0.0492 - val_precision_2: 0.3642 - val_recall_2: 0.0159 - lr: 0.0010
# Epoch 3/100
# 3063/3063 [==============================] - 374s 122ms/step - loss: 0.2753 - auc_2: 0.6133 - f1_score: 0.0804 - precision_2: 0.5146 - recall_2: 0.0166 - val_loss: 0.2367 - val_auc_2: 0.6513 - val_f1_score: 0.0682 - val_precision_2: 0.3877 - val_recall_2: 0.0258 - lr: 0.0010
# Epoch 4/100
# 3063/3063 [==============================] - 373s 122ms/step - loss: 0.2718 - auc_2: 0.6353 - f1_score: 0.0907 - precision_2: 0.5372 - recall_2: 0.0299 - val_loss: 0.2307 - val_auc_2: 0.6721 - val_f1_score: 0.0610 - val_precision_2: 0.4082 - val_recall_2: 0.0243 - lr: 0.0010
# Epoch 5/100
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2693 - auc_2: 0.6511 - f1_score: 0.0954 - precision_2: 0.5532 - recall_2: 0.0421 - val_loss: 0.2331 - val_auc_2: 0.6913 - val_f1_score: 0.0671 - val_precision_2: 0.4383 - val_recall_2: 0.0300 - lr: 0.0010
# Epoch 6/100
# 3063/3063 [==============================] - 373s 122ms/step - loss: 0.2664 - auc_2: 0.6688 - f1_score: 0.1047 - precision_2: 0.5529 - recall_2: 0.0529 - val_loss: 0.2271 - val_auc_2: 0.7016 - val_f1_score: 0.1037 - val_precision_2: 0.4440 - val_recall_2: 0.0323 - lr: 0.0010
# Epoch 7/100
# 3063/3063 [==============================] - 373s 122ms/step - loss: 0.2640 - auc_2: 0.6835 - f1_score: 0.1195 - precision_2: 0.5662 - recall_2: 0.0620 - val_loss: 0.2273 - val_auc_2: 0.7103 - val_f1_score: 0.1051 - val_precision_2: 0.4367 - val_recall_2: 0.0407 - lr: 0.0010
# Epoch 8/100
# 3063/3063 [==============================] - 372s 121ms/step - loss: 0.2633 - auc_2: 0.6853 - f1_score: 0.1246 - precision_2: 0.5702 - recall_2: 0.0639 - val_loss: 0.2322 - val_auc_2: 0.7088 - val_f1_score: 0.0874 - val_precision_2: 0.4581 - val_recall_2: 0.0342 - lr: 0.0010
# Epoch 9/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2627 - auc_2: 0.6874 - f1_score: 0.1259 - precision_2: 0.5719 - recall_2: 0.0658
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2627 - auc_2: 0.6874 - f1_score: 0.1259 - precision_2: 0.5719 - recall_2: 0.0658 - val_loss: 0.2320 - val_auc_2: 0.7097 - val_f1_score: 0.1043 - val_precision_2: 0.4410 - val_recall_2: 0.0396 - lr: 5.0000e-04
# Epoch 10/100
# 3063/3063 [==============================] - 370s 121ms/step - loss: 0.2590 - auc_2: 0.7059 - f1_score: 0.1387 - precision_2: 0.5843 - recall_2: 0.0813 - val_loss: 0.2276 - val_auc_2: 0.7260 - val_f1_score: 0.1197 - val_precision_2: 0.4617 - val_recall_2: 0.0390 - lr: 5.0000e-04
# Epoch 11/100
# 3063/3063 [==============================] - 372s 121ms/step - loss: 0.2567 - auc_2: 0.7155 - f1_score: 0.1459 - precision_2: 0.5932 - recall_2: 0.0900 - val_loss: 0.2260 - val_auc_2: 0.7310 - val_f1_score: 0.1231 - val_precision_2: 0.4546 - val_recall_2: 0.0466 - lr: 5.0000e-04
# Epoch 12/100
# 3063/3063 [==============================] - 372s 121ms/step - loss: 0.2552 - auc_2: 0.7215 - f1_score: 0.1506 - precision_2: 0.5960 - recall_2: 0.0977 - val_loss: 0.2302 - val_auc_2: 0.7320 - val_f1_score: 0.1205 - val_precision_2: 0.4451 - val_recall_2: 0.0486 - lr: 5.0000e-04
# Epoch 13/100
# 3063/3063 [==============================] - 372s 121ms/step - loss: 0.2535 - auc_2: 0.7285 - f1_score: 0.1539 - precision_2: 0.6003 - recall_2: 0.1037 - val_loss: 0.2253 - val_auc_2: 0.7349 - val_f1_score: 0.1314 - val_precision_2: 0.4565 - val_recall_2: 0.0552 - lr: 5.0000e-04
# Epoch 14/100
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2518 - auc_2: 0.7341 - f1_score: 0.1600 - precision_2: 0.6059 - recall_2: 0.1127 - val_loss: 0.2270 - val_auc_2: 0.7345 - val_f1_score: 0.1303 - val_precision_2: 0.4574 - val_recall_2: 0.0635 - lr: 5.0000e-04
# Epoch 15/100
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2503 - auc_2: 0.7407 - f1_score: 0.1637 - precision_2: 0.6094 - recall_2: 0.1195 - val_loss: 0.2307 - val_auc_2: 0.7347 - val_f1_score: 0.1257 - val_precision_2: 0.4434 - val_recall_2: 0.0663 - lr: 5.0000e-04
# Epoch 16/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2488 - auc_2: 0.7457 - f1_score: 0.1691 - precision_2: 0.6096 - recall_2: 0.1279
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2488 - auc_2: 0.7457 - f1_score: 0.1691 - precision_2: 0.6096 - recall_2: 0.1279 - val_loss: 0.2290 - val_auc_2: 0.7359 - val_f1_score: 0.1318 - val_precision_2: 0.4363 - val_recall_2: 0.0755 - lr: 2.5000e-04
# Epoch 17/100
# 3063/3063 [==============================] - 372s 122ms/step - loss: 0.2439 - auc_2: 0.7615 - f1_score: 0.1810 - precision_2: 0.6244 - recall_2: 0.1483 - val_loss: 0.2266 - val_auc_2: 0.7361 - val_f1_score: 0.1405 - val_precision_2: 0.4837 - val_recall_2: 0.0996 - lr: 2.5000e-04
# Epoch 18/100
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2414 - auc_2: 0.7693 - f1_score: 0.1882 - precision_2: 0.6278 - recall_2: 0.1609 - val_loss: 0.2291 - val_auc_2: 0.7340 - val_f1_score: 0.1381 - val_precision_2: 0.4654 - val_recall_2: 0.1018 - lr: 2.5000e-04
# Epoch 19/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2393 - auc_2: 0.7748 - f1_score: 0.1939 - precision_2: 0.6341 - recall_2: 0.1717
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3063/3063 [==============================] - 371s 121ms/step - loss: 0.2393 - auc_2: 0.7748 - f1_score: 0.1939 - precision_2: 0.6341 - recall_2: 0.1717 - val_loss: 0.2284 - val_auc_2: 0.7322 - val_f1_score: 0.1423 - val_precision_2: 0.4774 - val_recall_2: 0.1117 - lr: 1.2500e-04
# Epoch 20/100
# 3063/3063 [==============================] - 372s 121ms/step - loss: 0.2354 - auc_2: 0.7868 - f1_score: 0.2038 - precision_2: 0.6417 - recall_2: 0.1859 - val_loss: 0.2315 - val_auc_2: 0.7311 - val_f1_score: 0.1422 - val_precision_2: 0.4731 - val_recall_2: 0.1393 - lr: 1.2500e-04
# Epoch 21/100
# 3063/3063 [==============================] - 372s 122ms/step - loss: 0.2334 - auc_2: 0.7930 - f1_score: 0.2099 - precision_2: 0.6466 - recall_2: 0.1965 - val_loss: 0.2339 - val_auc_2: 0.7256 - val_f1_score: 0.1422 - val_precision_2: 0.4672 - val_recall_2: 0.1462 - lr: 1.2500e-04
# Epoch 22/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2314 - auc_2: 0.7977 - f1_score: 0.2148 - precision_2: 0.6517 - recall_2: 0.2063
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3063/3063 [==============================] - 372s 121ms/step - loss: 0.2314 - auc_2: 0.7977 - f1_score: 0.2148 - precision_2: 0.6517 - recall_2: 0.2063 - val_loss: 0.2342 - val_auc_2: 0.7250 - val_f1_score: 0.1424 - val_precision_2: 0.4627 - val_recall_2: 0.1508 - lr: 6.2500e-05
# Epoch 23/100
# 3063/3063 [==============================] - 373s 122ms/step - loss: 0.2289 - auc_2: 0.8044 - f1_score: 0.2208 - precision_2: 0.6575 - recall_2: 0.2150 - val_loss: 0.2386 - val_auc_2: 0.7235 - val_f1_score: 0.1406 - val_precision_2: 0.4448 - val_recall_2: 0.1501 - lr: 6.2500e-05
# Epoch 24/100
# 3063/3063 [==============================] - 372s 122ms/step - loss: 0.2277 - auc_2: 0.8068 - f1_score: 0.2249 - precision_2: 0.6604 - recall_2: 0.2220 - val_loss: 0.2384 - val_auc_2: 0.7226 - val_f1_score: 0.1421 - val_precision_2: 0.4542 - val_recall_2: 0.1624 - lr: 6.2500e-05
# Epoch 25/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2265 - auc_2: 0.8088 - f1_score: 0.2275 - precision_2: 0.6629 - recall_2: 0.2270
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3063/3063 [==============================] - 359s 117ms/step - loss: 0.2265 - auc_2: 0.8088 - f1_score: 0.2275 - precision_2: 0.6629 - recall_2: 0.2270 - val_loss: 0.2399 - val_auc_2: 0.7191 - val_f1_score: 0.1427 - val_precision_2: 0.4489 - val_recall_2: 0.1555 - lr: 3.1250e-05
# Epoch 26/100
# 3063/3063 [==============================] - 358s 117ms/step - loss: 0.2251 - auc_2: 0.8126 - f1_score: 0.2318 - precision_2: 0.6665 - recall_2: 0.2317 - val_loss: 0.2394 - val_auc_2: 0.7201 - val_f1_score: 0.1438 - val_precision_2: 0.4549 - val_recall_2: 0.1636 - lr: 3.1250e-05
# Epoch 27/100
# 3063/3063 [==============================] - 358s 117ms/step - loss: 0.2245 - auc_2: 0.8141 - f1_score: 0.2319 - precision_2: 0.6679 - recall_2: 0.2357 - val_loss: 0.2404 - val_auc_2: 0.7198 - val_f1_score: 0.1431 - val_precision_2: 0.4538 - val_recall_2: 0.1673 - lr: 3.1250e-05
# Epoch 28/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2236 - auc_2: 0.8165 - f1_score: 0.2349 - precision_2: 0.6704 - recall_2: 0.2373
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3063/3063 [==============================] - 358s 117ms/step - loss: 0.2236 - auc_2: 0.8165 - f1_score: 0.2349 - precision_2: 0.6704 - recall_2: 0.2373 - val_loss: 0.2407 - val_auc_2: 0.7213 - val_f1_score: 0.1434 - val_precision_2: 0.4548 - val_recall_2: 0.1691 - lr: 1.5625e-05
# Epoch 29/100
# 3063/3063 [==============================] - 358s 117ms/step - loss: 0.2231 - auc_2: 0.8173 - f1_score: 0.2354 - precision_2: 0.6705 - recall_2: 0.2403 - val_loss: 0.2389 - val_auc_2: 0.7227 - val_f1_score: 0.1452 - val_precision_2: 0.4619 - val_recall_2: 0.1750 - lr: 1.5625e-05
# Epoch 30/100
# 3063/3063 [==============================] - 357s 117ms/step - loss: 0.2225 - auc_2: 0.8193 - f1_score: 0.2374 - precision_2: 0.6735 - recall_2: 0.2429 - val_loss: 0.2391 - val_auc_2: 0.7219 - val_f1_score: 0.1452 - val_precision_2: 0.4662 - val_recall_2: 0.1776 - lr: 1.5625e-05
# Epoch 31/100
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2223 - auc_2: 0.8189 - f1_score: 0.2381 - precision_2: 0.6711 - recall_2: 0.2429
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3063/3063 [==============================] - 358s 117ms/step - loss: 0.2223 - auc_2: 0.8189 - f1_score: 0.2381 - precision_2: 0.6711 - recall_2: 0.2429 - val_loss: 0.2389 - val_auc_2: 0.7224 - val_f1_score: 0.1461 - val_precision_2: 0.4656 - val_recall_2: 0.1776 - lr: 7.8125e-06
# Epoch 32/100
# 3063/3063 [==============================] - 359s 117ms/step - loss: 0.2218 - auc_2: 0.8186 - f1_score: 0.2395 - precision_2: 0.6772 - recall_2: 0.2473 - val_loss: 0.2375 - val_auc_2: 0.7241 - val_f1_score: 0.1462 - val_precision_2: 0.4721 - val_recall_2: 0.1819 - lr: 7.8125e-06
# Epoch 33/100
# 3063/3063 [==============================] - 357s 117ms/step - loss: 0.2216 - auc_2: 0.8207 - f1_score: 0.2384 - precision_2: 0.6754 - recall_2: 0.2459 - val_loss: 0.2379 - val_auc_2: 0.7241 - val_f1_score: 0.1459 - val_precision_2: 0.4701 - val_recall_2: 0.1802 - lr: 7.8125e-06
# Epoch 33: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 12172.04 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7544),
#  ('Atelectasis', 9230),
#  ('Consolidation', 3744),
#  ('Infiltration', 15814),
#  ('Pneumothorax', 4234),
#  ('Edema', 1840),
#  ('Emphysema', 2000),
#  ('Fibrosis', 1315),
#  ('Effusion', 10613),
#  ('Pneumonia', 1160),
#  ('Pleural_Thickening', 2694),
#  ('Cardiomegaly', 2251),
#  ('Nodule', 5046),
# ...
# Epoch 22/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.1980 - auc_3: 0.8623 - f1_score: 0.2970 - precision_3: 0.7154 - recall_3: 0.3707
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3052/3052 [==============================] - 357s 117ms/step - loss: 0.1980 - auc_3: 0.8623 - f1_score: 0.2970 - precision_3: 0.7154 - recall_3: 0.3707 - val_loss: 0.2690 - val_auc_3: 0.7090 - val_f1_score: 0.1435 - val_precision_3: 0.4071 - val_recall_3: 0.2322 - lr: 1.5625e-05
# Epoch 23/100
# 3052/3052 [==============================] - 357s 117ms/step - loss: 0.1965 - auc_3: 0.8627 - f1_score: 0.2991 - precision_3: 0.7206 - recall_3: 0.3783 - val_loss: 0.2671 - val_auc_3: 0.7117 - val_f1_score: 0.1455 - val_precision_3: 0.4129 - val_recall_3: 0.2369 - lr: 1.5625e-05
# Epoch 24/100
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.1955 - auc_3: 0.8644 - f1_score: 0.3019 - precision_3: 0.7223 - recall_3: 0.3817 - val_loss: 0.2686 - val_auc_3: 0.7111 - val_f1_score: 0.1449 - val_precision_3: 0.4093 - val_recall_3: 0.2368 - lr: 1.5625e-05
# Epoch 25/100
# 3052/3052 [==============================] - ETA: 0s - loss: 0.1945 - auc_3: 0.8660 - f1_score: 0.3036 - precision_3: 0.7242 - recall_3: 0.3858
# Epoch 25: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3052/3052 [==============================] - 356s 117ms/step - loss: 0.1945 - auc_3: 0.8660 - f1_score: 0.3036 - precision_3: 0.7242 - recall_3: 0.3858 - val_loss: 0.2690 - val_auc_3: 0.7113 - val_f1_score: 0.1454 - val_precision_3: 0.4147 - val_recall_3: 0.2410 - lr: 7.8125e-06
# Epoch 26/100
# 3052/3052 [==============================] - 355s 116ms/step - loss: 0.1938 - auc_3: 0.8670 - f1_score: 0.3047 - precision_3: 0.7244 - recall_3: 0.3897 - val_loss: 0.2679 - val_auc_3: 0.7125 - val_f1_score: 0.1453 - val_precision_3: 0.4152 - val_recall_3: 0.2418 - lr: 7.8125e-06
# Epoch 27/100
# 3052/3052 [==============================] - 358s 117ms/step - loss: 0.1934 - auc_3: 0.8680 - f1_score: 0.3056 - precision_3: 0.7261 - recall_3: 0.3905 - val_loss: 0.2682 - val_auc_3: 0.7124 - val_f1_score: 0.1453 - val_precision_3: 0.4153 - val_recall_3: 0.2431 - lr: 7.8125e-06
# Epoch 27: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 9647.90 second(s) ===== ===== ===== ===== =====
#
#
# [('No Finding', 7551),
#  ('Atelectasis', 9213),
#  ('Consolidation', 3713),
#  ('Infiltration', 15911),
#  ('Pneumothorax', 4265),
#  ('Edema', 1824),
#  ('Emphysema', 2001),
#  ('Fibrosis', 1383),
#  ('Effusion', 10732),
#  ('Pneumonia', 1127),
#  ('Pleural_Thickening', 2698),
#  ('Cardiomegaly', 2249),
#  ('Nodule', 5103),
#  ('Mass', 4594),
#  ('Hernia', 189)]
# Count: 48985
# [('No Finding', 12099),
#  ('Atelectasis', 2346),
#  ('Consolidation', 954),
#  ('Infiltration', 3983),
#  ('Pneumothorax', 1037),
#  ('Edema', 479),
#  ('Emphysema', 515),
#  ('Fibrosis', 303),
#  ('Effusion', 2585),
#  ('Pneumonia', 304),
#  ('Pleural_Thickening', 687),
#  ('Cardiomegaly', 527),
#  ('Nodule', 1228),
#  ('Mass', 1188),
#  ('Hernia', 38)]
# Count:  22424
# All: 71409
# Model: "under_sampling_5_folds_with_cross_entropy_loss_FOLD_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_4 (Flatten)         (None, 62720)             0
#
#  dense_20 (Dense)            (None, 128)               8028288
#
#  dense_21 (Dense)            (None, 128)               16512
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dense_23 (Dense)            (None, 64)                4160
#
#  dense_24 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 12,107,762
# Trainable params: 12,065,739
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 3062/3062 [==============================] - 375s 118ms/step - loss: 0.2860 - auc_4: 0.5587 - f1_score: 0.0533 - precision_4: 0.2706 - recall_4: 0.0062 - val_loss: 0.2443 - val_auc_4: 0.6269 - val_f1_score: 0.0210 - val_precision_4: 0.3699 - val_recall_4: 0.0057 - lr: 0.0010
# Epoch 2/100
# 3062/3062 [==============================] - 353s 115ms/step - loss: 0.2760 - auc_4: 0.6120 - f1_score: 0.0773 - precision_4: 0.4900 - recall_4: 0.0108 - val_loss: 0.2320 - val_auc_4: 0.6691 - val_f1_score: 0.0834 - val_precision_4: 0.3680 - val_recall_4: 0.0174 - lr: 0.0010
# Epoch 3/100
# 3062/3062 [==============================] - 355s 116ms/step - loss: 0.2728 - auc_4: 0.6366 - f1_score: 0.0873 - precision_4: 0.5290 - recall_4: 0.0264 - val_loss: 0.2320 - val_auc_4: 0.6872 - val_f1_score: 0.0759 - val_precision_4: 0.3954 - val_recall_4: 0.0249 - lr: 0.0010
# Epoch 4/100
# 3062/3062 [==============================] - 365s 119ms/step - loss: 0.2683 - auc_4: 0.6618 - f1_score: 0.0984 - precision_4: 0.5458 - recall_4: 0.0440 - val_loss: 0.2371 - val_auc_4: 0.6813 - val_f1_score: 0.0816 - val_precision_4: 0.3690 - val_recall_4: 0.0366 - lr: 0.0010
# Epoch 5/100
# 3062/3062 [==============================] - 363s 119ms/step - loss: 0.2662 - auc_4: 0.6734 - f1_score: 0.1107 - precision_4: 0.5590 - recall_4: 0.0535 - val_loss: 0.2254 - val_auc_4: 0.7046 - val_f1_score: 0.1103 - val_precision_4: 0.3856 - val_recall_4: 0.0491 - lr: 0.0010
# Epoch 6/100
# 3062/3062 [==============================] - 354s 116ms/step - loss: 0.2643 - auc_4: 0.6850 - f1_score: 0.1196 - precision_4: 0.5617 - recall_4: 0.0572 - val_loss: 0.2263 - val_auc_4: 0.7182 - val_f1_score: 0.1122 - val_precision_4: 0.3922 - val_recall_4: 0.0496 - lr: 0.0010
# Epoch 7/100
# 3062/3062 [==============================] - 357s 116ms/step - loss: 0.2654 - auc_4: 0.6791 - f1_score: 0.1177 - precision_4: 0.5623 - recall_4: 0.0568 - val_loss: 0.2273 - val_auc_4: 0.7108 - val_f1_score: 0.1157 - val_precision_4: 0.3853 - val_recall_4: 0.0470 - lr: 0.0010
# Epoch 8/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2636 - auc_4: 0.6889 - f1_score: 0.1239 - precision_4: 0.5637 - recall_4: 0.0635
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2636 - auc_4: 0.6889 - f1_score: 0.1239 - precision_4: 0.5637 - recall_4: 0.0635 - val_loss: 0.2277 - val_auc_4: 0.7154 - val_f1_score: 0.1059 - val_precision_4: 0.3945 - val_recall_4: 0.0457 - lr: 5.0000e-04
# Epoch 9/100
# 3062/3062 [==============================] - 355s 116ms/step - loss: 0.2588 - auc_4: 0.7089 - f1_score: 0.1376 - precision_4: 0.5776 - recall_4: 0.0817 - val_loss: 0.2223 - val_auc_4: 0.7323 - val_f1_score: 0.1281 - val_precision_4: 0.4447 - val_recall_4: 0.0531 - lr: 5.0000e-04
# Epoch 10/100
# 3062/3062 [==============================] - 355s 116ms/step - loss: 0.2567 - auc_4: 0.7191 - f1_score: 0.1457 - precision_4: 0.5867 - recall_4: 0.0911 - val_loss: 0.2224 - val_auc_4: 0.7367 - val_f1_score: 0.1336 - val_precision_4: 0.4751 - val_recall_4: 0.0537 - lr: 5.0000e-04
# Epoch 11/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2547 - auc_4: 0.7265 - f1_score: 0.1534 - precision_4: 0.5936 - recall_4: 0.1000 - val_loss: 0.2228 - val_auc_4: 0.7370 - val_f1_score: 0.1328 - val_precision_4: 0.4663 - val_recall_4: 0.0725 - lr: 5.0000e-04
# Epoch 12/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2539 - auc_4: 0.7305 - f1_score: 0.1567 - precision_4: 0.5935 - recall_4: 0.1049
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2539 - auc_4: 0.7305 - f1_score: 0.1567 - precision_4: 0.5935 - recall_4: 0.1049 - val_loss: 0.2243 - val_auc_4: 0.7250 - val_f1_score: 0.1250 - val_precision_4: 0.4599 - val_recall_4: 0.0568 - lr: 2.5000e-04
# Epoch 13/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2524 - auc_4: 0.7349 - f1_score: 0.1587 - precision_4: 0.6012 - recall_4: 0.1109 - val_loss: 0.2215 - val_auc_4: 0.7426 - val_f1_score: 0.1370 - val_precision_4: 0.4934 - val_recall_4: 0.0845 - lr: 2.5000e-04
# Epoch 14/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2496 - auc_4: 0.7449 - f1_score: 0.1682 - precision_4: 0.6034 - recall_4: 0.1219 - val_loss: 0.2224 - val_auc_4: 0.7438 - val_f1_score: 0.1397 - val_precision_4: 0.4940 - val_recall_4: 0.0984 - lr: 2.5000e-04
# Epoch 15/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2480 - auc_4: 0.7511 - f1_score: 0.1735 - precision_4: 0.6073 - recall_4: 0.1290 - val_loss: 0.2255 - val_auc_4: 0.7371 - val_f1_score: 0.1368 - val_precision_4: 0.4789 - val_recall_4: 0.1017 - lr: 2.5000e-04
# Epoch 16/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2465 - auc_4: 0.7552 - f1_score: 0.1765 - precision_4: 0.6097 - recall_4: 0.1373
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2465 - auc_4: 0.7552 - f1_score: 0.1765 - precision_4: 0.6097 - recall_4: 0.1373 - val_loss: 0.2233 - val_auc_4: 0.7414 - val_f1_score: 0.1414 - val_precision_4: 0.4857 - val_recall_4: 0.1093 - lr: 1.2500e-04
# Epoch 17/100
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2438 - auc_4: 0.7655 - f1_score: 0.1845 - precision_4: 0.6184 - recall_4: 0.1512 - val_loss: 0.2228 - val_auc_4: 0.7432 - val_f1_score: 0.1449 - val_precision_4: 0.4882 - val_recall_4: 0.1280 - lr: 1.2500e-04
# Epoch 18/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2426 - auc_4: 0.7686 - f1_score: 0.1888 - precision_4: 0.6155 - recall_4: 0.1561 - val_loss: 0.2229 - val_auc_4: 0.7424 - val_f1_score: 0.1454 - val_precision_4: 0.4862 - val_recall_4: 0.1340 - lr: 1.2500e-04
# Epoch 19/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2415 - auc_4: 0.7716 - f1_score: 0.1917 - precision_4: 0.6223 - recall_4: 0.1634
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2415 - auc_4: 0.7716 - f1_score: 0.1917 - precision_4: 0.6223 - recall_4: 0.1634 - val_loss: 0.2239 - val_auc_4: 0.7403 - val_f1_score: 0.1456 - val_precision_4: 0.4869 - val_recall_4: 0.1392 - lr: 6.2500e-05
# Epoch 20/100
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2394 - auc_4: 0.7785 - f1_score: 0.1958 - precision_4: 0.6274 - recall_4: 0.1731 - val_loss: 0.2251 - val_auc_4: 0.7396 - val_f1_score: 0.1434 - val_precision_4: 0.4674 - val_recall_4: 0.1400 - lr: 6.2500e-05
# Epoch 21/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2386 - auc_4: 0.7818 - f1_score: 0.1990 - precision_4: 0.6302 - recall_4: 0.1775 - val_loss: 0.2259 - val_auc_4: 0.7370 - val_f1_score: 0.1438 - val_precision_4: 0.4708 - val_recall_4: 0.1452 - lr: 6.2500e-05
# Epoch 22/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2378 - auc_4: 0.7833 - f1_score: 0.2016 - precision_4: 0.6309 - recall_4: 0.1811
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3062/3062 [==============================] - 357s 116ms/step - loss: 0.2378 - auc_4: 0.7833 - f1_score: 0.2016 - precision_4: 0.6309 - recall_4: 0.1811 - val_loss: 0.2270 - val_auc_4: 0.7333 - val_f1_score: 0.1425 - val_precision_4: 0.4596 - val_recall_4: 0.1442 - lr: 3.1250e-05
# Epoch 23/100
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2366 - auc_4: 0.7860 - f1_score: 0.2047 - precision_4: 0.6330 - recall_4: 0.1874 - val_loss: 0.2272 - val_auc_4: 0.7346 - val_f1_score: 0.1433 - val_precision_4: 0.4596 - val_recall_4: 0.1501 - lr: 3.1250e-05
# Epoch 24/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2362 - auc_4: 0.7874 - f1_score: 0.2054 - precision_4: 0.6363 - recall_4: 0.1901 - val_loss: 0.2274 - val_auc_4: 0.7342 - val_f1_score: 0.1439 - val_precision_4: 0.4599 - val_recall_4: 0.1487 - lr: 3.1250e-05
# Epoch 25/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2356 - auc_4: 0.7890 - f1_score: 0.2076 - precision_4: 0.6374 - recall_4: 0.1933
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2356 - auc_4: 0.7890 - f1_score: 0.2076 - precision_4: 0.6374 - recall_4: 0.1933 - val_loss: 0.2274 - val_auc_4: 0.7342 - val_f1_score: 0.1432 - val_precision_4: 0.4635 - val_recall_4: 0.1531 - lr: 1.5625e-05
# Epoch 26/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2350 - auc_4: 0.7896 - f1_score: 0.2091 - precision_4: 0.6395 - recall_4: 0.1960 - val_loss: 0.2276 - val_auc_4: 0.7357 - val_f1_score: 0.1447 - val_precision_4: 0.4609 - val_recall_4: 0.1522 - lr: 1.5625e-05
# Epoch 27/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2345 - auc_4: 0.7924 - f1_score: 0.2082 - precision_4: 0.6399 - recall_4: 0.1982 - val_loss: 0.2284 - val_auc_4: 0.7349 - val_f1_score: 0.1433 - val_precision_4: 0.4574 - val_recall_4: 0.1496 - lr: 1.5625e-05
# Epoch 28/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2344 - auc_4: 0.7916 - f1_score: 0.2091 - precision_4: 0.6380 - recall_4: 0.1983
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2344 - auc_4: 0.7916 - f1_score: 0.2091 - precision_4: 0.6380 - recall_4: 0.1983 - val_loss: 0.2277 - val_auc_4: 0.7357 - val_f1_score: 0.1443 - val_precision_4: 0.4588 - val_recall_4: 0.1511 - lr: 7.8125e-06
# Epoch 29/100
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2339 - auc_4: 0.7934 - f1_score: 0.2100 - precision_4: 0.6408 - recall_4: 0.2006 - val_loss: 0.2281 - val_auc_4: 0.7355 - val_f1_score: 0.1450 - val_precision_4: 0.4607 - val_recall_4: 0.1512 - lr: 7.8125e-06
# Epoch 30/100
# 3062/3062 [==============================] - 359s 117ms/step - loss: 0.2339 - auc_4: 0.7935 - f1_score: 0.2110 - precision_4: 0.6427 - recall_4: 0.2027 - val_loss: 0.2276 - val_auc_4: 0.7340 - val_f1_score: 0.1459 - val_precision_4: 0.4649 - val_recall_4: 0.1544 - lr: 7.8125e-06
# Epoch 31/100
# 3062/3062 [==============================] - ETA: 0s - loss: 0.2338 - auc_4: 0.7942 - f1_score: 0.2109 - precision_4: 0.6421 - recall_4: 0.2032
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2338 - auc_4: 0.7942 - f1_score: 0.2109 - precision_4: 0.6421 - recall_4: 0.2032 - val_loss: 0.2284 - val_auc_4: 0.7330 - val_f1_score: 0.1443 - val_precision_4: 0.4610 - val_recall_4: 0.1527 - lr: 3.9063e-06
# Epoch 32/100
# 3062/3062 [==============================] - 358s 117ms/step - loss: 0.2338 - auc_4: 0.7924 - f1_score: 0.2103 - precision_4: 0.6425 - recall_4: 0.2031 - val_loss: 0.2278 - val_auc_4: 0.7344 - val_f1_score: 0.1447 - val_precision_4: 0.4626 - val_recall_4: 0.1548 - lr: 3.9063e-06
# Epoch 33/100
# 3062/3062 [==============================] - 357s 117ms/step - loss: 0.2336 - auc_4: 0.7945 - f1_score: 0.2133 - precision_4: 0.6419 - recall_4: 0.2036 - val_loss: 0.2276 - val_auc_4: 0.7345 - val_f1_score: 0.1453 - val_precision_4: 0.4624 - val_recall_4: 0.1560 - lr: 3.9063e-06
# Epoch 33: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 11818.97 second(s) ===== ===== ===== ===== =====

# %%
print("Done")
# Out:
# Done
