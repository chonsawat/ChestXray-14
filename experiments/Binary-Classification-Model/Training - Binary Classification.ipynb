# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (3.0.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from typeguard>=2.7->tensorflow_addons) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
import sys
sys.path.append('/home/jovyan/ChestXray-14')

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, TensorBoard
# Out:
# 2023-03-29 15:48:30.027040: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
ROOT_PATH = "/home/jovyan/ChestXray-14"
INPUT_PATH = f"{ROOT_PATH}/dataset/ChestXray NIH"

LABELS = ['No Finding']

weight_option = 'imagenet' # None or 'imagenet'
EXPERIMENT_NAME = "binary_classification_with_cross_entropy_loss"

# %% [markdown]
# tf.keras.mixed_precision
# ---
# make model train faster
# ```python
# tf.keras.mixed_precision.global_policy()
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
# ```

# %%
tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA A100-SXM4-40GB MIG 2g.10gb, compute capability 8.0

# %% [markdown]
# ## Model Training

# %%
import os
CURRENT_PATH = os.path.abspath("")
CURRENT_PATH
# Out:
# '/home/jovyan/ChestXray-14/experiments/Binary-Classification-Model'

# %%
# Learning rate
def lr_schedule(epoch, learning_rate):
    tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
    return learning_rate

# %%
import datetime

def get_callbacks(NAME, weight_option, fold_num=None):
    log_dir = f"{CURRENT_PATH}/logs/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    
    model_checkpoint_callback = ModelCheckpoint(f'results/models/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}.h5', monitor='val_loss', mode='min', save_best_only=True)
    early_stop_callback = EarlyStopping(monitor='val_loss', mode="min", patience=20, verbose=1)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.5, patience=3, verbose=1)
    lr_logging_callback = LearningRateScheduler(lr_schedule)
    
    return model_checkpoint_callback, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback

# %%
# Constant variables
NAME = "EfficientNetB0"
EPOCHS = 100
weight_option = None # use `'imagenet'` or `None` only

# %%
import time
from modules.models import ModelBinaryClassification
from modules.dataset import Dataset

NUM_FOLDS = 5
dataset = Dataset()
for fold_num in range(1, NUM_FOLDS + 1):
    
    # Callbacks
    (
        model_checkpoint_callback, 
        early_stop_callback, 
        reduce_lr_callback, 
        lr_logging_callback, 
        tensorboard_callback
    ) = get_callbacks(
        NAME, weight_option, fold_num
    )

    # Path for CSV
    path = os.path.join(CURRENT_PATH, "results", "history", EXPERIMENT_NAME, f"{NAME}_{weight_option}_FOLD_{fold_num}")
    os.makedirs(path, exist_ok=True)

    # CSV Logger
    csv_logger = CSVLogger(os.path.join(path, f"history.csv"))

    # Dataset
    train_dataset, test_dataset = dataset.get_kfold(fold_num)

    # Modeling
    transfer_model = tf.keras.applications.efficientnet.EfficientNetB0(
        include_top=False, 
        weights=weight_option,
        input_shape=(224, 224, 3),
        pooling=None
    )

    model = ModelBinaryClassification(
        transfer_model,
    )
    model = model.get_model()
    model._name = f"{EXPERIMENT_NAME}_FOLD_{fold_num}"
    model.summary()

    # Record time for training
    start = time.time()
    
    # Visualize
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=test_dataset,
        verbose=1, # Show Progress Bar while Traning
        callbacks=[model_checkpoint_callback, csv_logger, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback]
    )
    
    end = time.time()
    print(
        "===== " * 5,
        "Model Traninig for: {:.2f} second(s)".format(end - start),
        "===== " * 5,
        "\n\n"
    )
# Out:
# 2023-03-29 15:48:33.346821: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 15:48:34.114490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8011 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:31:00.0, compute capability: 8.0
# Model: "binary_classification_with_cross_entropy_loss_FOLD_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 128)               8028288
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12,106,852
# Trainable params: 12,064,829
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 2023-03-29 15:48:49.128850: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-03-29 15:48:49.837060: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-03-29 15:48:49.837882: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-03-29 15:48:49.837903: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-03-29 15:48:49.838643: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-03-29 15:48:49.838699: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 5606/5606 [==============================] - 627s 109ms/step - loss: 0.6859 - accuracy: 8.9190e-05 - auc: 0.5906 - f1_score: 0.6991 - val_loss: 0.6624 - val_accuracy: 0.0000e+00 - val_auc: 0.6370 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 2/100
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6528 - accuracy: 0.0000e+00 - auc: 0.6595 - f1_score: 0.6991 - val_loss: 0.6340 - val_accuracy: 0.0000e+00 - val_auc: 0.6979 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 3/100
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6279 - accuracy: 0.0000e+00 - auc: 0.7017 - f1_score: 0.6991 - val_loss: 0.6178 - val_accuracy: 0.0000e+00 - val_auc: 0.7148 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 4/100
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6155 - accuracy: 0.0000e+00 - auc: 0.7194 - f1_score: 0.6991 - val_loss: 0.6063 - val_accuracy: 0.0000e+00 - val_auc: 0.7330 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 5/100
# 5606/5606 [==============================] - 598s 107ms/step - loss: 0.6056 - accuracy: 0.0000e+00 - auc: 0.7326 - f1_score: 0.6991 - val_loss: 0.6074 - val_accuracy: 0.0000e+00 - val_auc: 0.7298 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 6/100
# 5606/5606 [==============================] - 596s 106ms/step - loss: 0.5989 - accuracy: 0.0000e+00 - auc: 0.7413 - f1_score: 0.6991 - val_loss: 0.5992 - val_accuracy: 0.0000e+00 - val_auc: 0.7424 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 7/100
# 5606/5606 [==============================] - 596s 106ms/step - loss: 0.5915 - accuracy: 0.0000e+00 - auc: 0.7499 - f1_score: 0.6991 - val_loss: 0.5981 - val_accuracy: 0.0000e+00 - val_auc: 0.7425 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 8/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.5848 - accuracy: 0.0000e+00 - auc: 0.7573 - f1_score: 0.6991 - val_loss: 0.6049 - val_accuracy: 0.0000e+00 - val_auc: 0.7407 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 9/100
# 5606/5606 [==============================] - 575s 102ms/step - loss: 0.5792 - accuracy: 0.0000e+00 - auc: 0.7636 - f1_score: 0.6991 - val_loss: 0.5972 - val_accuracy: 0.0000e+00 - val_auc: 0.7433 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 10/100
# 5606/5606 [==============================] - 541s 96ms/step - loss: 0.5746 - accuracy: 1.1149e-05 - auc: 0.7686 - f1_score: 0.6991 - val_loss: 0.6031 - val_accuracy: 0.0000e+00 - val_auc: 0.7425 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 11/100
# 5606/5606 [==============================] - 588s 105ms/step - loss: 0.5685 - accuracy: 0.0000e+00 - auc: 0.7751 - f1_score: 0.6991 - val_loss: 0.6027 - val_accuracy: 0.0000e+00 - val_auc: 0.7421 - val_f1_score: 0.7032 - lr: 0.0010
# Epoch 12/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5632 - accuracy: 2.2298e-05 - auc: 0.7801 - f1_score: 0.6991
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5606/5606 [==============================] - 574s 102ms/step - loss: 0.5632 - accuracy: 2.2298e-05 - auc: 0.7801 - f1_score: 0.6991 - val_loss: 0.6052 - val_accuracy: 0.0000e+00 - val_auc: 0.7400 - val_f1_score: 0.7032 - lr: 5.0000e-04
# Epoch 13/100
# 5606/5606 [==============================] - 580s 103ms/step - loss: 0.5407 - accuracy: 2.2298e-05 - auc: 0.8014 - f1_score: 0.6991 - val_loss: 0.6208 - val_accuracy: 0.0000e+00 - val_auc: 0.7350 - val_f1_score: 0.7032 - lr: 5.0000e-04
# Epoch 14/100
# 5606/5606 [==============================] - 580s 104ms/step - loss: 0.5211 - accuracy: 7.8041e-05 - auc: 0.8183 - f1_score: 0.6991 - val_loss: 0.6408 - val_accuracy: 0.0000e+00 - val_auc: 0.7292 - val_f1_score: 0.7032 - lr: 5.0000e-04
# Epoch 15/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 4.4595e-05 - auc: 0.8333 - f1_score: 0.6991
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5606/5606 [==============================] - 562s 100ms/step - loss: 0.5024 - accuracy: 4.4595e-05 - auc: 0.8333 - f1_score: 0.6991 - val_loss: 0.6592 - val_accuracy: 0.0000e+00 - val_auc: 0.7249 - val_f1_score: 0.7032 - lr: 2.5000e-04
# Epoch 16/100
# 5606/5606 [==============================] - 588s 105ms/step - loss: 0.4738 - accuracy: 3.3446e-04 - auc: 0.8542 - f1_score: 0.6991 - val_loss: 0.7081 - val_accuracy: 4.4595e-05 - val_auc: 0.7076 - val_f1_score: 0.7032 - lr: 2.5000e-04
# Epoch 17/100
# 5606/5606 [==============================] - 594s 106ms/step - loss: 0.4553 - accuracy: 4.5710e-04 - auc: 0.8665 - f1_score: 0.6991 - val_loss: 0.7320 - val_accuracy: 4.0136e-04 - val_auc: 0.7018 - val_f1_score: 0.7032 - lr: 2.5000e-04
# Epoch 18/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4381 - accuracy: 8.6960e-04 - auc: 0.8774 - f1_score: 0.6991
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5606/5606 [==============================] - 596s 106ms/step - loss: 0.4381 - accuracy: 8.6960e-04 - auc: 0.8774 - f1_score: 0.6991 - val_loss: 0.7383 - val_accuracy: 1.7838e-04 - val_auc: 0.6985 - val_f1_score: 0.7032 - lr: 1.2500e-04
# Epoch 19/100
# 5606/5606 [==============================] - 597s 106ms/step - loss: 0.4202 - accuracy: 0.0014 - auc: 0.8879 - f1_score: 0.6991 - val_loss: 0.8027 - val_accuracy: 8.4731e-04 - val_auc: 0.6914 - val_f1_score: 0.7032 - lr: 1.2500e-04
# Epoch 20/100
# 5606/5606 [==============================] - 592s 106ms/step - loss: 0.4045 - accuracy: 0.0024 - auc: 0.8967 - f1_score: 0.6991 - val_loss: 0.8407 - val_accuracy: 0.0018 - val_auc: 0.6906 - val_f1_score: 0.7032 - lr: 1.2500e-04
# Epoch 21/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.3928 - accuracy: 0.0034 - auc: 0.9030 - f1_score: 0.6991
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.3928 - accuracy: 0.0034 - auc: 0.9030 - f1_score: 0.6991 - val_loss: 0.8628 - val_accuracy: 0.0025 - val_auc: 0.6872 - val_f1_score: 0.7032 - lr: 6.2500e-05
# Epoch 22/100
# 5606/5606 [==============================] - 595s 106ms/step - loss: 0.3890 - accuracy: 0.0042 - auc: 0.9050 - f1_score: 0.6991 - val_loss: 0.8778 - val_accuracy: 0.0030 - val_auc: 0.6865 - val_f1_score: 0.7032 - lr: 6.2500e-05
# Epoch 23/100
# 5606/5606 [==============================] - 594s 106ms/step - loss: 0.3788 - accuracy: 0.0061 - auc: 0.9101 - f1_score: 0.6991 - val_loss: 0.8965 - val_accuracy: 0.0041 - val_auc: 0.6849 - val_f1_score: 0.7032 - lr: 6.2500e-05
# Epoch 24/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.0070 - auc: 0.9132 - f1_score: 0.6991
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 5606/5606 [==============================] - 594s 106ms/step - loss: 0.3723 - accuracy: 0.0070 - auc: 0.9132 - f1_score: 0.6991 - val_loss: 0.9113 - val_accuracy: 0.0041 - val_auc: 0.6827 - val_f1_score: 0.7032 - lr: 3.1250e-05
# Epoch 25/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.3732 - accuracy: 0.0065 - auc: 0.9130 - f1_score: 0.6992 - val_loss: 0.8960 - val_accuracy: 0.0040 - val_auc: 0.6834 - val_f1_score: 0.7032 - lr: 3.1250e-05
# Epoch 26/100
# 5606/5606 [==============================] - 592s 106ms/step - loss: 0.3697 - accuracy: 0.0071 - auc: 0.9145 - f1_score: 0.6992 - val_loss: 0.9103 - val_accuracy: 0.0059 - val_auc: 0.6847 - val_f1_score: 0.7032 - lr: 3.1250e-05
# Epoch 27/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.0078 - auc: 0.9182 - f1_score: 0.6992
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 5606/5606 [==============================] - 597s 107ms/step - loss: 0.3620 - accuracy: 0.0078 - auc: 0.9182 - f1_score: 0.6992 - val_loss: 0.9299 - val_accuracy: 0.0057 - val_auc: 0.6821 - val_f1_score: 0.7032 - lr: 1.5625e-05
# Epoch 28/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.3631 - accuracy: 0.0078 - auc: 0.9177 - f1_score: 0.6992 - val_loss: 0.9177 - val_accuracy: 0.0062 - val_auc: 0.6841 - val_f1_score: 0.7032 - lr: 1.5625e-05
# Epoch 29/100
# 5606/5606 [==============================] - 600s 107ms/step - loss: 0.3572 - accuracy: 0.0086 - auc: 0.9204 - f1_score: 0.6993 - val_loss: 0.9226 - val_accuracy: 0.0060 - val_auc: 0.6839 - val_f1_score: 0.7032 - lr: 1.5625e-05
# Epoch 29: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 17132.55 second(s) ===== ===== ===== ===== =====
#
#
# Model: "binary_classification_with_cross_entropy_loss_FOLD_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_1 (Flatten)         (None, 62720)             0
#
#  dense_5 (Dense)             (None, 128)               8028288
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12,106,852
# Trainable params: 12,064,829
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 5606/5606 [==============================] - 614s 108ms/step - loss: 0.6841 - accuracy: 8.9190e-05 - auc_1: 0.5925 - f1_score: 0.7002 - val_loss: 0.6959 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5461 - val_f1_score: 0.6987 - lr: 0.0010
# Epoch 2/100
# 5606/5606 [==============================] - 601s 107ms/step - loss: 0.6839 - accuracy: 0.0000e+00 - auc_1: 0.5620 - f1_score: 0.7002 - val_loss: 0.6901 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 0.0010
# Epoch 3/100
# 5606/5606 [==============================] - 598s 107ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_1: 0.4995 - f1_score: 0.7002 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 0.0010
# Epoch 4/100
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4991 - f1_score: 0.7002 - val_loss: 0.6908 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 0.0010
# Epoch 5/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4993 - f1_score: 0.7002
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5606/5606 [==============================] - 600s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4993 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 5.0000e-04
# Epoch 6/100
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4995 - f1_score: 0.7002 - val_loss: 0.6906 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 5.0000e-04
# Epoch 7/100
# 5606/5606 [==============================] - 600s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4989 - f1_score: 0.7002 - val_loss: 0.6903 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 5.0000e-04
# Epoch 8/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4990 - f1_score: 0.7002
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4990 - f1_score: 0.7002 - val_loss: 0.6903 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 2.5000e-04
# Epoch 9/100
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4983 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 2.5000e-04
# Epoch 10/100
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4976 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 2.5000e-04
# Epoch 11/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4982 - f1_score: 0.7002
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5606/5606 [==============================] - 601s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4982 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 1.2500e-04
# Epoch 12/100
# 5606/5606 [==============================] - 600s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4992 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 1.2500e-04
# Epoch 13/100
# 5606/5606 [==============================] - 597s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4987 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 1.2500e-04
# Epoch 14/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4989 - f1_score: 0.7002
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 5606/5606 [==============================] - 601s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4989 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 6.2500e-05
# Epoch 15/100
# 5606/5606 [==============================] - 597s 106ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4987 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 6.2500e-05
# Epoch 16/100
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4983 - f1_score: 0.7002 - val_loss: 0.6906 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 6.2500e-05
# Epoch 17/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4981 - f1_score: 0.7002
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 5606/5606 [==============================] - 598s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.4981 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 3.1250e-05
# Epoch 18/100
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.5000 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 3.1250e-05
# Epoch 19/100
# 5606/5606 [==============================] - 599s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.5000 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 3.1250e-05
# Epoch 20/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.5000 - f1_score: 0.7002
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 5606/5606 [==============================] - 601s 107ms/step - loss: 0.6902 - accuracy: 0.0000e+00 - auc_1: 0.5000 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 1.5625e-05
# Epoch 21/100
# 5606/5606 [==============================] - 598s 107ms/step - loss: 0.6901 - accuracy: 0.0000e+00 - auc_1: 0.5000 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 1.5625e-05
# Epoch 22/100
# 5606/5606 [==============================] - 600s 107ms/step - loss: 0.6901 - accuracy: 0.0000e+00 - auc_1: 0.5000 - f1_score: 0.7002 - val_loss: 0.6905 - val_accuracy: 0.0000e+00 - val_auc_1: 0.5000 - val_f1_score: 0.6987 - lr: 1.5625e-05
# Epoch 22: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 13205.95 second(s) ===== ===== ===== ===== =====
#
#
# Model: "binary_classification_with_cross_entropy_loss_FOLD_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dense_10 (Dense)            (None, 128)               8028288
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12,106,852
# Trainable params: 12,064,829
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 5606/5606 [==============================] - 624s 109ms/step - loss: 0.6877 - accuracy: 7.8041e-05 - auc_2: 0.5728 - f1_score: 0.6995 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_2: 0.5633 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 2/100
# 5606/5606 [==============================] - 610s 109ms/step - loss: 0.6611 - accuracy: 0.0000e+00 - auc_2: 0.6404 - f1_score: 0.6995 - val_loss: 0.6645 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6339 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 3/100
# 5606/5606 [==============================] - 613s 109ms/step - loss: 0.6559 - accuracy: 7.8041e-05 - auc_2: 0.6523 - f1_score: 0.6995 - val_loss: 0.6573 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6606 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 4/100
# 5606/5606 [==============================] - 608s 108ms/step - loss: 0.6613 - accuracy: 6.6893e-05 - auc_2: 0.6406 - f1_score: 0.6995 - val_loss: 0.6569 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6518 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 5/100
# 5606/5606 [==============================] - 591s 105ms/step - loss: 0.6581 - accuracy: 0.0000e+00 - auc_2: 0.6461 - f1_score: 0.6995 - val_loss: 0.6533 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6567 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 6/100
# 5606/5606 [==============================] - 608s 108ms/step - loss: 0.6539 - accuracy: 1.1149e-05 - auc_2: 0.6545 - f1_score: 0.6995 - val_loss: 0.6431 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6751 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 7/100
# 5606/5606 [==============================] - 605s 108ms/step - loss: 0.6429 - accuracy: 0.0000e+00 - auc_2: 0.6767 - f1_score: 0.6995 - val_loss: 0.6348 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6901 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 8/100
# 5606/5606 [==============================] - 610s 109ms/step - loss: 0.6351 - accuracy: 0.0000e+00 - auc_2: 0.6894 - f1_score: 0.6995 - val_loss: 0.6345 - val_accuracy: 0.0000e+00 - val_auc_2: 0.6975 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 9/100
# 5606/5606 [==============================] - 613s 109ms/step - loss: 0.6289 - accuracy: 0.0000e+00 - auc_2: 0.6994 - f1_score: 0.6995 - val_loss: 0.6289 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7035 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 10/100
# 5606/5606 [==============================] - 591s 105ms/step - loss: 0.6263 - accuracy: 0.0000e+00 - auc_2: 0.7033 - f1_score: 0.6995 - val_loss: 0.6236 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7171 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 11/100
# 5606/5606 [==============================] - 610s 109ms/step - loss: 0.6177 - accuracy: 0.0000e+00 - auc_2: 0.7162 - f1_score: 0.6995 - val_loss: 0.6105 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7266 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 12/100
# 5606/5606 [==============================] - 609s 109ms/step - loss: 0.6071 - accuracy: 0.0000e+00 - auc_2: 0.7302 - f1_score: 0.6995 - val_loss: 0.6111 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7294 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 13/100
# 5606/5606 [==============================] - 605s 108ms/step - loss: 0.6012 - accuracy: 0.0000e+00 - auc_2: 0.7380 - f1_score: 0.6995 - val_loss: 0.6032 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7367 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 14/100
# 5606/5606 [==============================] - 607s 108ms/step - loss: 0.5956 - accuracy: 0.0000e+00 - auc_2: 0.7446 - f1_score: 0.6995 - val_loss: 0.6013 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7409 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 15/100
# 5606/5606 [==============================] - 612s 109ms/step - loss: 0.5908 - accuracy: 0.0000e+00 - auc_2: 0.7501 - f1_score: 0.6995 - val_loss: 0.6046 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7372 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 16/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.5872 - accuracy: 0.0000e+00 - auc_2: 0.7542 - f1_score: 0.6995 - val_loss: 0.5993 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7409 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 17/100
# 5606/5606 [==============================] - 610s 109ms/step - loss: 0.5825 - accuracy: 0.0000e+00 - auc_2: 0.7596 - f1_score: 0.6995 - val_loss: 0.6016 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7413 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 18/100
# 5606/5606 [==============================] - 612s 109ms/step - loss: 0.5788 - accuracy: 1.1149e-05 - auc_2: 0.7640 - f1_score: 0.6995 - val_loss: 0.6017 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7392 - val_f1_score: 0.7016 - lr: 0.0010
# Epoch 19/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.0000e+00 - auc_2: 0.7702 - f1_score: 0.6995
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5606/5606 [==============================] - 607s 108ms/step - loss: 0.5727 - accuracy: 0.0000e+00 - auc_2: 0.7702 - f1_score: 0.6995 - val_loss: 0.6102 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7360 - val_f1_score: 0.7016 - lr: 5.0000e-04
# Epoch 20/100
# 5606/5606 [==============================] - 609s 109ms/step - loss: 0.5573 - accuracy: 0.0000e+00 - auc_2: 0.7855 - f1_score: 0.6995 - val_loss: 0.6128 - val_accuracy: 0.0000e+00 - val_auc_2: 0.7371 - val_f1_score: 0.7016 - lr: 5.0000e-04
# Epoch 21/100
# 5606/5606 [==============================] - 612s 109ms/step - loss: 0.5483 - accuracy: 3.3446e-05 - auc_2: 0.7938 - f1_score: 0.6995 - val_loss: 0.6249 - val_accuracy: 1.7838e-04 - val_auc_2: 0.7335 - val_f1_score: 0.7016 - lr: 5.0000e-04
# Epoch 22/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 1.3379e-04 - auc_2: 0.8025 - f1_score: 0.6995
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5606/5606 [==============================] - 610s 109ms/step - loss: 0.5392 - accuracy: 1.3379e-04 - auc_2: 0.8025 - f1_score: 0.6995 - val_loss: 0.6300 - val_accuracy: 1.7838e-04 - val_auc_2: 0.7307 - val_f1_score: 0.7016 - lr: 2.5000e-04
# Epoch 23/100
# 5606/5606 [==============================] - 605s 108ms/step - loss: 0.5244 - accuracy: 6.4663e-04 - auc_2: 0.8152 - f1_score: 0.6995 - val_loss: 0.6471 - val_accuracy: 5.7974e-04 - val_auc_2: 0.7240 - val_f1_score: 0.7016 - lr: 2.5000e-04
# Epoch 24/100
# 5606/5606 [==============================] - 603s 108ms/step - loss: 0.5150 - accuracy: 9.2535e-04 - auc_2: 0.8228 - f1_score: 0.6995 - val_loss: 0.6626 - val_accuracy: 8.4731e-04 - val_auc_2: 0.7233 - val_f1_score: 0.7016 - lr: 2.5000e-04
# Epoch 25/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5082 - accuracy: 0.0014 - auc_2: 0.8282 - f1_score: 0.6995
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5606/5606 [==============================] - 609s 109ms/step - loss: 0.5082 - accuracy: 0.0014 - auc_2: 0.8282 - f1_score: 0.6995 - val_loss: 0.6710 - val_accuracy: 0.0018 - val_auc_2: 0.7212 - val_f1_score: 0.7015 - lr: 1.2500e-04
# Epoch 26/100
# 5606/5606 [==============================] - 606s 108ms/step - loss: 0.4987 - accuracy: 0.0023 - auc_2: 0.8355 - f1_score: 0.6995 - val_loss: 0.6902 - val_accuracy: 0.0032 - val_auc_2: 0.7185 - val_f1_score: 0.7016 - lr: 1.2500e-04
# Epoch 27/100
# 5606/5606 [==============================] - 607s 108ms/step - loss: 0.4918 - accuracy: 0.0031 - auc_2: 0.8405 - f1_score: 0.6995 - val_loss: 0.7026 - val_accuracy: 0.0040 - val_auc_2: 0.7156 - val_f1_score: 0.7015 - lr: 1.2500e-04
# Epoch 28/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.0030 - auc_2: 0.8450 - f1_score: 0.6995
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 5606/5606 [==============================] - 600s 107ms/step - loss: 0.4859 - accuracy: 0.0030 - auc_2: 0.8450 - f1_score: 0.6995 - val_loss: 0.7026 - val_accuracy: 0.0033 - val_auc_2: 0.7144 - val_f1_score: 0.7016 - lr: 6.2500e-05
# Epoch 29/100
# 5606/5606 [==============================] - 608s 108ms/step - loss: 0.4828 - accuracy: 0.0030 - auc_2: 0.8473 - f1_score: 0.6995 - val_loss: 0.6991 - val_accuracy: 0.0028 - val_auc_2: 0.7139 - val_f1_score: 0.7016 - lr: 6.2500e-05
# Epoch 30/100
# 5606/5606 [==============================] - 607s 108ms/step - loss: 0.4779 - accuracy: 0.0035 - auc_2: 0.8505 - f1_score: 0.6996 - val_loss: 0.7083 - val_accuracy: 0.0033 - val_auc_2: 0.7120 - val_f1_score: 0.7016 - lr: 6.2500e-05
# Epoch 31/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.0039 - auc_2: 0.8527 - f1_score: 0.6995
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 5606/5606 [==============================] - 606s 108ms/step - loss: 0.4749 - accuracy: 0.0039 - auc_2: 0.8527 - f1_score: 0.6995 - val_loss: 0.7084 - val_accuracy: 0.0036 - val_auc_2: 0.7132 - val_f1_score: 0.7016 - lr: 3.1250e-05
# Epoch 32/100
# 5606/5606 [==============================] - 608s 108ms/step - loss: 0.4741 - accuracy: 0.0048 - auc_2: 0.8532 - f1_score: 0.6995 - val_loss: 0.7071 - val_accuracy: 0.0039 - val_auc_2: 0.7133 - val_f1_score: 0.7015 - lr: 3.1250e-05
# Epoch 33/100
# 5606/5606 [==============================] - 608s 108ms/step - loss: 0.4702 - accuracy: 0.0055 - auc_2: 0.8558 - f1_score: 0.6996 - val_loss: 0.7156 - val_accuracy: 0.0045 - val_auc_2: 0.7120 - val_f1_score: 0.7015 - lr: 3.1250e-05
# Epoch 34/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.0052 - auc_2: 0.8576 - f1_score: 0.6996
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 5606/5606 [==============================] - 611s 109ms/step - loss: 0.4679 - accuracy: 0.0052 - auc_2: 0.8576 - f1_score: 0.6996 - val_loss: 0.7195 - val_accuracy: 0.0043 - val_auc_2: 0.7107 - val_f1_score: 0.7014 - lr: 1.5625e-05
# Epoch 35/100
# 5606/5606 [==============================] - 613s 109ms/step - loss: 0.4691 - accuracy: 0.0054 - auc_2: 0.8566 - f1_score: 0.6996 - val_loss: 0.7236 - val_accuracy: 0.0046 - val_auc_2: 0.7096 - val_f1_score: 0.7015 - lr: 1.5625e-05
# Epoch 36/100
# 5606/5606 [==============================] - 610s 109ms/step - loss: 0.4666 - accuracy: 0.0056 - auc_2: 0.8584 - f1_score: 0.6996 - val_loss: 0.7268 - val_accuracy: 0.0050 - val_auc_2: 0.7101 - val_f1_score: 0.7015 - lr: 1.5625e-05
# Epoch 36: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 21872.29 second(s) ===== ===== ===== ===== =====
#
#
# Model: "binary_classification_with_cross_entropy_loss_FOLD_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_3 (Flatten)         (None, 62720)             0
#
#  dense_15 (Dense)            (None, 128)               8028288
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12,106,852
# Trainable params: 12,064,829
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 5606/5606 [==============================] - 618s 108ms/step - loss: 0.6815 - accuracy: 1.6723e-04 - auc_3: 0.6014 - f1_score: 0.7011 - val_loss: 0.6556 - val_accuracy: 0.0000e+00 - val_auc_3: 0.6529 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 2/100
# 5606/5606 [==============================] - 609s 109ms/step - loss: 0.6680 - accuracy: 0.0000e+00 - auc_3: 0.6233 - f1_score: 0.7011 - val_loss: 0.6494 - val_accuracy: 0.0000e+00 - val_auc_3: 0.6654 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 3/100
# 5606/5606 [==============================] - 605s 108ms/step - loss: 0.6537 - accuracy: 0.0000e+00 - auc_3: 0.6562 - f1_score: 0.7011 - val_loss: 0.6458 - val_accuracy: 0.0000e+00 - val_auc_3: 0.6795 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 4/100
# 5606/5606 [==============================] - 605s 108ms/step - loss: 0.6459 - accuracy: 1.1149e-05 - auc_3: 0.6721 - f1_score: 0.7011 - val_loss: 0.6373 - val_accuracy: 0.0000e+00 - val_auc_3: 0.6880 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 5/100
# 5606/5606 [==============================] - 597s 106ms/step - loss: 0.6361 - accuracy: 0.0000e+00 - auc_3: 0.6878 - f1_score: 0.7011 - val_loss: 0.6294 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7003 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 6/100
# 5606/5606 [==============================] - 591s 105ms/step - loss: 0.6271 - accuracy: 0.0000e+00 - auc_3: 0.7018 - f1_score: 0.7011 - val_loss: 0.6204 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7131 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 7/100
# 5606/5606 [==============================] - 594s 106ms/step - loss: 0.6209 - accuracy: 0.0000e+00 - auc_3: 0.7113 - f1_score: 0.7011 - val_loss: 0.6164 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7204 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 8/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.6145 - accuracy: 0.0000e+00 - auc_3: 0.7199 - f1_score: 0.7011 - val_loss: 0.6097 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7300 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 9/100
# 5606/5606 [==============================] - 595s 106ms/step - loss: 0.6085 - accuracy: 0.0000e+00 - auc_3: 0.7280 - f1_score: 0.7011 - val_loss: 0.6060 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7336 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 10/100
# 5606/5606 [==============================] - 594s 106ms/step - loss: 0.6034 - accuracy: 0.0000e+00 - auc_3: 0.7344 - f1_score: 0.7011 - val_loss: 0.6003 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7403 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 11/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.5994 - accuracy: 0.0000e+00 - auc_3: 0.7401 - f1_score: 0.7011 - val_loss: 0.5997 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7419 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 12/100
# 5606/5606 [==============================] - 595s 106ms/step - loss: 0.5945 - accuracy: 0.0000e+00 - auc_3: 0.7458 - f1_score: 0.7011 - val_loss: 0.6036 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7400 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 13/100
# 5606/5606 [==============================] - 595s 106ms/step - loss: 0.5908 - accuracy: 0.0000e+00 - auc_3: 0.7504 - f1_score: 0.7011 - val_loss: 0.6038 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7407 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 14/100
# 5606/5606 [==============================] - 595s 106ms/step - loss: 0.5868 - accuracy: 1.1149e-05 - auc_3: 0.7549 - f1_score: 0.7011 - val_loss: 0.5984 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7456 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 15/100
# 5606/5606 [==============================] - 593s 106ms/step - loss: 0.5837 - accuracy: 1.1149e-05 - auc_3: 0.7583 - f1_score: 0.7011 - val_loss: 0.5986 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7468 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 16/100
# 5606/5606 [==============================] - 594s 106ms/step - loss: 0.5790 - accuracy: 5.5744e-05 - auc_3: 0.7636 - f1_score: 0.7011 - val_loss: 0.5973 - val_accuracy: 4.4595e-05 - val_auc_3: 0.7465 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 17/100
# 5606/5606 [==============================] - 592s 106ms/step - loss: 0.5748 - accuracy: 1.1149e-04 - auc_3: 0.7683 - f1_score: 0.7011 - val_loss: 0.6120 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7408 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 18/100
# 5606/5606 [==============================] - 571s 102ms/step - loss: 0.5693 - accuracy: 5.5744e-05 - auc_3: 0.7739 - f1_score: 0.7011 - val_loss: 0.6043 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7414 - val_f1_score: 0.6951 - lr: 0.0010
# Epoch 19/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5657 - accuracy: 1.8953e-04 - auc_3: 0.7778 - f1_score: 0.7011
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5606/5606 [==============================] - 573s 102ms/step - loss: 0.5657 - accuracy: 1.8953e-04 - auc_3: 0.7778 - f1_score: 0.7011 - val_loss: 0.6092 - val_accuracy: 0.0000e+00 - val_auc_3: 0.7416 - val_f1_score: 0.6951 - lr: 5.0000e-04
# Epoch 20/100
# 5606/5606 [==============================] - 553s 99ms/step - loss: 0.5469 - accuracy: 2.2298e-04 - auc_3: 0.7954 - f1_score: 0.7011 - val_loss: 0.6190 - val_accuracy: 4.4595e-05 - val_auc_3: 0.7385 - val_f1_score: 0.6951 - lr: 5.0000e-04
# Epoch 21/100
# 5606/5606 [==============================] - 549s 98ms/step - loss: 0.5359 - accuracy: 4.1250e-04 - auc_3: 0.8053 - f1_score: 0.7011 - val_loss: 0.6211 - val_accuracy: 3.1217e-04 - val_auc_3: 0.7369 - val_f1_score: 0.6951 - lr: 5.0000e-04
# Epoch 22/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 9.3650e-04 - auc_3: 0.8132 - f1_score: 0.7011
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5606/5606 [==============================] - 538s 96ms/step - loss: 0.5269 - accuracy: 9.3650e-04 - auc_3: 0.8132 - f1_score: 0.7011 - val_loss: 0.6310 - val_accuracy: 3.1217e-04 - val_auc_3: 0.7331 - val_f1_score: 0.6951 - lr: 2.5000e-04
# Epoch 23/100
# 5606/5606 [==============================] - 542s 97ms/step - loss: 0.5093 - accuracy: 0.0011 - auc_3: 0.8273 - f1_score: 0.7011 - val_loss: 0.6614 - val_accuracy: 0.0012 - val_auc_3: 0.7268 - val_f1_score: 0.6951 - lr: 2.5000e-04
# Epoch 24/100
# 5606/5606 [==============================] - 561s 100ms/step - loss: 0.4981 - accuracy: 0.0015 - auc_3: 0.8361 - f1_score: 0.7011 - val_loss: 0.6698 - val_accuracy: 0.0013 - val_auc_3: 0.7210 - val_f1_score: 0.6951 - lr: 2.5000e-04
# Epoch 25/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.0020 - auc_3: 0.8437 - f1_score: 0.7011
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5606/5606 [==============================] - 583s 104ms/step - loss: 0.4875 - accuracy: 0.0020 - auc_3: 0.8437 - f1_score: 0.7011 - val_loss: 0.6802 - val_accuracy: 0.0018 - val_auc_3: 0.7210 - val_f1_score: 0.6951 - lr: 1.2500e-04
# Epoch 26/100
# 5606/5606 [==============================] - 552s 98ms/step - loss: 0.4761 - accuracy: 0.0026 - auc_3: 0.8517 - f1_score: 0.7011 - val_loss: 0.7051 - val_accuracy: 0.0032 - val_auc_3: 0.7150 - val_f1_score: 0.6951 - lr: 1.2500e-04
# Epoch 27/100
# 5606/5606 [==============================] - 546s 97ms/step - loss: 0.4668 - accuracy: 0.0034 - auc_3: 0.8581 - f1_score: 0.7011 - val_loss: 0.7157 - val_accuracy: 0.0035 - val_auc_3: 0.7130 - val_f1_score: 0.6951 - lr: 1.2500e-04
# Epoch 28/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4594 - accuracy: 0.0038 - auc_3: 0.8630 - f1_score: 0.7012
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 5606/5606 [==============================] - 523s 93ms/step - loss: 0.4594 - accuracy: 0.0038 - auc_3: 0.8630 - f1_score: 0.7012 - val_loss: 0.7327 - val_accuracy: 0.0045 - val_auc_3: 0.7108 - val_f1_score: 0.6951 - lr: 6.2500e-05
# Epoch 29/100
# 5606/5606 [==============================] - 525s 94ms/step - loss: 0.4541 - accuracy: 0.0044 - auc_3: 0.8664 - f1_score: 0.7011 - val_loss: 0.7334 - val_accuracy: 0.0039 - val_auc_3: 0.7125 - val_f1_score: 0.6951 - lr: 6.2500e-05
# Epoch 30/100
# 5606/5606 [==============================] - 561s 100ms/step - loss: 0.4489 - accuracy: 0.0047 - auc_3: 0.8697 - f1_score: 0.7012 - val_loss: 0.7405 - val_accuracy: 0.0040 - val_auc_3: 0.7117 - val_f1_score: 0.6951 - lr: 6.2500e-05
# Epoch 31/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4444 - accuracy: 0.0055 - auc_3: 0.8725 - f1_score: 0.7012
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 5606/5606 [==============================] - 603s 108ms/step - loss: 0.4444 - accuracy: 0.0055 - auc_3: 0.8725 - f1_score: 0.7012 - val_loss: 0.7520 - val_accuracy: 0.0049 - val_auc_3: 0.7087 - val_f1_score: 0.6952 - lr: 3.1250e-05
# Epoch 32/100
# 5606/5606 [==============================] - 545s 97ms/step - loss: 0.4435 - accuracy: 0.0056 - auc_3: 0.8733 - f1_score: 0.7012 - val_loss: 0.7504 - val_accuracy: 0.0052 - val_auc_3: 0.7110 - val_f1_score: 0.6952 - lr: 3.1250e-05
# Epoch 33/100
# 5606/5606 [==============================] - 552s 99ms/step - loss: 0.4398 - accuracy: 0.0060 - auc_3: 0.8754 - f1_score: 0.7012 - val_loss: 0.7574 - val_accuracy: 0.0054 - val_auc_3: 0.7093 - val_f1_score: 0.6952 - lr: 3.1250e-05
# Epoch 34/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.4374 - accuracy: 0.0063 - auc_3: 0.8768 - f1_score: 0.7012
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 5606/5606 [==============================] - 553s 99ms/step - loss: 0.4374 - accuracy: 0.0063 - auc_3: 0.8768 - f1_score: 0.7012 - val_loss: 0.7627 - val_accuracy: 0.0060 - val_auc_3: 0.7086 - val_f1_score: 0.6952 - lr: 1.5625e-05
# Epoch 35/100
# 5606/5606 [==============================] - 555s 99ms/step - loss: 0.4366 - accuracy: 0.0066 - auc_3: 0.8773 - f1_score: 0.7013 - val_loss: 0.7597 - val_accuracy: 0.0057 - val_auc_3: 0.7087 - val_f1_score: 0.6952 - lr: 1.5625e-05
# Epoch 36/100
# 5606/5606 [==============================] - 553s 99ms/step - loss: 0.4359 - accuracy: 0.0066 - auc_3: 0.8777 - f1_score: 0.7013 - val_loss: 0.7657 - val_accuracy: 0.0059 - val_auc_3: 0.7084 - val_f1_score: 0.6952 - lr: 1.5625e-05
# Epoch 36: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 20699.28 second(s) ===== ===== ===== ===== =====
#
#
# Model: "binary_classification_with_cross_entropy_loss_FOLD_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_4 (Flatten)         (None, 62720)             0
#
#  dense_20 (Dense)            (None, 128)               8028288
#
#  dense_21 (Dense)            (None, 128)               16512
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dense_23 (Dense)            (None, 64)                4160
#
#  dense_24 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12,106,852
# Trainable params: 12,064,829
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 5606/5606 [==============================] - 569s 100ms/step - loss: 0.6976 - accuracy: 1.1149e-04 - auc_4: 0.5036 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.4999 - val_f1_score: 0.7009 - lr: 0.0010
# Epoch 2/100
# 5606/5606 [==============================] - 557s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5019 - f1_score: 0.6997 - val_loss: 0.6901 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 0.0010
# Epoch 3/100
# 5606/5606 [==============================] - 560s 100ms/step - loss: 0.6913 - accuracy: 0.0000e+00 - auc_4: 0.5033 - f1_score: 0.6997 - val_loss: 0.6898 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5014 - val_f1_score: 0.7009 - lr: 0.0010
# Epoch 4/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5021 - f1_score: 0.6997
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5606/5606 [==============================] - 558s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5021 - f1_score: 0.6997 - val_loss: 0.6898 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 5.0000e-04
# Epoch 5/100
# 5606/5606 [==============================] - 559s 100ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4998 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 5.0000e-04
# Epoch 6/100
# 5606/5606 [==============================] - 558s 100ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4991 - f1_score: 0.6997 - val_loss: 0.6904 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 5.0000e-04
# Epoch 7/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4997 - f1_score: 0.6997
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5606/5606 [==============================] - 555s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4997 - f1_score: 0.6997 - val_loss: 0.6904 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 2.5000e-04
# Epoch 8/100
# 5606/5606 [==============================] - 558s 100ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5001 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 2.5000e-04
# Epoch 9/100
# 5606/5606 [==============================] - 557s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5002 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 2.5000e-04
# Epoch 10/100
# 5606/5606 [==============================] - 543s 97ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5001 - f1_score: 0.6997 - val_loss: 0.6897 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 2.5000e-04
# Epoch 11/100
# 5606/5606 [==============================] - 556s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4998 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 2.5000e-04
# Epoch 12/100
# 5606/5606 [==============================] - 558s 100ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4998 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 2.5000e-04
# Epoch 13/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4999 - f1_score: 0.6997
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5606/5606 [==============================] - 556s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4999 - f1_score: 0.6997 - val_loss: 0.6897 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.2500e-04
# Epoch 14/100
# 5606/5606 [==============================] - 558s 99ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4989 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.2500e-04
# Epoch 15/100
# 5606/5606 [==============================] - 558s 100ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4996 - f1_score: 0.6997 - val_loss: 0.6900 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.2500e-04
# Epoch 16/100
# 5606/5606 [==============================] - 616s 110ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4993 - f1_score: 0.6997 - val_loss: 0.6894 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.2500e-04
# Epoch 17/100
# 5606/5606 [==============================] - 615s 110ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4991 - f1_score: 0.6997 - val_loss: 0.6894 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.2500e-04
# Epoch 18/100
# 5606/5606 [==============================] - 618s 110ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4990 - f1_score: 0.6997 - val_loss: 0.6894 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.2500e-04
# Epoch 19/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4990 - f1_score: 0.6997
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 5606/5606 [==============================] - 621s 111ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4990 - f1_score: 0.6997 - val_loss: 0.6894 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 6.2500e-05
# Epoch 20/100
# 5606/5606 [==============================] - 616s 110ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4988 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 6.2500e-05
# Epoch 21/100
# 5606/5606 [==============================] - 618s 110ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4989 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 6.2500e-05
# Epoch 22/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4993 - f1_score: 0.6997
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 5606/5606 [==============================] - 612s 109ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4993 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 3.1250e-05
# Epoch 23/100
# 5606/5606 [==============================] - 608s 108ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4980 - f1_score: 0.6997 - val_loss: 0.6903 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 3.1250e-05
# Epoch 24/100
# 5606/5606 [==============================] - 604s 108ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4980 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 3.1250e-05
# Epoch 25/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4973 - f1_score: 0.6997
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4973 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.5625e-05
# Epoch 26/100
# 5606/5606 [==============================] - 601s 107ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4998 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.5625e-05
# Epoch 27/100
# 5606/5606 [==============================] - 604s 108ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4992 - f1_score: 0.6997 - val_loss: 0.6899 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.5625e-05
# Epoch 28/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4991 - f1_score: 0.6997
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.4991 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 7.8125e-06
# Epoch 29/100
# 5606/5606 [==============================] - 605s 108ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 7.8125e-06
# Epoch 30/100
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 7.8125e-06
# Epoch 31/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 5606/5606 [==============================] - 601s 107ms/step - loss: 0.6903 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 3.9063e-06
# Epoch 32/100
# 5606/5606 [==============================] - 603s 108ms/step - loss: 0.6904 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 3.9063e-06
# Epoch 33/100
# 5606/5606 [==============================] - 602s 107ms/step - loss: 0.6904 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 3.9063e-06
# Epoch 34/100
# 5606/5606 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 5606/5606 [==============================] - 604s 108ms/step - loss: 0.6904 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.9531e-06
# Epoch 35/100
# 5606/5606 [==============================] - 603s 108ms/step - loss: 0.6904 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.9531e-06
# Epoch 36/100
# 5606/5606 [==============================] - 603s 108ms/step - loss: 0.6904 - accuracy: 0.0000e+00 - auc_4: 0.5000 - f1_score: 0.6997 - val_loss: 0.6902 - val_accuracy: 0.0000e+00 - val_auc_4: 0.5000 - val_f1_score: 0.7009 - lr: 1.9531e-06
# Epoch 36: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 21123.90 second(s) ===== ===== ===== ===== =====

# %%
test_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.int64, name=None))>
