# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from typeguard>=2.7->tensorflow_addons) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
import sys
sys.path.append('/home/jovyan/ChestXray-14')

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, TensorBoard
# Out:
# 2023-04-04 17:21:57.441564: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
ROOT_PATH = "/home/jovyan/ChestXray-14"
INPUT_PATH = f"{ROOT_PATH}/dataset/ChestXray NIH"

LABELS = ["Infiltration", "Atelectasis","Effusion", "No Finding"]

EXPERIMENT_NAME = "multiclass_classification_with_cross_entropy_loss"

# %%
class Dataset:
    INPUT_PATH = INPUT_PATH
    
    def __init__(self, fold_num):
        self.fold_num = fold_num
    
    def get_train(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/multiclass_dataset/folds/fold{self.fold_num}/train/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

    def get_test(self):
        filenames = tf.io.gfile.glob(f'{self.INPUT_PATH}/data/multiclass_dataset/folds/fold{self.fold_num}/test/*.tfrec')
        dataset = get_dataset(filenames)
        return dataset

# %% [markdown]
# tf.keras.mixed_precision
# ---
# make model train faster
# ```python
# tf.keras.mixed_precision.global_policy()
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
# ```

# %%
tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA A100-SXM4-40GB MIG 2g.10gb, compute capability 8.0

# %% [markdown]
# ## Model Training

# %%
import os
CURRENT_PATH = os.path.abspath("")
CURRENT_PATH
# Out:
# '/home/jovyan/ChestXray-14/experiments/MultiClass-Classification'

# %%
# Learning rate
def lr_schedule(epoch, learning_rate):
    tf.summary.scalar('learning rate', data=learning_rate, step=epoch)
    return learning_rate

# %%
import datetime

def get_callbacks(NAME, weight_option, fold_num=None):
    log_dir = f"{CURRENT_PATH}/logs/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    
    model_checkpoint_callback = ModelCheckpoint(f'results/models/{EXPERIMENT_NAME}/{NAME}_{weight_option}_FOLD_{fold_num}.h5', monitor='val_loss', mode='min', save_best_only=True)
    early_stop_callback = EarlyStopping(monitor='val_loss', mode="min", patience=20, verbose=1)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.5, patience=3, verbose=1)
    lr_logging_callback = LearningRateScheduler(lr_schedule)
    
    return model_checkpoint_callback, early_stop_callback, reduce_lr_callback, lr_logging_callback, tensorboard_callback

# %%
# Constant variables
NAME = "EfficientNetB0"
EPOCHS = 100
weight_option = None # use `'imagenet'` or `None` only

# %%
import time
from modules.models import Model
from modules.dataset import Dataset

NUM_FOLDS = 5
dataset = Dataset()
for fold_num in range(1, NUM_FOLDS + 1):
    
    # Callbacks
    (
        model_checkpoint_callback, 
        early_stop_callback, 
        reduce_lr_callback, 
        lr_logging_callback, 
        tensorboard_callback
    ) = get_callbacks(
        NAME, weight_option, fold_num
    )

    # Path for CSV
    path = os.path.join(CURRENT_PATH, "results", "history", EXPERIMENT_NAME, f"{NAME}_{weight_option}_FOLD_{fold_num}")
    os.makedirs(path, exist_ok=True)

    # CSV Logger
    csv_logger = CSVLogger(os.path.join(path, f"history.csv"))

    # Dataset
    train_dataset, test_dataset = dataset.get_kfold(fold_num)

    # Modeling
    transfer_model = tf.keras.applications.efficientnet.EfficientNetB0(
        include_top=False, 
        weights=weight_option,
        input_shape=(224, 224, 3),
        pooling=None
    )

    model = Model(
        transfer_model,
    )
    model = model.get_model()
    model._name = f"{EXPERIMENT_NAME}_FOLD_{fold_num}"
    model.summary()

    # Record time for training
    start = time.time()
    
    # Visualize
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=test_dataset,
        verbose=1, # Show Progress Bar while Traning
        callbacks=[model_checkpoint_callback, csv_logger, early_stop_callback, reduce_lr_callback, lr_logging_callback]
    )
    
    end = time.time()
    print(
        "===== " * 5,
        "Model Traninig for: {:.2f} second(s)".format(end - start),
        "===== " * 5,
        "\n\n"
    )
# Out:
# 2023-04-04 17:22:00.608025: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 17:22:01.368820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8011 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:ca:00.0, compute capability: 8.0
# Model: "multiclass_classification_with_cross_entropy_loss_FOLD_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 128)               8028288
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 12,107,047
# Trainable params: 12,065,024
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 2023-04-04 17:22:16.528103: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-04-04 17:22:17.428692: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-04 17:22:17.429966: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-04 17:22:17.430018: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-04-04 17:22:17.431074: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-04 17:22:17.431276: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 200/200 [==============================] - 40s 124ms/step - loss: 1.6063 - f1_score: 0.2402 - precision: 0.2400 - recall: 0.0281 - val_loss: 1.3928 - val_f1_score: 0.1040 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 200/200 [==============================] - 23s 114ms/step - loss: 1.4266 - f1_score: 0.2502 - precision: 0.2897 - recall: 0.0131 - val_loss: 1.3900 - val_f1_score: 0.1012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 200/200 [==============================] - 22s 111ms/step - loss: 1.3920 - f1_score: 0.2708 - precision: 0.3382 - recall: 0.0072 - val_loss: 1.3867 - val_f1_score: 0.1012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.3940 - f1_score: 0.2645 - precision: 0.2545 - recall: 0.0044 - val_loss: 1.3987 - val_f1_score: 0.2321 - val_precision: 0.3333 - val_recall: 0.0037 - lr: 0.0010
# Epoch 5/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.4062 - f1_score: 0.2504 - precision: 0.2593 - recall: 0.0066 - val_loss: 1.4389 - val_f1_score: 0.1981 - val_precision: 0.3000 - val_recall: 0.0188 - lr: 0.0010
# Epoch 6/100
# 200/200 [==============================] - 22s 112ms/step - loss: 1.3914 - f1_score: 0.2553 - precision: 0.2353 - recall: 0.0012 - val_loss: 1.3853 - val_f1_score: 0.1487 - val_precision: 0.3333 - val_recall: 0.0012 - lr: 0.0010
# Epoch 7/100
# 200/200 [==============================] - 21s 105ms/step - loss: 1.3921 - f1_score: 0.2516 - precision: 0.2903 - recall: 0.0028 - val_loss: 1.4337 - val_f1_score: 0.2179 - val_precision: 0.2000 - val_recall: 0.0037 - lr: 0.0010
# Epoch 8/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.3899 - f1_score: 0.2430 - precision: 0.3636 - recall: 0.0025 - val_loss: 1.3865 - val_f1_score: 0.1696 - val_precision: 0.5000 - val_recall: 0.0037 - lr: 0.0010
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3744 - f1_score: 0.2773 - precision: 0.3000 - recall: 9.3750e-04
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 21s 106ms/step - loss: 1.3744 - f1_score: 0.2773 - precision: 0.3000 - recall: 9.3750e-04 - val_loss: 1.4006 - val_f1_score: 0.1841 - val_precision: 0.2857 - val_recall: 0.0075 - lr: 5.0000e-04
# Epoch 10/100
# 200/200 [==============================] - 22s 111ms/step - loss: 1.3501 - f1_score: 0.2974 - precision: 0.5161 - recall: 0.0050 - val_loss: 1.3530 - val_f1_score: 0.2131 - val_precision: 0.4444 - val_recall: 0.0050 - lr: 5.0000e-04
# Epoch 11/100
# 200/200 [==============================] - 22s 112ms/step - loss: 1.3370 - f1_score: 0.3252 - precision: 0.4179 - recall: 0.0088 - val_loss: 1.3438 - val_f1_score: 0.3186 - val_precision: 0.3939 - val_recall: 0.0162 - lr: 5.0000e-04
# Epoch 12/100
# 200/200 [==============================] - 23s 112ms/step - loss: 1.3226 - f1_score: 0.3466 - precision: 0.4706 - recall: 0.0200 - val_loss: 1.3113 - val_f1_score: 0.3281 - val_precision: 0.6000 - val_recall: 0.0225 - lr: 5.0000e-04
# Epoch 13/100
# 200/200 [==============================] - 21s 105ms/step - loss: 1.3052 - f1_score: 0.3548 - precision: 0.5191 - recall: 0.0425 - val_loss: 1.3407 - val_f1_score: 0.3292 - val_precision: 0.5088 - val_recall: 0.0725 - lr: 5.0000e-04
# Epoch 14/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.2864 - f1_score: 0.3662 - precision: 0.5364 - recall: 0.0691 - val_loss: 1.3396 - val_f1_score: 0.3609 - val_precision: 0.4936 - val_recall: 0.0962 - lr: 5.0000e-04
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 1.2392 - f1_score: 0.3983 - precision: 0.5888 - recall: 0.1088
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 21s 107ms/step - loss: 1.2392 - f1_score: 0.3983 - precision: 0.5888 - recall: 0.1088 - val_loss: 1.4930 - val_f1_score: 0.3323 - val_precision: 0.4112 - val_recall: 0.1650 - lr: 2.5000e-04
# Epoch 16/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.0737 - f1_score: 0.4962 - precision: 0.6360 - recall: 0.2894 - val_loss: 1.5102 - val_f1_score: 0.3670 - val_precision: 0.4390 - val_recall: 0.2025 - lr: 2.5000e-04
# Epoch 17/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.9498 - f1_score: 0.5638 - precision: 0.6851 - recall: 0.4256 - val_loss: 1.8187 - val_f1_score: 0.3561 - val_precision: 0.3612 - val_recall: 0.2750 - lr: 2.5000e-04
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.8295 - f1_score: 0.6359 - precision: 0.7373 - recall: 0.5325
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 21s 105ms/step - loss: 0.8295 - f1_score: 0.6359 - precision: 0.7373 - recall: 0.5325 - val_loss: 1.9512 - val_f1_score: 0.3341 - val_precision: 0.3616 - val_recall: 0.2825 - lr: 1.2500e-04
# Epoch 19/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6228 - f1_score: 0.7411 - precision: 0.8218 - recall: 0.6803 - val_loss: 2.2603 - val_f1_score: 0.3344 - val_precision: 0.3462 - val_recall: 0.2800 - lr: 1.2500e-04
# Epoch 20/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4937 - f1_score: 0.7951 - precision: 0.8572 - recall: 0.7503 - val_loss: 2.4347 - val_f1_score: 0.3411 - val_precision: 0.3610 - val_recall: 0.3100 - lr: 1.2500e-04
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3936 - f1_score: 0.8392 - precision: 0.8994 - recall: 0.7987
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 21s 104ms/step - loss: 0.3936 - f1_score: 0.8392 - precision: 0.8994 - recall: 0.7987 - val_loss: 2.7620 - val_f1_score: 0.3609 - val_precision: 0.3683 - val_recall: 0.3113 - lr: 6.2500e-05
# Epoch 22/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.3486 - f1_score: 0.8629 - precision: 0.9202 - recall: 0.8213 - val_loss: 2.9619 - val_f1_score: 0.3602 - val_precision: 0.3592 - val_recall: 0.3237 - lr: 6.2500e-05
# Epoch 23/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.2917 - f1_score: 0.8798 - precision: 0.9372 - recall: 0.8394 - val_loss: 3.2099 - val_f1_score: 0.3531 - val_precision: 0.3567 - val_recall: 0.3237 - lr: 6.2500e-05
# Epoch 24/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2574 - f1_score: 0.8964 - precision: 0.9464 - recall: 0.8612
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 21s 104ms/step - loss: 0.2574 - f1_score: 0.8964 - precision: 0.9464 - recall: 0.8612 - val_loss: 3.5352 - val_f1_score: 0.3619 - val_precision: 0.3680 - val_recall: 0.3450 - lr: 3.1250e-05
# Epoch 25/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.2313 - f1_score: 0.9095 - precision: 0.9561 - recall: 0.8712 - val_loss: 3.6923 - val_f1_score: 0.3546 - val_precision: 0.3599 - val_recall: 0.3388 - lr: 3.1250e-05
# Epoch 26/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.2283 - f1_score: 0.9071 - precision: 0.9553 - recall: 0.8750 - val_loss: 3.6266 - val_f1_score: 0.3539 - val_precision: 0.3471 - val_recall: 0.3262 - lr: 3.1250e-05
# Epoch 27/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2092 - f1_score: 0.9182 - precision: 0.9621 - recall: 0.8800
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 200/200 [==============================] - 21s 104ms/step - loss: 0.2092 - f1_score: 0.9182 - precision: 0.9621 - recall: 0.8800 - val_loss: 3.7514 - val_f1_score: 0.3659 - val_precision: 0.3620 - val_recall: 0.3425 - lr: 1.5625e-05
# Epoch 28/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.1933 - f1_score: 0.9243 - precision: 0.9623 - recall: 0.8850 - val_loss: 3.9366 - val_f1_score: 0.3682 - val_precision: 0.3671 - val_recall: 0.3487 - lr: 1.5625e-05
# Epoch 29/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.1904 - f1_score: 0.9254 - precision: 0.9650 - recall: 0.8875 - val_loss: 4.0302 - val_f1_score: 0.3702 - val_precision: 0.3633 - val_recall: 0.3487 - lr: 1.5625e-05
# Epoch 30/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1892 - f1_score: 0.9291 - precision: 0.9655 - recall: 0.8925
# Epoch 30: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 200/200 [==============================] - 21s 104ms/step - loss: 0.1892 - f1_score: 0.9291 - precision: 0.9655 - recall: 0.8925 - val_loss: 4.1443 - val_f1_score: 0.3656 - val_precision: 0.3577 - val_recall: 0.3425 - lr: 7.8125e-06
# Epoch 31/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.1821 - f1_score: 0.9344 - precision: 0.9702 - recall: 0.8950 - val_loss: 4.1226 - val_f1_score: 0.3577 - val_precision: 0.3529 - val_recall: 0.3375 - lr: 7.8125e-06
# Epoch 32/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.1832 - f1_score: 0.9313 - precision: 0.9710 - recall: 0.8891 - val_loss: 4.2034 - val_f1_score: 0.3668 - val_precision: 0.3590 - val_recall: 0.3438 - lr: 7.8125e-06
# Epoch 32: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 704.25 second(s) ===== ===== ===== ===== =====
#
#
# Model: "multiclass_classification_with_cross_entropy_loss_FOLD_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_1 (Flatten)         (None, 62720)             0
#
#  dense_5 (Dense)             (None, 128)               8028288
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 12,107,047
# Trainable params: 12,065,024
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 200/200 [==============================] - 34s 121ms/step - loss: 1.5210 - f1_score: 0.2519 - precision_1: 0.2865 - recall_1: 0.0319 - val_loss: 1.3859 - val_f1_score: 0.1067 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 200/200 [==============================] - 21s 103ms/step - loss: 1.4616 - f1_score: 0.2451 - precision_1: 0.2376 - recall_1: 0.0134 - val_loss: 1.4153 - val_f1_score: 0.1012 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.4076 - f1_score: 0.2275 - precision_1: 0.1857 - recall_1: 0.0041 - val_loss: 1.3950 - val_f1_score: 0.1012 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 200/200 [==============================] - 22s 112ms/step - loss: 1.3851 - f1_score: 0.2702 - precision_1: 0.3200 - recall_1: 0.0025 - val_loss: 1.3756 - val_f1_score: 0.2443 - val_precision_1: 0.5000 - val_recall_1: 0.0012 - lr: 0.0010
# Epoch 5/100
# 200/200 [==============================] - 22s 110ms/step - loss: 1.3764 - f1_score: 0.2772 - precision_1: 0.2609 - recall_1: 0.0019 - val_loss: 1.3682 - val_f1_score: 0.3062 - val_precision_1: 1.0000 - val_recall_1: 0.0012 - lr: 0.0010
# Epoch 6/100
# 200/200 [==============================] - 21s 105ms/step - loss: 1.3844 - f1_score: 0.2787 - precision_1: 0.2532 - recall_1: 0.0063 - val_loss: 1.3711 - val_f1_score: 0.2628 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 7/100
# 200/200 [==============================] - 22s 110ms/step - loss: 1.3564 - f1_score: 0.3165 - precision_1: 0.5089 - recall_1: 0.0178 - val_loss: 1.3398 - val_f1_score: 0.3409 - val_precision_1: 0.3810 - val_recall_1: 0.0100 - lr: 0.0010
# Epoch 8/100
# 200/200 [==============================] - 21s 104ms/step - loss: 1.3472 - f1_score: 0.3103 - precision_1: 0.4148 - recall_1: 0.0175 - val_loss: 2.0329 - val_f1_score: 0.1974 - val_precision_1: 0.2558 - val_recall_1: 0.1388 - lr: 0.0010
# Epoch 9/100
# 200/200 [==============================] - 22s 111ms/step - loss: 1.3359 - f1_score: 0.3047 - precision_1: 0.4878 - recall_1: 0.0312 - val_loss: 1.3266 - val_f1_score: 0.3055 - val_precision_1: 0.5000 - val_recall_1: 0.0587 - lr: 0.0010
# Epoch 10/100
# 200/200 [==============================] - 21s 106ms/step - loss: 1.3158 - f1_score: 0.3231 - precision_1: 0.5580 - recall_1: 0.0391 - val_loss: 1.3320 - val_f1_score: 0.3139 - val_precision_1: 0.5510 - val_recall_1: 0.0338 - lr: 0.0010
# Epoch 11/100
# 200/200 [==============================] - 21s 105ms/step - loss: 1.3437 - f1_score: 0.3349 - precision_1: 0.5492 - recall_1: 0.0209 - val_loss: 1.3514 - val_f1_score: 0.2789 - val_precision_1: 0.5714 - val_recall_1: 0.0150 - lr: 0.0010
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3199 - f1_score: 0.3349 - precision_1: 0.5183 - recall_1: 0.0353
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 21s 106ms/step - loss: 1.3199 - f1_score: 0.3349 - precision_1: 0.5183 - recall_1: 0.0353 - val_loss: 1.3816 - val_f1_score: 0.3246 - val_precision_1: 0.3806 - val_recall_1: 0.0737 - lr: 5.0000e-04
# Epoch 13/100
# 200/200 [==============================] - 22s 110ms/step - loss: 1.2854 - f1_score: 0.3641 - precision_1: 0.5556 - recall_1: 0.0547 - val_loss: 1.3044 - val_f1_score: 0.3622 - val_precision_1: 0.4620 - val_recall_1: 0.1063 - lr: 5.0000e-04
# Epoch 14/100
# 200/200 [==============================] - 21s 105ms/step - loss: 1.2354 - f1_score: 0.4045 - precision_1: 0.5567 - recall_1: 0.1150 - val_loss: 1.3633 - val_f1_score: 0.3493 - val_precision_1: 0.4944 - val_recall_1: 0.1663 - lr: 5.0000e-04
# Epoch 15/100
# 200/200 [==============================] - 21s 105ms/step - loss: 1.1878 - f1_score: 0.4263 - precision_1: 0.5899 - recall_1: 0.1825 - val_loss: 1.4157 - val_f1_score: 0.3193 - val_precision_1: 0.4064 - val_recall_1: 0.1737 - lr: 5.0000e-04
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 1.0910 - f1_score: 0.4779 - precision_1: 0.6318 - recall_1: 0.2831
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 21s 105ms/step - loss: 1.0910 - f1_score: 0.4779 - precision_1: 0.6318 - recall_1: 0.2831 - val_loss: 1.5353 - val_f1_score: 0.3586 - val_precision_1: 0.4208 - val_recall_1: 0.2525 - lr: 2.5000e-04
# Epoch 17/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.9141 - f1_score: 0.5800 - precision_1: 0.6862 - recall_1: 0.4491 - val_loss: 1.6355 - val_f1_score: 0.4092 - val_precision_1: 0.4434 - val_recall_1: 0.3038 - lr: 2.5000e-04
# Epoch 18/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.7702 - f1_score: 0.6503 - precision_1: 0.7577 - recall_1: 0.5628 - val_loss: 1.9182 - val_f1_score: 0.3759 - val_precision_1: 0.4113 - val_recall_1: 0.3363 - lr: 2.5000e-04
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6849 - f1_score: 0.7079 - precision_1: 0.7918 - recall_1: 0.6144
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6849 - f1_score: 0.7079 - precision_1: 0.7918 - recall_1: 0.6144 - val_loss: 1.9257 - val_f1_score: 0.3698 - val_precision_1: 0.4101 - val_recall_1: 0.3250 - lr: 1.2500e-04
# Epoch 20/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5577 - f1_score: 0.7669 - precision_1: 0.8445 - recall_1: 0.7128 - val_loss: 2.1842 - val_f1_score: 0.3719 - val_precision_1: 0.3985 - val_recall_1: 0.3388 - lr: 1.2500e-04
# Epoch 21/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4313 - f1_score: 0.8240 - precision_1: 0.8901 - recall_1: 0.7769 - val_loss: 2.3904 - val_f1_score: 0.3722 - val_precision_1: 0.3793 - val_recall_1: 0.3162 - lr: 1.2500e-04
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3864 - f1_score: 0.8452 - precision_1: 0.8996 - recall_1: 0.8012
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 21s 104ms/step - loss: 0.3864 - f1_score: 0.8452 - precision_1: 0.8996 - recall_1: 0.8012 - val_loss: 2.6357 - val_f1_score: 0.3717 - val_precision_1: 0.3841 - val_recall_1: 0.3375 - lr: 6.2500e-05
# Epoch 23/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.3148 - f1_score: 0.8741 - precision_1: 0.9317 - recall_1: 0.8400 - val_loss: 2.7037 - val_f1_score: 0.3667 - val_precision_1: 0.3909 - val_recall_1: 0.3450 - lr: 6.2500e-05
# Epoch 24/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.2768 - f1_score: 0.8863 - precision_1: 0.9322 - recall_1: 0.8547 - val_loss: 3.0411 - val_f1_score: 0.3662 - val_precision_1: 0.3863 - val_recall_1: 0.3462 - lr: 6.2500e-05
# Epoch 25/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2473 - f1_score: 0.9041 - precision_1: 0.9351 - recall_1: 0.8775
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 21s 106ms/step - loss: 0.2473 - f1_score: 0.9041 - precision_1: 0.9351 - recall_1: 0.8775 - val_loss: 3.1196 - val_f1_score: 0.3697 - val_precision_1: 0.3836 - val_recall_1: 0.3500 - lr: 3.1250e-05
# Epoch 26/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.2317 - f1_score: 0.9126 - precision_1: 0.9419 - recall_1: 0.8869 - val_loss: 3.2205 - val_f1_score: 0.3598 - val_precision_1: 0.3724 - val_recall_1: 0.3413 - lr: 3.1250e-05
# Epoch 27/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2133 - f1_score: 0.9212 - precision_1: 0.9485 - recall_1: 0.8988 - val_loss: 3.3270 - val_f1_score: 0.3636 - val_precision_1: 0.3757 - val_recall_1: 0.3475 - lr: 3.1250e-05
# Epoch 28/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2107 - f1_score: 0.9171 - precision_1: 0.9398 - recall_1: 0.9019
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 200/200 [==============================] - 22s 107ms/step - loss: 0.2107 - f1_score: 0.9171 - precision_1: 0.9398 - recall_1: 0.9019 - val_loss: 3.2779 - val_f1_score: 0.3664 - val_precision_1: 0.3651 - val_recall_1: 0.3400 - lr: 1.5625e-05
# Epoch 29/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.1766 - f1_score: 0.9368 - precision_1: 0.9521 - recall_1: 0.9187 - val_loss: 3.3120 - val_f1_score: 0.3542 - val_precision_1: 0.3590 - val_recall_1: 0.3325 - lr: 1.5625e-05
# Epoch 30/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1823 - f1_score: 0.9296 - precision_1: 0.9494 - recall_1: 0.9141 - val_loss: 3.3775 - val_f1_score: 0.3571 - val_precision_1: 0.3664 - val_recall_1: 0.3413 - lr: 1.5625e-05
# Epoch 31/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1869 - f1_score: 0.9351 - precision_1: 0.9530 - recall_1: 0.9197
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1869 - f1_score: 0.9351 - precision_1: 0.9530 - recall_1: 0.9197 - val_loss: 3.3851 - val_f1_score: 0.3587 - val_precision_1: 0.3639 - val_recall_1: 0.3375 - lr: 7.8125e-06
# Epoch 32/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1555 - f1_score: 0.9434 - precision_1: 0.9621 - recall_1: 0.9291 - val_loss: 3.4439 - val_f1_score: 0.3577 - val_precision_1: 0.3646 - val_recall_1: 0.3400 - lr: 7.8125e-06
# Epoch 33/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.1587 - f1_score: 0.9465 - precision_1: 0.9606 - recall_1: 0.9300 - val_loss: 3.4931 - val_f1_score: 0.3577 - val_precision_1: 0.3613 - val_recall_1: 0.3388 - lr: 7.8125e-06
# Epoch 33: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 721.67 second(s) ===== ===== ===== ===== =====
#
#
# Model: "multiclass_classification_with_cross_entropy_loss_FOLD_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dense_10 (Dense)            (None, 128)               8028288
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 12,107,047
# Trainable params: 12,065,024
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 200/200 [==============================] - 36s 123ms/step - loss: 1.5032 - f1_score: 0.2547 - precision_2: 0.2752 - recall_2: 0.0256 - val_loss: 1.3936 - val_f1_score: 0.1024 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 200/200 [==============================] - 23s 113ms/step - loss: 1.4472 - f1_score: 0.2599 - precision_2: 0.2810 - recall_2: 0.0134 - val_loss: 1.3904 - val_f1_score: 0.1059 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 200/200 [==============================] - 21s 107ms/step - loss: 1.4064 - f1_score: 0.2729 - precision_2: 0.1857 - recall_2: 0.0041 - val_loss: 1.4500 - val_f1_score: 0.1186 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3800 - f1_score: 0.2902 - precision_2: 0.1739 - recall_2: 0.0025 - val_loss: 1.3953 - val_f1_score: 0.2793 - val_precision_2: 0.0833 - val_recall_2: 0.0025 - lr: 0.0010
# Epoch 5/100
# 200/200 [==============================] - 23s 114ms/step - loss: 1.3614 - f1_score: 0.3100 - precision_2: 0.4074 - recall_2: 0.0103 - val_loss: 1.3662 - val_f1_score: 0.2632 - val_precision_2: 0.2787 - val_recall_2: 0.0213 - lr: 0.0010
# Epoch 6/100
# 200/200 [==============================] - 23s 113ms/step - loss: 1.3423 - f1_score: 0.3087 - precision_2: 0.3729 - recall_2: 0.0137 - val_loss: 1.3323 - val_f1_score: 0.2953 - val_precision_2: 0.4545 - val_recall_2: 0.0125 - lr: 0.0010
# Epoch 7/100
# 200/200 [==============================] - 22s 107ms/step - loss: 1.3113 - f1_score: 0.3401 - precision_2: 0.4583 - recall_2: 0.0275 - val_loss: 1.3754 - val_f1_score: 0.3372 - val_precision_2: 0.4773 - val_recall_2: 0.0262 - lr: 0.0010
# Epoch 8/100
# 200/200 [==============================] - 22s 107ms/step - loss: 1.3129 - f1_score: 0.3455 - precision_2: 0.4098 - recall_2: 0.0156 - val_loss: 1.3810 - val_f1_score: 0.3244 - val_precision_2: 0.4902 - val_recall_2: 0.0625 - lr: 0.0010
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 1.2796 - f1_score: 0.3698 - precision_2: 0.5299 - recall_2: 0.0637
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 22s 109ms/step - loss: 1.2796 - f1_score: 0.3698 - precision_2: 0.5299 - recall_2: 0.0637 - val_loss: 1.6057 - val_f1_score: 0.2381 - val_precision_2: 0.3154 - val_recall_2: 0.1025 - lr: 5.0000e-04
# Epoch 10/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.1670 - f1_score: 0.4390 - precision_2: 0.5741 - recall_2: 0.1731 - val_loss: 1.5013 - val_f1_score: 0.3158 - val_precision_2: 0.4060 - val_recall_2: 0.1863 - lr: 5.0000e-04
# Epoch 11/100
# 200/200 [==============================] - 22s 107ms/step - loss: 1.0798 - f1_score: 0.4799 - precision_2: 0.5779 - recall_2: 0.2503 - val_loss: 1.5205 - val_f1_score: 0.3241 - val_precision_2: 0.3801 - val_recall_2: 0.1287 - lr: 5.0000e-04
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.9844 - f1_score: 0.5315 - precision_2: 0.6330 - recall_2: 0.3600
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.9844 - f1_score: 0.5315 - precision_2: 0.6330 - recall_2: 0.3600 - val_loss: 1.6901 - val_f1_score: 0.3012 - val_precision_2: 0.3376 - val_recall_2: 0.1975 - lr: 2.5000e-04
# Epoch 13/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.7711 - f1_score: 0.6549 - precision_2: 0.7119 - recall_2: 0.5644 - val_loss: 2.0237 - val_f1_score: 0.3502 - val_precision_2: 0.3585 - val_recall_2: 0.2912 - lr: 2.5000e-04
# Epoch 14/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.6414 - f1_score: 0.7121 - precision_2: 0.7509 - recall_2: 0.6556 - val_loss: 2.3635 - val_f1_score: 0.3208 - val_precision_2: 0.3386 - val_recall_2: 0.2950 - lr: 2.5000e-04
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5425 - f1_score: 0.7581 - precision_2: 0.7896 - recall_2: 0.7191
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5425 - f1_score: 0.7581 - precision_2: 0.7896 - recall_2: 0.7191 - val_loss: 2.5846 - val_f1_score: 0.3401 - val_precision_2: 0.3427 - val_recall_2: 0.3050 - lr: 1.2500e-04
# Epoch 16/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4027 - f1_score: 0.8439 - precision_2: 0.8647 - recall_2: 0.8206 - val_loss: 2.7236 - val_f1_score: 0.3394 - val_precision_2: 0.3520 - val_recall_2: 0.3225 - lr: 1.2500e-04
# Epoch 17/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2918 - f1_score: 0.8911 - precision_2: 0.9041 - recall_2: 0.8747 - val_loss: 2.8743 - val_f1_score: 0.3176 - val_precision_2: 0.3311 - val_recall_2: 0.3038 - lr: 1.2500e-04
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2397 - f1_score: 0.9150 - precision_2: 0.9264 - recall_2: 0.9003
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2397 - f1_score: 0.9150 - precision_2: 0.9264 - recall_2: 0.9003 - val_loss: 2.9569 - val_f1_score: 0.3225 - val_precision_2: 0.3329 - val_recall_2: 0.2975 - lr: 6.2500e-05
# Epoch 19/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.1810 - f1_score: 0.9356 - precision_2: 0.9468 - recall_2: 0.9241 - val_loss: 3.2231 - val_f1_score: 0.3208 - val_precision_2: 0.3270 - val_recall_2: 0.3025 - lr: 6.2500e-05
# Epoch 20/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1497 - f1_score: 0.9466 - precision_2: 0.9563 - recall_2: 0.9369 - val_loss: 3.4697 - val_f1_score: 0.3242 - val_precision_2: 0.3221 - val_recall_2: 0.2975 - lr: 6.2500e-05
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1583 - f1_score: 0.9447 - precision_2: 0.9538 - recall_2: 0.9347
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1583 - f1_score: 0.9447 - precision_2: 0.9538 - recall_2: 0.9347 - val_loss: 3.4127 - val_f1_score: 0.3244 - val_precision_2: 0.3271 - val_recall_2: 0.3050 - lr: 3.1250e-05
# Epoch 22/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.1357 - f1_score: 0.9540 - precision_2: 0.9646 - recall_2: 0.9463 - val_loss: 3.5066 - val_f1_score: 0.3381 - val_precision_2: 0.3410 - val_recall_2: 0.3162 - lr: 3.1250e-05
# Epoch 23/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.1228 - f1_score: 0.9550 - precision_2: 0.9645 - recall_2: 0.9500 - val_loss: 3.5331 - val_f1_score: 0.3313 - val_precision_2: 0.3347 - val_recall_2: 0.3088 - lr: 3.1250e-05
# Epoch 24/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1163 - f1_score: 0.9563 - precision_2: 0.9641 - recall_2: 0.9491
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 200/200 [==============================] - 22s 107ms/step - loss: 0.1163 - f1_score: 0.9563 - precision_2: 0.9641 - recall_2: 0.9491 - val_loss: 3.5497 - val_f1_score: 0.3250 - val_precision_2: 0.3288 - val_recall_2: 0.3038 - lr: 1.5625e-05
# Epoch 25/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1120 - f1_score: 0.9579 - precision_2: 0.9692 - recall_2: 0.9525 - val_loss: 3.6335 - val_f1_score: 0.3422 - val_precision_2: 0.3405 - val_recall_2: 0.3150 - lr: 1.5625e-05
# Epoch 26/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1094 - f1_score: 0.9638 - precision_2: 0.9733 - recall_2: 0.9553 - val_loss: 3.7296 - val_f1_score: 0.3409 - val_precision_2: 0.3400 - val_recall_2: 0.3175 - lr: 1.5625e-05
# Epoch 26: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 581.55 second(s) ===== ===== ===== ===== =====
#
#
# Model: "multiclass_classification_with_cross_entropy_loss_FOLD_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_3 (Flatten)         (None, 62720)             0
#
#  dense_15 (Dense)            (None, 128)               8028288
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 12,107,047
# Trainable params: 12,065,024
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 200/200 [==============================] - 36s 125ms/step - loss: 1.5191 - f1_score: 0.2647 - precision_3: 0.2606 - recall_3: 0.0288 - val_loss: 1.3915 - val_f1_score: 0.0914 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.4051 - f1_score: 0.2530 - precision_3: 0.3291 - recall_3: 0.0081 - val_loss: 1.3933 - val_f1_score: 0.0914 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.4038 - f1_score: 0.2542 - precision_3: 0.3333 - recall_3: 0.0088 - val_loss: 1.4000 - val_f1_score: 0.0914 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 200/200 [==============================] - 23s 114ms/step - loss: 1.3945 - f1_score: 0.2396 - precision_3: 0.3214 - recall_3: 0.0028 - val_loss: 1.3887 - val_f1_score: 0.1887 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 5/100
# 200/200 [==============================] - 22s 112ms/step - loss: 1.3842 - f1_score: 0.2525 - precision_3: 0.2414 - recall_3: 0.0022 - val_loss: 1.3893 - val_f1_score: 0.2050 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 6/100
# 200/200 [==============================] - 22s 110ms/step - loss: 1.3847 - f1_score: 0.2653 - precision_3: 0.3636 - recall_3: 0.0012 - val_loss: 1.3915 - val_f1_score: 0.1625 - val_precision_3: 0.5714 - val_recall_3: 0.0050 - lr: 0.0010
# Epoch 7/100
# 200/200 [==============================] - 23s 115ms/step - loss: 1.3715 - f1_score: 0.2702 - precision_3: 0.2500 - recall_3: 6.2500e-04 - val_loss: 1.3573 - val_f1_score: 0.2821 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - lr: 0.0010
# Epoch 8/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.3544 - f1_score: 0.2873 - precision_3: 0.4754 - recall_3: 0.0091 - val_loss: 1.4660 - val_f1_score: 0.2710 - val_precision_3: 0.3664 - val_recall_3: 0.0600 - lr: 0.0010
# Epoch 9/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.3418 - f1_score: 0.2929 - precision_3: 0.5116 - recall_3: 0.0069 - val_loss: 1.4120 - val_f1_score: 0.2883 - val_precision_3: 0.4375 - val_recall_3: 0.0088 - lr: 0.0010
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3288 - f1_score: 0.3175 - precision_3: 0.4780 - recall_3: 0.0272
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 22s 109ms/step - loss: 1.3288 - f1_score: 0.3175 - precision_3: 0.4780 - recall_3: 0.0272 - val_loss: 1.4395 - val_f1_score: 0.2564 - val_precision_3: 0.3507 - val_recall_3: 0.0587 - lr: 5.0000e-04
# Epoch 11/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.2712 - f1_score: 0.3483 - precision_3: 0.5596 - recall_3: 0.0866 - val_loss: 1.4329 - val_f1_score: 0.2870 - val_precision_3: 0.4076 - val_recall_3: 0.0800 - lr: 5.0000e-04
# Epoch 12/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.2444 - f1_score: 0.3734 - precision_3: 0.5888 - recall_3: 0.1253 - val_loss: 1.5488 - val_f1_score: 0.3000 - val_precision_3: 0.3793 - val_recall_3: 0.2062 - lr: 5.0000e-04
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 1.1860 - f1_score: 0.3972 - precision_3: 0.6044 - recall_3: 0.1728
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 22s 109ms/step - loss: 1.1860 - f1_score: 0.3972 - precision_3: 0.6044 - recall_3: 0.1728 - val_loss: 1.8887 - val_f1_score: 0.1626 - val_precision_3: 0.3264 - val_recall_3: 0.1963 - lr: 2.5000e-04
# Epoch 14/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.0541 - f1_score: 0.4561 - precision_3: 0.6534 - recall_3: 0.2716 - val_loss: 1.5120 - val_f1_score: 0.3034 - val_precision_3: 0.4393 - val_recall_3: 0.1675 - lr: 2.5000e-04
# Epoch 15/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.9408 - f1_score: 0.5370 - precision_3: 0.6763 - recall_3: 0.3434 - val_loss: 1.7604 - val_f1_score: 0.2907 - val_precision_3: 0.3883 - val_recall_3: 0.1737 - lr: 2.5000e-04
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.8692 - f1_score: 0.5717 - precision_3: 0.6862 - recall_3: 0.4353
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 23s 113ms/step - loss: 0.8692 - f1_score: 0.5717 - precision_3: 0.6862 - recall_3: 0.4353 - val_loss: 2.3186 - val_f1_score: 0.2792 - val_precision_3: 0.3333 - val_recall_3: 0.2313 - lr: 1.2500e-04
# Epoch 17/100
# 200/200 [==============================] - 23s 112ms/step - loss: 0.7749 - f1_score: 0.6177 - precision_3: 0.7170 - recall_3: 0.5028 - val_loss: 2.3217 - val_f1_score: 0.2740 - val_precision_3: 0.3020 - val_recall_3: 0.2250 - lr: 1.2500e-04
# Epoch 18/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.6428 - f1_score: 0.7026 - precision_3: 0.7572 - recall_3: 0.6141 - val_loss: 2.6479 - val_f1_score: 0.2634 - val_precision_3: 0.2788 - val_recall_3: 0.2450 - lr: 1.2500e-04
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5463 - f1_score: 0.7574 - precision_3: 0.7851 - recall_3: 0.7203
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 22s 112ms/step - loss: 0.5463 - f1_score: 0.7574 - precision_3: 0.7851 - recall_3: 0.7203 - val_loss: 2.9144 - val_f1_score: 0.2941 - val_precision_3: 0.3030 - val_recall_3: 0.2750 - lr: 6.2500e-05
# Epoch 20/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4644 - f1_score: 0.7947 - precision_3: 0.8116 - recall_3: 0.7769 - val_loss: 3.1226 - val_f1_score: 0.3089 - val_precision_3: 0.3123 - val_recall_3: 0.2975 - lr: 6.2500e-05
# Epoch 21/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4048 - f1_score: 0.8280 - precision_3: 0.8439 - recall_3: 0.8159 - val_loss: 3.3653 - val_f1_score: 0.3063 - val_precision_3: 0.3096 - val_recall_3: 0.2937 - lr: 6.2500e-05
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3527 - f1_score: 0.8640 - precision_3: 0.8797 - recall_3: 0.8500
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3527 - f1_score: 0.8640 - precision_3: 0.8797 - recall_3: 0.8500 - val_loss: 3.7868 - val_f1_score: 0.3077 - val_precision_3: 0.3094 - val_recall_3: 0.2962 - lr: 3.1250e-05
# Epoch 23/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.3269 - f1_score: 0.8793 - precision_3: 0.8962 - recall_3: 0.8662 - val_loss: 3.6914 - val_f1_score: 0.3093 - val_precision_3: 0.3131 - val_recall_3: 0.3025 - lr: 3.1250e-05
# Epoch 24/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2743 - f1_score: 0.8985 - precision_3: 0.9137 - recall_3: 0.8869 - val_loss: 3.9249 - val_f1_score: 0.3131 - val_precision_3: 0.3127 - val_recall_3: 0.3025 - lr: 3.1250e-05
# Epoch 25/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2548 - f1_score: 0.9036 - precision_3: 0.9206 - recall_3: 0.8909
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 200/200 [==============================] - 22s 110ms/step - loss: 0.2548 - f1_score: 0.9036 - precision_3: 0.9206 - recall_3: 0.8909 - val_loss: 4.2534 - val_f1_score: 0.3152 - val_precision_3: 0.3133 - val_recall_3: 0.3063 - lr: 1.5625e-05
# Epoch 26/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.2118 - f1_score: 0.9166 - precision_3: 0.9358 - recall_3: 0.9059 - val_loss: 4.4924 - val_f1_score: 0.3184 - val_precision_3: 0.3193 - val_recall_3: 0.3125 - lr: 1.5625e-05
# Epoch 27/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.2242 - f1_score: 0.9206 - precision_3: 0.9348 - recall_3: 0.9094 - val_loss: 4.5700 - val_f1_score: 0.3131 - val_precision_3: 0.3104 - val_recall_3: 0.3050 - lr: 1.5625e-05
# Epoch 27: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 611.95 second(s) ===== ===== ===== ===== =====
#
#
# Model: "multiclass_classification_with_cross_entropy_loss_FOLD_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_4 (Flatten)         (None, 62720)             0
#
#  dense_20 (Dense)            (None, 128)               8028288
#
#  dense_21 (Dense)            (None, 128)               16512
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dense_23 (Dense)            (None, 64)                4160
#
#  dense_24 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 12,107,047
# Trainable params: 12,065,024
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 200/200 [==============================] - 36s 125ms/step - loss: 1.5181 - f1_score: 0.2404 - precision_4: 0.2342 - recall_4: 0.0244 - val_loss: 1.3926 - val_f1_score: 0.0972 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 200/200 [==============================] - 23s 114ms/step - loss: 1.4206 - f1_score: 0.2429 - precision_4: 0.3101 - recall_4: 0.0125 - val_loss: 1.3859 - val_f1_score: 0.0964 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.4040 - f1_score: 0.2394 - precision_4: 0.2857 - recall_4: 0.0044 - val_loss: 1.3912 - val_f1_score: 0.0972 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.4215 - f1_score: 0.2372 - precision_4: 0.3256 - recall_4: 0.0088 - val_loss: 5.2172 - val_f1_score: 0.1044 - val_precision_4: 0.2600 - val_recall_4: 0.1875 - lr: 0.0010
# Epoch 5/100
# 200/200 [==============================] - 23s 114ms/step - loss: 1.3964 - f1_score: 0.2333 - precision_4: 0.3226 - recall_4: 0.0031 - val_loss: 1.3812 - val_f1_score: 0.2250 - val_precision_4: 1.0000 - val_recall_4: 0.0012 - lr: 0.0010
# Epoch 6/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3943 - f1_score: 0.2113 - precision_4: 0.3421 - recall_4: 0.0041 - val_loss: 1.5177 - val_f1_score: 0.1933 - val_precision_4: 0.1884 - val_recall_4: 0.0162 - lr: 0.0010
# Epoch 7/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3924 - f1_score: 0.2076 - precision_4: 0.3200 - recall_4: 0.0050 - val_loss: 1.4111 - val_f1_score: 0.1718 - val_precision_4: 0.3438 - val_recall_4: 0.0137 - lr: 0.0010
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3941 - f1_score: 0.2235 - precision_4: 0.3250 - recall_4: 0.0041
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3941 - f1_score: 0.2235 - precision_4: 0.3250 - recall_4: 0.0041 - val_loss: 1.3904 - val_f1_score: 0.1937 - val_precision_4: 0.2857 - val_recall_4: 0.0075 - lr: 5.0000e-04
# Epoch 9/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3822 - f1_score: 0.1958 - precision_4: 0.3333 - recall_4: 3.1250e-04 - val_loss: 1.3845 - val_f1_score: 0.1220 - val_precision_4: 1.0000 - val_recall_4: 0.0012 - lr: 5.0000e-04
# Epoch 10/100
# 200/200 [==============================] - 23s 113ms/step - loss: 1.3818 - f1_score: 0.1784 - precision_4: 0.4167 - recall_4: 0.0016 - val_loss: 1.3805 - val_f1_score: 0.1761 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 5.0000e-04
# Epoch 11/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3786 - f1_score: 0.2010 - precision_4: 0.5385 - recall_4: 0.0022 - val_loss: 1.3864 - val_f1_score: 0.1222 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - lr: 5.0000e-04
# Epoch 12/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.3754 - f1_score: 0.2296 - precision_4: 0.5714 - recall_4: 0.0012 - val_loss: 1.4279 - val_f1_score: 0.2198 - val_precision_4: 0.5714 - val_recall_4: 0.0150 - lr: 5.0000e-04
# Epoch 13/100
# 200/200 [==============================] - 24s 118ms/step - loss: 1.3796 - f1_score: 0.2019 - precision_4: 0.2941 - recall_4: 0.0016 - val_loss: 1.3780 - val_f1_score: 0.1880 - val_precision_4: 0.5000 - val_recall_4: 0.0075 - lr: 5.0000e-04
# Epoch 14/100
# 200/200 [==============================] - 22s 112ms/step - loss: 1.3755 - f1_score: 0.2462 - precision_4: 0.3571 - recall_4: 0.0016 - val_loss: 1.3733 - val_f1_score: 0.2013 - val_precision_4: 0.5000 - val_recall_4: 0.0025 - lr: 5.0000e-04
# Epoch 15/100
# 200/200 [==============================] - 21s 107ms/step - loss: 1.3716 - f1_score: 0.2462 - precision_4: 0.2222 - recall_4: 0.0012 - val_loss: 1.4412 - val_f1_score: 0.2205 - val_precision_4: 0.3289 - val_recall_4: 0.0312 - lr: 5.0000e-04
# Epoch 16/100
# 200/200 [==============================] - 21s 107ms/step - loss: 1.3660 - f1_score: 0.2008 - precision_4: 0.4118 - recall_4: 0.0044 - val_loss: 1.3896 - val_f1_score: 0.1347 - val_precision_4: 0.4000 - val_recall_4: 0.0025 - lr: 5.0000e-04
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3608 - f1_score: 0.2229 - precision_4: 0.4500 - recall_4: 0.0113
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 21s 106ms/step - loss: 1.3608 - f1_score: 0.2229 - precision_4: 0.4500 - recall_4: 0.0113 - val_loss: 1.3813 - val_f1_score: 0.1826 - val_precision_4: 0.5000 - val_recall_4: 0.0025 - lr: 2.5000e-04
# Epoch 18/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3562 - f1_score: 0.2213 - precision_4: 0.4694 - recall_4: 0.0072 - val_loss: 1.3804 - val_f1_score: 0.1307 - val_precision_4: 0.5000 - val_recall_4: 0.0012 - lr: 2.5000e-04
# Epoch 19/100
# 200/200 [==============================] - 22s 108ms/step - loss: 1.3433 - f1_score: 0.2328 - precision_4: 0.5268 - recall_4: 0.0184 - val_loss: 1.3758 - val_f1_score: 0.1960 - val_precision_4: 0.1667 - val_recall_4: 0.0012 - lr: 2.5000e-04
# Epoch 20/100
# 200/200 [==============================] - 23s 114ms/step - loss: 1.3355 - f1_score: 0.2558 - precision_4: 0.5092 - recall_4: 0.0259 - val_loss: 1.3706 - val_f1_score: 0.2095 - val_precision_4: 0.5000 - val_recall_4: 0.0075 - lr: 2.5000e-04
# Epoch 21/100
# 200/200 [==============================] - 23s 113ms/step - loss: 1.3163 - f1_score: 0.2761 - precision_4: 0.5274 - recall_4: 0.0331 - val_loss: 1.3640 - val_f1_score: 0.2454 - val_precision_4: 0.3810 - val_recall_4: 0.0100 - lr: 2.5000e-04
# Epoch 22/100
# 200/200 [==============================] - 23s 115ms/step - loss: 1.3017 - f1_score: 0.3514 - precision_4: 0.5119 - recall_4: 0.0469 - val_loss: 1.3623 - val_f1_score: 0.2429 - val_precision_4: 0.3077 - val_recall_4: 0.0050 - lr: 2.5000e-04
# Epoch 23/100
# 200/200 [==============================] - 22s 109ms/step - loss: 1.2581 - f1_score: 0.3815 - precision_4: 0.5539 - recall_4: 0.0931 - val_loss: 1.3806 - val_f1_score: 0.3350 - val_precision_4: 0.4587 - val_recall_4: 0.0625 - lr: 2.5000e-04
# Epoch 24/100
# 200/200 [==============================] - 22s 107ms/step - loss: 1.2080 - f1_score: 0.4109 - precision_4: 0.5929 - recall_4: 0.1625 - val_loss: 1.4011 - val_f1_score: 0.3301 - val_precision_4: 0.3448 - val_recall_4: 0.0375 - lr: 2.5000e-04
# Epoch 25/100
# 200/200 [==============================] - ETA: 0s - loss: 1.1503 - f1_score: 0.4499 - precision_4: 0.6423 - recall_4: 0.1975
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 22s 108ms/step - loss: 1.1503 - f1_score: 0.4499 - precision_4: 0.6423 - recall_4: 0.1975 - val_loss: 1.4157 - val_f1_score: 0.3541 - val_precision_4: 0.4304 - val_recall_4: 0.1238 - lr: 1.2500e-04
# Epoch 26/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.9937 - f1_score: 0.5324 - precision_4: 0.6796 - recall_4: 0.3494 - val_loss: 1.5812 - val_f1_score: 0.3310 - val_precision_4: 0.3780 - val_recall_4: 0.1937 - lr: 1.2500e-04
# Epoch 27/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.8711 - f1_score: 0.6033 - precision_4: 0.7193 - recall_4: 0.4822 - val_loss: 1.6138 - val_f1_score: 0.3498 - val_precision_4: 0.4000 - val_recall_4: 0.2125 - lr: 1.2500e-04
# Epoch 28/100
# 200/200 [==============================] - ETA: 0s - loss: 0.7369 - f1_score: 0.6777 - precision_4: 0.7656 - recall_4: 0.5828
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 21s 106ms/step - loss: 0.7369 - f1_score: 0.6777 - precision_4: 0.7656 - recall_4: 0.5828 - val_loss: 1.7544 - val_f1_score: 0.3383 - val_precision_4: 0.3704 - val_recall_4: 0.2412 - lr: 6.2500e-05
# Epoch 29/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.6029 - f1_score: 0.7483 - precision_4: 0.8064 - recall_4: 0.6834 - val_loss: 1.9378 - val_f1_score: 0.3596 - val_precision_4: 0.3710 - val_recall_4: 0.2788 - lr: 6.2500e-05
# Epoch 30/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5060 - f1_score: 0.7959 - precision_4: 0.8345 - recall_4: 0.7581 - val_loss: 2.0911 - val_f1_score: 0.3463 - val_precision_4: 0.3770 - val_recall_4: 0.2950 - lr: 6.2500e-05
# Epoch 31/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4467 - f1_score: 0.8312 - precision_4: 0.8658 - recall_4: 0.7981
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 21s 107ms/step - loss: 0.4467 - f1_score: 0.8312 - precision_4: 0.8658 - recall_4: 0.7981 - val_loss: 2.2203 - val_f1_score: 0.3285 - val_precision_4: 0.3550 - val_recall_4: 0.2937 - lr: 3.1250e-05
# Epoch 32/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.3816 - f1_score: 0.8505 - precision_4: 0.8782 - recall_4: 0.8250 - val_loss: 2.3828 - val_f1_score: 0.3487 - val_precision_4: 0.3495 - val_recall_4: 0.2875 - lr: 3.1250e-05
# Epoch 33/100
# 200/200 [==============================] - 22s 107ms/step - loss: 0.3460 - f1_score: 0.8674 - precision_4: 0.8941 - recall_4: 0.8469 - val_loss: 2.4814 - val_f1_score: 0.3365 - val_precision_4: 0.3425 - val_recall_4: 0.2950 - lr: 3.1250e-05
# Epoch 34/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3288 - f1_score: 0.8822 - precision_4: 0.9046 - recall_4: 0.8619
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3288 - f1_score: 0.8822 - precision_4: 0.9046 - recall_4: 0.8619 - val_loss: 2.5095 - val_f1_score: 0.3535 - val_precision_4: 0.3519 - val_recall_4: 0.3075 - lr: 1.5625e-05
# Epoch 35/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3011 - f1_score: 0.8894 - precision_4: 0.9120 - recall_4: 0.8716 - val_loss: 2.6020 - val_f1_score: 0.3377 - val_precision_4: 0.3366 - val_recall_4: 0.3000 - lr: 1.5625e-05
# Epoch 36/100
# 200/200 [==============================] - 23s 115ms/step - loss: 0.2599 - f1_score: 0.9066 - precision_4: 0.9275 - recall_4: 0.8919 - val_loss: 2.7152 - val_f1_score: 0.3386 - val_precision_4: 0.3449 - val_recall_4: 0.3113 - lr: 1.5625e-05
# Epoch 37/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2695 - f1_score: 0.9050 - precision_4: 0.9201 - recall_4: 0.8963
# Epoch 37: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 200/200 [==============================] - 22s 110ms/step - loss: 0.2695 - f1_score: 0.9050 - precision_4: 0.9201 - recall_4: 0.8963 - val_loss: 2.7481 - val_f1_score: 0.3475 - val_precision_4: 0.3475 - val_recall_4: 0.3162 - lr: 7.8125e-06
# Epoch 38/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.2549 - f1_score: 0.9154 - precision_4: 0.9315 - recall_4: 0.9013 - val_loss: 2.7023 - val_f1_score: 0.3377 - val_precision_4: 0.3485 - val_recall_4: 0.3150 - lr: 7.8125e-06
# Epoch 39/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.2314 - f1_score: 0.9174 - precision_4: 0.9353 - recall_4: 0.9038 - val_loss: 2.7675 - val_f1_score: 0.3401 - val_precision_4: 0.3430 - val_recall_4: 0.3113 - lr: 7.8125e-06
# Epoch 40/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2429 - f1_score: 0.9218 - precision_4: 0.9395 - recall_4: 0.9081
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2429 - f1_score: 0.9218 - precision_4: 0.9395 - recall_4: 0.9081 - val_loss: 2.7765 - val_f1_score: 0.3306 - val_precision_4: 0.3356 - val_recall_4: 0.3025 - lr: 3.9063e-06
# Epoch 41/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.2276 - f1_score: 0.9228 - precision_4: 0.9383 - recall_4: 0.9084 - val_loss: 2.8003 - val_f1_score: 0.3360 - val_precision_4: 0.3384 - val_recall_4: 0.3038 - lr: 3.9063e-06
# Epoch 42/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.2359 - f1_score: 0.9182 - precision_4: 0.9349 - recall_4: 0.9066 - val_loss: 2.8237 - val_f1_score: 0.3330 - val_precision_4: 0.3361 - val_recall_4: 0.3038 - lr: 3.9063e-06
# Epoch 42: early stopping
# ===== ===== ===== ===== =====  Model Traninig for: 938.37 second(s) ===== ===== ===== ===== =====

# %%
test_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.int64, name=None))>
