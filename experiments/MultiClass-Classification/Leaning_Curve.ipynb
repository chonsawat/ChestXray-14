# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ROOT_PATH = "/home/jovyan/ChestXray-14"

# %%
EXPERIMENT_NAME = "MultiClass-Classification"
RESULT_PATH = f"{ROOT_PATH}/experiments/{EXPERIMENT_NAME}/results"

# %%
RESULT_PATH
# Out:
# '/home/jovyan/ChestXray-14/experiments/MultiClass-Classification/results'

# %%
EXPERIMENT_NAME = "multiclass_classification_with_cross_entropy_loss"
MODEL_NAME = "EfficientNetB0"
WEIGHT = "None"
FOLD_NUM = 1

# %%
FOLD_NUM = 1
history1 = pd.read_csv(f"{RESULT_PATH}/history/{EXPERIMENT_NAME}/{MODEL_NAME}_{WEIGHT}_FOLD_{FOLD_NUM}/history.csv")
history1
# Out:
#     epoch                                           f1_score      loss  \
# 0       0  "[0.23783118, 0.22789785, 0.27210885, 0.222968...  1.606289
# 1       1   "[0.2460606, 0.26713532, 0.23569952, 0.2518797]"  1.426582
# 2       2  "[0.26035503, 0.22526637, 0.30676857, 0.290771...  1.391978
# 3       3   "[0.19909501, 0.29036143, 0.2940863, 0.2743078]"  1.393984
# 4       4  "[0.2658643, 0.20245399, 0.29600888, 0.23726541]"  1.406211
# 5       5  "[0.28272253, 0.25253808, 0.23367198, 0.252252...  1.391387
# 6       6  "[0.18421051, 0.27670753, 0.31723484, 0.2283237]"  1.392114
# 7       7  "[0.10052356, 0.19939117, 0.32082653, 0.351316...  1.389868
# 8       8  "[0.25354013, 0.20634922, 0.33888346, 0.310323...  1.374434
# 9       9  "[0.12387612, 0.4028436, 0.23728813, 0.42570284]"  1.350137
# 10     10  "[0.14671814, 0.42206746, 0.29866666, 0.433433...  1.336973
# 11     11  "[0.18328841, 0.46015933, 0.3342071, 0.40888387]"  1.322598
# 12     12  "[0.17032966, 0.47880298, 0.34827814, 0.4219457]"  1.305215
# 13     13      "[0.18538326, 0.5104686, 0.33666, 0.4322799]"  1.286367
# 14     14    "[0.2458629, 0.55187404, 0.36133924, 0.434172]"  1.239238
# 15     15   "[0.3485415, 0.67052025, 0.45577395, 0.5099648]"  1.073667
# 16     16     "[0.4059702, 0.7423887, 0.5382775, 0.5687091]"  0.949802
# 17     17  "[0.50034946, 0.78743964, 0.61002946, 0.645679...  0.829518
# 18     18    "[0.63238364, 0.8517619, 0.7203791, 0.7596804]"  0.622822
# 19     19    "[0.7053271, 0.87315273, 0.7840096, 0.8177887]"  0.493732
# 20     20         "[0.777128, 0.8858896, 0.83874923, 0.855]"  0.393619
# 21     21           "[0.8, 0.9016494, 0.8748451, 0.8749206]"  0.348597
# 22     22    "[0.84528303, 0.9032258, 0.88261145, 0.888183]"  0.291711
# 23     23    "[0.86366516, 0.9142857, 0.9023024, 0.9053549]"  0.257436
# 24     24   "[0.88471174, 0.9273183, 0.91339564, 0.9127182]"  0.231326
# 25     25   "[0.88502175, 0.9247312, 0.9145353, 0.90422887]"  0.228304
# 26     26   "[0.89401495, 0.9292035, 0.9233668, 0.92601734]"  0.209170
# 28   0.965002  0.887500  "[0.34573308, 0.4021739, 0.38222224, 0.35076922]"
# 29   0.965517  0.892500  "[0.33624455, 0.41935486, 0.35240275, 0.354354...
# 30   0.970190  0.895000   "[0.33620688, 0.4076087, 0.34498835, 0.3421829]"
# 31   0.970990  0.889063   "[0.33333334, 0.4139785, 0.36448598, 0.3554217]"
#
#     val_loss  val_precision  val_recall
# 0   1.392832       0.000000     0.00000
# 1   1.389961       0.000000     0.00000
# 2   1.386719       0.000000     0.00000
# 3   1.398672       0.333333     0.00375
# 4   1.438926       0.300000     0.01875
# 5   1.385293       0.333333     0.00125
# 6   1.433730       0.200000     0.00375
# 7   1.386465       0.500000     0.00375
# 8   1.400645       0.285714     0.00750
# 9   1.353008       0.444444     0.00500
# 10  1.343809       0.393939     0.01625
# 11  1.311309       0.600000     0.02250
# 12  1.340684       0.508772     0.07250
# 13  1.339629       0.493590     0.09625
# 14  1.492988       0.411215     0.16500
# 15  1.510234       0.439024     0.20250
# 16  1.818652       0.361248     0.27500
# 17  1.951172       0.361600     0.28250
# 18  2.260293       0.346213     0.28000
# 19  2.434668       0.360990     0.31000
# 20  2.762012       0.368343     0.31125
# 21  2.961855       0.359223     0.32375
# 22  3.209922       0.356749     0.32375
# 23  3.535156       0.368000     0.34500
# 24  3.692324       0.359894     0.33875
# 25  3.626641       0.347074     0.32625
# 26  3.751387       0.361955     0.34250
# 27  3.936641       0.367105     0.34875
# 28  4.030156       0.363281     0.34875
# 29  4.144258       0.357702     0.34250
# 30  4.122617       0.352941     0.33750
# 31  4.203398       0.359008     0.34375

# %%
def parse_f1(value):
    
    return np.mean(eval(eval(value)))

# %%
plt.plot(history1.loss, label="Training");
plt.plot(history1.val_loss, label="Validation");
plt.legend();

# %%
FOLD_NUM = 2
history2 = pd.read_csv(f"{RESULT_PATH}/history/{EXPERIMENT_NAME}/{MODEL_NAME}_{WEIGHT}_FOLD_{FOLD_NUM}/history.csv")
plt.plot(history2.loss, label="Training");
plt.plot(history2.val_loss, label="Validation");
plt.legend();

# %%
FOLD_NUM = 3
history3 = pd.read_csv(f"{RESULT_PATH}/history/{EXPERIMENT_NAME}/{MODEL_NAME}_{WEIGHT}_FOLD_{FOLD_NUM}/history.csv")
plt.plot(history3.loss, label="Training");
plt.plot(history3.val_loss, label="Validation");
plt.legend();

# %%
FOLD_NUM = 4
history4 = pd.read_csv(f"{RESULT_PATH}/history/{EXPERIMENT_NAME}/{MODEL_NAME}_{WEIGHT}_FOLD_{FOLD_NUM}/history.csv")
plt.plot(history4.loss, label="Training");
plt.plot(history4.val_loss, label="Validation");
plt.legend();

# %%
FOLD_NUM = 5
history5 = pd.read_csv(f"{RESULT_PATH}/history/{EXPERIMENT_NAME}/{MODEL_NAME}_{WEIGHT}_FOLD_{FOLD_NUM}/history.csv")
plt.plot(history5.loss, label="Training");
plt.plot(history5.val_loss, label="Validation");
plt.legend();
