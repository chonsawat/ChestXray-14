# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.zeros((224, 224, 3))

# %%
plt.imshow(img)

# %%
import cv2

o_img = plt.imread("cuda-image-16x9-1.jpg")
o_img = cv2.resize(o_img, (224, 224))
o_img = cv2.cvtColor(o_img, cv2.COLOR_RGB2GRAY)
plt.imshow(o_img)

# %%
def RGB2Gray(original_img)
    img = np.zeros((224, 224, 3))
    img[:,:,0] = original_img / 255
    img[:,:,1] = original_img / 255
    img[:,:,2] = original_img / 255
    return img

plt.imshow(img)
