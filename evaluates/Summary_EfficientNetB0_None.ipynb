# %%
import pandas as pd
import tensorflow as tf
# Out:
# 2023-03-22 14:00:04.952824: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
MODEL_NAME = "EfficientNetB0" # DenseNet121 / EfficientNetB0 / Resnet50
WEIGHT_OPTION = "None" # None / Imagenet
LOSS_FUCNCTION = "cross_entropy"
EXPERIMENT_NAME = f"{MODEL_NAME}_{WEIGHT_OPTION}"
EXPERIMENT_PATH = f"results/evaluate/{LOSS_FUCNCTION}/{EXPERIMENT_NAME}"

# %%
f1_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/f1_scores.csv"):
    df = pd.read_csv(input_path)
    f1_scores.append(df)
    
df_f1_scores = pd.concat(f1_scores)
df_f1_scores.to_csv(f"{EXPERIMENT_PATH}/f1_scores.csv", index=False)
df_f1_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.742775     0.334810       0.194453      0.380623      0.264278
# 0    0.739836     0.326383       0.193909      0.373821      0.269145
# 0    0.742933     0.341032       0.191148      0.376297      0.264901
# 0    0.735831     0.331933       0.200162      0.378374      0.275293
# 0    0.740660     0.340299       0.207992      0.386318      0.263662
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.207809   0.127854  0.057874  0.482163   0.066995            0.166189
# 0  0.153265   0.117355  0.068939  0.480173   0.051487            0.153106
# 0  0.203606   0.136646  0.067618  0.475762   0.071053            0.156398
# 0  0.198582   0.135950  0.092038  0.467040   0.074778            0.140903
# 0  0.222080   0.147580  0.068509  0.482054   0.076980            0.169416
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.307811  0.143251  0.223330  0.028986
# 0      0.285930  0.158074  0.206514  0.025316
# 0      0.299526  0.142811  0.217523  0.011029
# 0      0.273208  0.165860  0.197183  0.008799
# 0      0.310933  0.145118  0.218792  0.018711

# %%
precision_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/precision.csv"):
    df = pd.read_csv(input_path)
    precision_scores.append(df)
    
df_precision_scores = pd.concat(precision_scores)
df_precision_scores.to_csv(f"{EXPERIMENT_PATH}/precision.csv", index=False)
df_precision_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.638062     0.235890       0.133261      0.290871      0.192336
# 0    0.658041     0.246070       0.138667      0.291691      0.191624
# 0    0.655705     0.242245       0.137708      0.274884      0.222222
# 0    0.645472     0.248230       0.136425      0.296894      0.197594
# 0    0.661716     0.253586       0.133641      0.297255      0.216779
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.141544   0.106476  0.063126  0.395635   0.045142            0.098722
# 0  0.092231   0.069434  0.039683  0.417227   0.027718            0.108292
# 0  0.136461   0.086842  0.040252  0.380720   0.040992            0.107317
# 0  0.158182   0.104603  0.036684  0.409784   0.048417            0.121096
# 0  0.144483   0.082208  0.031756  0.421172   0.037077            0.114045
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.226250  0.105565  0.132898  0.004486
# 0      0.258904  0.093660  0.140125  0.031250
# 0      0.299242  0.089127  0.150241  0.005714
# 0      0.367299  0.083831  0.157110  0.009615
# 0      0.270380  0.084681  0.148372  0.043478

# %%
recall_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/recall.csv"):
    df = pd.read_csv(input_path)
    recall_scores.append(df)
    
df_recall_scores = pd.concat(recall_scores)
df_recall_scores.to_csv(f"{EXPERIMENT_PATH}/recall.csv", index=False)
df_recall_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.868983     0.559897       0.401950      0.541176      0.484082
# 0    0.868779     0.540934       0.437500      0.552829      0.396104
# 0    0.846464     0.492584       0.356823      0.528980      0.338432
# 0    0.844850     0.484523       0.322314      0.520329      0.452004
# 0    0.856930     0.575874       0.312369      0.596284      0.327869
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.332613   0.187984  0.169811  0.569896   0.217712            0.246020
# 0  0.372591   0.250501  0.517143  0.585274   0.187726            0.281899
# 0  0.369955   0.287474  0.326019  0.563809   0.346939            0.306184
# 0  0.453125   0.378758  0.262391  0.565487   0.361403            0.261194
# 0  0.400835   0.320388  0.211221  0.634043   0.266447            0.288210
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.344762  0.386770  0.381927  0.227273
# 0      0.269565  0.539632  0.360210  0.346154
# 0      0.357271  0.464591  0.451358  0.021739
# 0      0.319257  0.506231  0.392450  0.021277
# 0      0.299810  0.359121  0.393939  0.157895
