# %%
import pandas as pd
import tensorflow as tf
# Out:
# 2023-03-22 13:58:59.142207: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
MODEL_NAME = "DenseNet121" # DenseNet121 / EfficientNetB0 / Resnet50
WEIGHT_OPTION = "None" # None / Imagenet
LOSS_FUCNCTION = "cross_entropy"
EXPERIMENT_NAME = f"{MODEL_NAME}_{WEIGHT_OPTION}"
EXPERIMENT_PATH = f"results/evaluate/{LOSS_FUCNCTION}/{EXPERIMENT_NAME}"

# %%
f1_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/f1_scores.csv"):
    df = pd.read_csv(input_path)
    f1_scores.append(df)
    
df_f1_scores = pd.concat(f1_scores)
df_f1_scores.to_csv(f"{EXPERIMENT_PATH}/f1_scores.csv", index=False)
df_f1_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.728068     0.308685       0.187584      0.369650      0.254545
# 0    0.735031     0.321966       0.183720      0.376199      0.254631
# 0    0.730963     0.308961       0.179452      0.365745      0.230353
# 0    0.729486     0.321826       0.212065      0.376748      0.257398
# 0    0.736381     0.326093       0.200092      0.377144      0.264532
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.170260   0.125000  0.072993  0.421418   0.068653            0.147534
# 0  0.193814   0.138748  0.066282  0.437509   0.069795            0.165599
# 0  0.178667   0.129821  0.053913  0.415114   0.054998            0.150828
# 0  0.216699   0.133485  0.076538  0.441480   0.053794            0.138401
# 0  0.208835   0.134565  0.067797  0.448153   0.070028            0.150425
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.224788  0.135661  0.197225  0.016791
# 0      0.205128  0.131326  0.207571  0.006867
# 0      0.187590  0.137480  0.198997  0.013504
# 0      0.204301  0.146090  0.186006  0.018450
# 0      0.265541  0.146303  0.217561  0.020891

# %%
precision_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/precision.csv"):
    df = pd.read_csv(input_path)
    precision_scores.append(df)
    
df_precision_scores = pd.concat(precision_scores)
df_precision_scores.to_csv(f"{EXPERIMENT_PATH}/precision.csv", index=False)
df_precision_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.629251     0.224570       0.115230      0.288796      0.214422
# 0    0.623030     0.224229       0.118426      0.276817      0.172628
# 0    0.652155     0.243010       0.127353      0.289884      0.189690
# 0    0.635220     0.238105       0.114198      0.291054      0.195652
# 0    0.631772     0.242490       0.140493      0.309179      0.207830
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.113152   0.087232  0.050562  0.319129   0.042097            0.104257
# 0  0.127135   0.084198  0.029156  0.318953   0.031547            0.106070
# 0  0.142633   0.080537  0.038678  0.346083   0.057208            0.103391
# 0  0.144467   0.097774  0.042396  0.355212   0.055028            0.125186
# 0  0.153707   0.094584  0.044124  0.341493   0.030180            0.091992
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.206506  0.086240  0.137383  0.008780
# 0      0.128121  0.084086  0.139347  0.006969
# 0      0.237637  0.091088  0.165301  0.010838
# 0      0.205323  0.081738  0.147804  0.003549
# 0      0.192893  0.092910  0.124424  0.010040

# %%
recall_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/recall.csv"):
    df = pd.read_csv(input_path)
    recall_scores.append(df)
    
df_recall_scores = pd.concat(recall_scores)
df_recall_scores.to_csv(f"{EXPERIMENT_PATH}/recall.csv", index=False)
df_recall_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.872056     0.497016       0.469602      0.531760      0.364513
# 0    0.862955     0.478317       0.432286      0.482108      0.338015
# 0    0.884128     0.496629       0.370246      0.538851      0.346080
# 0    0.845589     0.495499       0.466595      0.539559      0.436920
# 0    0.863704     0.493551       0.504132      0.513381      0.313141
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.294363   0.238835  0.151815  0.569439   0.095395            0.244541
# 0  0.367171   0.226744  0.288410  0.624260   0.247232            0.279305
# 0  0.300448   0.283368  0.357367  0.594286   0.214286            0.260935
# 0  0.389722   0.408818  0.274286  0.635612   0.090253            0.275964
# 0  0.343750   0.220441  0.131195  0.620212   0.185965            0.252239
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.204934  0.333876  0.348485  0.105263
# 0      0.217143  0.341634  0.368286  0.113636
# 0      0.350090  0.376654  0.347940  0.217391
# 0      0.300870  0.371497  0.318142  0.288462
# 0      0.246622  0.317757  0.349429  0.191489
