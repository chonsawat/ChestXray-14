# %%
import pandas as pd
import tensorflow as tf
# Out:
# 2023-03-22 13:56:33.712071: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
MODEL_NAME = "DenseNet121" # DenseNet121 / EfficientNetB0 / Resnet50
WEIGHT_OPTION = "Imagenet" # None / Imagenet
LOSS_FUCNCTION = "cross_entropy"
EXPERIMENT_NAME = f"{MODEL_NAME}_{WEIGHT_OPTION}"
EXPERIMENT_PATH = f"results/evaluate/{LOSS_FUCNCTION}/{EXPERIMENT_NAME}"

# %%
f1_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/f1_scores.csv"):
    df = pd.read_csv(input_path)
    f1_scores.append(df)
    
df_f1_scores = pd.concat(f1_scores)
df_f1_scores.to_csv(f"{EXPERIMENT_PATH}/f1_scores.csv", index=False)
df_f1_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.736097     0.302965       0.202026      0.387108      0.274179
# 0    0.737196     0.307499       0.197207      0.381622      0.245537
# 0    0.740336     0.329964       0.189453      0.381547      0.264008
# 0    0.745080     0.326923       0.181962      0.384183      0.231031
# 0    0.741187     0.322067       0.195578      0.386526      0.255228
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.200238   0.143413  0.070166  0.466475   0.057377            0.144546
# 0  0.159002   0.110528  0.066034  0.487694   0.062440            0.147157
# 0  0.187178   0.149818  0.075472  0.471626   0.074679            0.158947
# 0  0.176701   0.117757  0.063398  0.463633   0.059011            0.150874
# 0  0.195408   0.142549  0.058003  0.468085   0.061739            0.156122
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.213490  0.178279  0.191539  0.018349
# 0      0.277256  0.180432  0.209290  0.020833
# 0      0.295964  0.147692  0.226308  0.023529
# 0      0.264041  0.190395  0.225510  0.006701
# 0      0.262366  0.187639  0.218302  0.012134

# %%
precision_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/precision.csv"):
    df = pd.read_csv(input_path)
    precision_scores.append(df)
    
df_precision_scores = pd.concat(precision_scores)
df_precision_scores.to_csv(f"{EXPERIMENT_PATH}/precision.csv", index=False)
df_precision_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.663280     0.227517       0.135145      0.293596      0.166446
# 0    0.665181     0.238498       0.119155      0.308068      0.154925
# 0    0.667681     0.247919       0.124024      0.320428      0.190892
# 0    0.650154     0.221234       0.136450      0.294358      0.202132
# 0    0.648830     0.253309       0.123488      0.295958      0.196513
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.096317   0.069192  0.038462  0.416023   0.036171            0.094828
# 0  0.107008   0.076225  0.034418  0.369241   0.033424            0.094688
# 0  0.126582   0.097561  0.033277  0.394988   0.035096            0.107955
# 0  0.138272   0.092273  0.038889  0.381771   0.045553            0.094273
# 0  0.120627   0.119767  0.045103  0.380365   0.057866            0.119501
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.242119  0.133912  0.150364  0.020408
# 0      0.222359  0.149955  0.159050  0.003385
# 0      0.223171  0.129886  0.149196  0.006182
# 0      0.162675  0.116334  0.131671  0.015385
# 0      0.280612  0.101144  0.157171  0.021277

# %%
recall_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/recall.csv"):
    df = pd.read_csv(input_path)
    recall_scores.append(df)
    
df_recall_scores = pd.concat(recall_scores)
df_recall_scores.to_csv(f"{EXPERIMENT_PATH}/recall.csv", index=False)
df_recall_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.848221     0.480464       0.388949      0.565196      0.426030
# 0    0.829651     0.474205       0.364669      0.545033      0.467847
# 0    0.832879     0.459494       0.462284      0.486980      0.384972
# 0    0.846793     0.519551       0.384787      0.510251      0.454111
# 0    0.861889     0.473146       0.406709      0.536781      0.402122
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.362851   0.321705  0.358491  0.599482   0.077491            0.309696
# 0  0.455357   0.274549  0.233236  0.589201   0.228070            0.328358
# 0  0.428266   0.264529  0.225714  0.574380   0.256318            0.281899
# 0  0.506726   0.258727  0.401254  0.622857   0.251701            0.371041
# 0  0.417537   0.200000  0.231023  0.620503   0.105263            0.237263
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.310476  0.381323  0.351236  0.022727
# 0      0.324324  0.276480  0.344162  0.021277
# 0      0.318261  0.337870  0.406661  0.326923
# 0      0.324955  0.260700  0.387379  0.326087
# 0      0.313093  0.273616  0.404040  0.026316
