# %%
import pandas as pd
import tensorflow as tf
# Out:
# 2023-03-22 14:02:45.138142: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
MODEL_NAME = "Resnet50" # DenseNet121 / EfficientNetB0 / Resnet50
WEIGHT_OPTION = "Imagenet" # None / Imagenet
LOSS_FUCNCTION = "cross_entropy"
EXPERIMENT_NAME = f"{MODEL_NAME}_{WEIGHT_OPTION}"
EXPERIMENT_PATH = f"results/evaluate/{LOSS_FUCNCTION}/{EXPERIMENT_NAME}"

# %%
f1_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/f1_scores.csv"):
    df = pd.read_csv(input_path)
    f1_scores.append(df)
    
df_f1_scores = pd.concat(f1_scores)
df_f1_scores.to_csv(f"{EXPERIMENT_PATH}/f1_scores.csv", index=False)
df_f1_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.738131     0.329541       0.197189      0.384745      0.256923
# 0    0.736093     0.305113       0.192710      0.381638      0.253783
# 0    0.740217     0.311949       0.178660      0.376460      0.236575
# 0    0.740738     0.321482       0.188230      0.377901      0.233673
# 0    0.737629     0.317316       0.197213      0.374826      0.262136
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.183418   0.131476  0.074074  0.457071   0.056186            0.146122
# 0  0.177529   0.115540  0.071927  0.449416   0.054516            0.144762
# 0  0.143299   0.124724  0.058422  0.457335   0.057766            0.142116
# 0  0.183869   0.116723  0.060606  0.460344   0.063919            0.173994
# 0  0.152358   0.113372  0.071789  0.462300   0.054742            0.139157
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.200686  0.182575  0.227306  0.011084
# 0      0.232978  0.180084  0.192461  0.010526
# 0      0.211254  0.173537  0.216589  0.012755
# 0      0.272545  0.157180  0.211405  0.003383
# 0      0.239342  0.176786  0.182163  0.033195

# %%
precision_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/precision.csv"):
    df = pd.read_csv(input_path)
    precision_scores.append(df)
    
df_precision_scores = pd.concat(precision_scores)
df_precision_scores.to_csv(f"{EXPERIMENT_PATH}/precision.csv", index=False)
df_precision_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.664530     0.237747       0.118551      0.291823      0.190643
# 0    0.648896     0.245090       0.123343      0.318848      0.177534
# 0    0.646707     0.248602       0.121094      0.285659      0.163580
# 0    0.652627     0.227062       0.132275      0.292672      0.180570
# 0    0.669040     0.210423       0.122636      0.306210      0.177103
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.089256   0.079481  0.031584  0.393889   0.035601            0.090533
# 0  0.117021   0.083982  0.041697  0.362654   0.030490            0.097744
# 0  0.125966   0.068219  0.046847  0.374939   0.042938            0.128187
# 0  0.092966   0.069241  0.044444  0.384597   0.030749            0.087170
# 0  0.124564   0.075131  0.041631  0.362707   0.029078            0.092721
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.234649  0.137821  0.157958  0.006775
# 0      0.197970  0.152162  0.158003  0.005602
# 0      0.288747  0.107485  0.147519  0.001695
# 0      0.214765  0.143064  0.124797  0.020619
# 0      0.204611  0.140789  0.132666  0.005703

# %%
recall_scores = []
for input_path in tf.io.gfile.glob(f"{EXPERIMENT_PATH}/*/recall.csv"):
    df = pd.read_csv(input_path)
    recall_scores.append(df)
    
df_recall_scores = pd.concat(recall_scores)
df_recall_scores.to_csv(f"{EXPERIMENT_PATH}/recall.csv", index=False)
df_recall_scores
# Out:
#    No Finding  Atelectasis  Consolidation  Infiltration  Pneumothorax  \
# 0    0.866766     0.454817       0.422432      0.558122      0.408872
# 0    0.835362     0.453483       0.362416      0.530246      0.311663
# 0    0.855822     0.502786       0.491379      0.484977      0.464750
# 0    0.848090     0.526655       0.387397      0.521101      0.478099
# 0    0.818083     0.554745       0.449621      0.506373      0.447566
#
#       Edema  Emphysema  Fibrosis  Effusion  Pneumonia  Pleural_Thickening  \
# 0  0.340292   0.403884  0.085809  0.596132   0.125000            0.270742
# 0  0.363229   0.289528  0.388715  0.545143   0.153061            0.330317
# 0  0.423983   0.302605  0.331429  0.617956   0.357401            0.289318
# 0  0.421875   0.312625  0.186589  0.579351   0.249123            0.344776
# 0  0.308855   0.250000  0.264151  0.590607   0.435424            0.329957
#
#    Cardiomegaly    Nodule      Mass    Hernia
# 0      0.258064  0.292345  0.372896  1.000000
# 0      0.192101  0.234241  0.344435  0.108696
# 0      0.203478  0.228183  0.404908  0.519231
# 0      0.270270  0.231308  0.337138  0.085106
# 0      0.270476  0.249805  0.350384  0.068182
